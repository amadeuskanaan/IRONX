# %%
# %matplotlib inline
import nibabel as nb
import seaborn as sns

# %%
gm = nb.load('/Users/kanaan/SCR/workspace/tmp_randomise/randomise_CP_GM_tfce_corrp_tstat1_STR3_MOTOR_MASK.nii.gz').get_data()
strm = nb.load('/Users/kanaan/SCR/workspace/tmp_randomise/randomise_CP_STR3_MOTOR_tfce_corrp_tstat1_masked.nii.gz').get_data()

# %%
sns.jointplot(gm.ravel(), strm.ravel(), kind = 'reg')
