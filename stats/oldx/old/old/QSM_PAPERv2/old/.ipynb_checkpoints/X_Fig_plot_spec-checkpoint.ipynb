# %%
# %matplotlib inline
import os 
import numpy as np
import matplotlib.pylab as plt
import itertools
import matplotlib
import itertools
import seaborn as sns 
sns.set_style("ticks")
plt.rcParams['font.family'] = 'Myriad Pro'
savefigdir    = '/Users/kanaan/Google Drive/TS-EUROTRAIN/Papers/2016_QSM_paper/Figures_python'

datadir = '/Users/kanaan/SCR/Dataframes_20150820/ANALYSIS'
dpi = 300

# %%
def locate_coord_files(datadir, subject, ppmst, voxel_name):
    rda = os.path.join(datadir, 'study_a', subject, 'lcmodel_rda/%s/ppm_%s/coord'%(voxel_name,ppmst))
    twx = os.path.join(datadir, 'study_a', subject, 'lcmodel_twix/%s/ppm_%s/coord'%(voxel_name,ppmst))
    return rda, twx

def get_lcmodel_coords(coord_file, analysis_type):

    f = open(coord_file)
    ppm = []
    phased = []
    fit = []
    base = []
    
    if analysis_type is 'rda_400':
        xrange_list = [(47,125), (126,204), (205,283),(284,362) ]
    elif analysis_type is 'rda_367':
        xrange_list = [(44,115), (116,187), (188,259),(260,331) ]
    elif analysis_type is 'twix_400':
        xrange_list = [(47,127), (128,208), (209,289),(290,370) ]
    elif analysis_type is 'twix_367':
        xrange_list = [(44,117), (118,191), (192,265),(266,339) ]
        
    for i, line in enumerate(f):
        if i in xrange(xrange_list[0][0], xrange_list[0][1] ):
            ppm.append(np.array(line.split()))
        elif i in xrange(xrange_list[1][0], xrange_list[1][1]):
            phased.append(np.array(line.split()))
        elif i in xrange(xrange_list[2][0], xrange_list[2][1]):
            fit.append(np.array(line.split()))
        elif i in xrange(xrange_list[3][0], xrange_list[3][1]):
            base.append(np.array(line.split()))
    
    ppm  = np.array(map( float, np.asarray(list(itertools.chain.from_iterable(ppm)))))
    pha  = np.array(map( float, np.asarray(list(itertools.chain.from_iterable(phased)))))
    fit  = np.array(map( float, np.asarray(list(itertools.chain.from_iterable(fit)))))
    bsl  = np.array(map( float, np.asarray(list(itertools.chain.from_iterable(base)))))
    res  = pha -fit 
    return ppm, fit, res, bsl, pha

# %%
HR8T_RDA_ACC_400, HR8T_TWX_ACC_400 = locate_coord_files(datadir, 'HR8T', 4.0, 'ACC')
HR8T_RDA_THA_400, HR8T_TWX_THA_400 = locate_coord_files(datadir, 'HR8T', 4.0, 'THA')
HR8T_RDA_STR_400, HR8T_TWX_STR_400 = locate_coord_files(datadir, 'HR8T', 4.0, 'STR')

HR8T_RDA_ACC_367, HR8T_TWX_ACC_367 = locate_coord_files(datadir, 'HR8T', 3.67, 'ACC')
HR8T_RDA_THA_367, HR8T_TWX_THA_367 = locate_coord_files(datadir, 'HR8T', 3.67, 'THA')
HR8T_RDA_STR_367, HR8T_TWX_STR_367 = locate_coord_files(datadir, 'HR8T', 3.67, 'STR')


TSEP_RDA_ACC_400, TSEP_TWX_ACC_400 = locate_coord_files(datadir, 'TSEP', 4.0, 'ACC')
TSEP_RDA_THA_400, TSEP_TWX_THA_400 = locate_coord_files(datadir, 'TSEP', 4.0, 'THA')
TSEP_RDA_STR_400, TSEP_TWX_STR_400 = locate_coord_files(datadir, 'TSEP', 4.0, 'STR')

TSEP_RDA_ACC_367, TSEP_TWX_ACC_367 = locate_coord_files(datadir, 'TSEP', 3.67, 'ACC')
TSEP_RDA_THA_367, TSEP_TWX_THA_367 = locate_coord_files(datadir, 'TSEP', 3.67, 'THA')
TSEP_RDA_STR_367, TSEP_TWX_STR_367 = locate_coord_files(datadir, 'TSEP', 3.67, 'STR')

# %%
HR8T_TWX_400_ACC_PPM, HR8T_TWX_ACC_400_FIT, HR8T_TWX_ACC_400_RES, HR8T_TWX_ACC_400_BSL, HR8T_TWX_ACC_400_PH = get_lcmodel_coords(HR8T_TWX_ACC_400, 'twix_400')
HR8T_TWX_400_THA_PPM, HR8T_TWX_THA_400_FIT, HR8T_TWX_THA_400_RES, HR8T_TWX_THA_400_BSL, HR8T_TWX_THA_400_PH = get_lcmodel_coords(HR8T_TWX_THA_400, 'twix_400')
HR8T_TWX_400_STR_PPM, HR8T_TWX_STR_400_FIT, HR8T_TWX_STR_400_RES, HR8T_TWX_STR_400_BSL, HR8T_TWX_STR_400_PH = get_lcmodel_coords(HR8T_TWX_STR_400, 'twix_400')

HR8T_TWX_367_ACC_PPM, HR8T_TWX_ACC_367_FIT, HR8T_TWX_ACC_367_RES, HR8T_TWX_ACC_367_BSL, HR8T_TWX_ACC_367_PH = get_lcmodel_coords(HR8T_TWX_ACC_367, 'twix_367')
HR8T_TWX_367_THA_PPM, HR8T_TWX_THA_367_FIT, HR8T_TWX_THA_367_RES, HR8T_TWX_THA_367_BSL, HR8T_TWX_THA_367_PH = get_lcmodel_coords(HR8T_TWX_THA_367, 'twix_367')
HR8T_TWX_367_STR_PPM, HR8T_TWX_STR_367_FIT, HR8T_TWX_STR_367_RES, HR8T_TWX_STR_367_BSL, HR8T_TWX_STR_367_PH = get_lcmodel_coords(HR8T_TWX_STR_367, 'twix_367')


TSEP_TWX_400_ACC_PPM, TSEP_TWX_ACC_400_FIT, TSEP_TWX_ACC_400_RES, TSEP_TWX_ACC_400_BSL, TSEP_TWX_ACC_400_PH = get_lcmodel_coords(TSEP_TWX_ACC_400, 'twix_400')
TSEP_TWX_400_THA_PPM, TSEP_TWX_THA_400_FIT, TSEP_TWX_THA_400_RES, TSEP_TWX_THA_400_BSL, TSEP_TWX_THA_400_PH = get_lcmodel_coords(TSEP_TWX_THA_400, 'twix_400')
TSEP_TWX_400_STR_PPM, TSEP_TWX_STR_400_FIT, TSEP_TWX_STR_400_RES, TSEP_TWX_STR_400_BSL, TSEP_TWX_STR_400_PH = get_lcmodel_coords(TSEP_TWX_STR_400, 'twix_400')

TSEP_TWX_367_ACC_PPM, TSEP_TWX_ACC_367_FIT, TSEP_TWX_ACC_367_RES, TSEP_TWX_ACC_367_BSL, TSEP_TWX_ACC_367_PH = get_lcmodel_coords(TSEP_TWX_ACC_367, 'twix_367')
TSEP_TWX_367_THA_PPM, TSEP_TWX_THA_367_FIT, TSEP_TWX_THA_367_RES, TSEP_TWX_THA_367_BSL, TSEP_TWX_THA_367_PH = get_lcmodel_coords(TSEP_TWX_THA_367, 'twix_367')
TSEP_TWX_367_STR_PPM, TSEP_TWX_STR_367_FIT, TSEP_TWX_STR_367_RES, TSEP_TWX_STR_367_BSL, TSEP_TWX_STR_367_PH = get_lcmodel_coords(TSEP_TWX_STR_367, 'twix_367')


FMEP_RDA_THA_400, FMEP_TWX_THA_400 = locate_coord_files(datadir, 'FMEP', 4.0, 'THA')
FMEP_RDA_THA_367, FMEP_TWX_THA_367 = locate_coord_files(datadir, 'FMEP', 3.67, 'THA')

FMEP_TWX_400_THA_PPM, FMEP_TWX_THA_400_FIT, FMEP_TWX_THA_400_RES, FMEP_TWX_THA_400_BSL, FMEP_TWX_THA_400_PH = get_lcmodel_coords(FMEP_TWX_THA_400, 'twix_400')
FMEP_TWX_367_THA_PPM, FMEP_TWX_THA_367_FIT, FMEP_TWX_THA_367_RES, FMEP_TWX_THA_367_BSL, FMEP_TWX_THA_367_PH = get_lcmodel_coords(FMEP_TWX_THA_367, 'twix_367')

# %%
# ACC 

# Initialize
fig, ax = plt.subplots(1)
fig.set_size_inches([21,15.5])

# PLOT
ax.plot(TSEP_TWX_367_ACC_PPM,  TSEP_TWX_ACC_367_FIT, 'red', linewidth=2.5) 
ax.plot(TSEP_TWX_367_ACC_PPM,  TSEP_TWX_ACC_367_BSL, 'k', linewidth=2.5) 
ax.plot(TSEP_TWX_367_ACC_PPM,  TSEP_TWX_ACC_367_RES, 'b', linewidth=2.5) 


# CLEAN
ax.get_xaxis().tick_bottom()
#ax.set_xticks([]) 
#ax.set_xticklabels([])
ax.set_yticks([]) 
ax.set_yticklabels([])
ax.legend(frameon=False)
#ax.spines['bottom'].set_visible(False)
#ax.spines['right'].set_visible(False)
#ax.spines['left'].set_visible(False)
#ax.spines['top'].set_visible(False)
#ax.tick_params(axis='x', labelsize=14,pad=8)
plt.xlim(0.25,3.7)
plt.ylim(-3e5, 3.8e6)
ax.tick_params(axis='x', direction='in', labelsize=25)
ax.invert_xaxis()
ax.xaxis.set_tick_params(size=13, width =2)
#plt.xlabel('Frequency (ppm)',fontsize= 15, weight='bold')
#plt.savefig('/Users/kanaan/Desktop/Glu_Paper/Figures_python/spectrum_acc.png',dpi=300, transparent=True, bbox_inches='tight')
# Out:
# /Users/kanaan/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
# Initialize
fig, ax = plt.subplots(1)
fig.set_size_inches([21,15.5])

# PLOT
xppm, xfit, xres, xbsl, xpha = get_lcmodel_coords(TSEP_RDA_STR_400, 'rda_400')
ppm, fit, res, bsl, pha = get_lcmodel_coords(TSEP_RDA_STR_367, 'rda_367')
ax.plot(ppm,  fit, 'k', linewidth=4) 
#ax.plot(xppm,  xfit, 'k', linewidth=4) 

#ppm, fit, res, bsl, pha = get_lcmodel_coords(TSEP_TWX_STR_400, 'twix_400')
#ax.plot(ppm,  fit, 'red', linewidth=2.5) 

#ax.plot(ppm,  bsl, 'k', linewidth=2.5) 
#ax.plot(ppm,  res, 'b', linewidth=2.5) 

#ax.plot(TSEP_RDA_367_ACC_PPM,  TSEP_RDA_ACC_367_FIT, 'red', linewidth=2.5) 
#ax.plot(TSEP_RDA_367_ACC_PPM,  TSEP_RDA_ACC_367_BSL, 'k', linewidth=2.5) 
#ax.plot(TSEP_RDA_367_ACC_PPM,  TSEP_RDA_ACC_367_RES, 'b', linewidth=2.5) 

# CLEAN
ax.get_xaxis().tick_bottom()
ax.set_xticks([]) 
ax.set_xticklabels([])
ax.set_yticks([]) 
ax.set_yticklabels([])
ax.legend(frameon=False)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['top'].set_visible(False)

ax.xaxis.set_tick_params(size=11, width =2)
ax.tick_params(axis='x', direction='in', labelsize=20, )
plt.xlim(0.3,3.67)
#plt.ylim(2e5, 3e6)
plt.ylim(-3.5e5, 3e6)
#ax.tick_params(axis='x', direction='in', labelsize=25)
ax.invert_xaxis()
ax.xaxis.set_tick_params(size=13, width =2)
#plt.xlabel('Frequency (ppm)',fontsize= 15, weight='bold')
#plt.savefig('/Users/kanaan/Desktop/Glu_Paper/Figures_python/tsep_uncorrected.png',dpi=dpi, transparent=True, bbox_inches='tight')
plt.savefig(os.path.join(savefigdir, 'spec_str_unfit'),dpi=dpi, transparent=True, bbox_inches='tight')

# %%
# Initialize
fig, ax = plt.subplots(1)
fig.set_size_inches([21,15.5])

# PLOT
ppm, fit, res, bsl, pha = get_lcmodel_coords(TSEP_TWX_STR_367, 'twix_367')
ppm, fit, res, bsl, pha = get_lcmodel_coords(TSEP_TWX_STR_367, 'twix_367')

ax.plot(ppm,  fit, 'red', linewidth=4) 
#ax.plot(FMEP_TWX_400_THA_PPM, FMEP_TWX_THA_400_RES, 'blue',  linewidth=2.5) 
#ax.plot(FMEP_TWX_367_THA_PPM, FMEP_TWX_THA_367_RES, 'red',  linewidth=2.5) 

#ax.plot(ppm,  bsl, 'k', linewidth=2.5) 
#ax.plot(ppm,  res, 'b', linewidth=2.5) 

#ax.plot(TSEP_RDA_367_ACC_PPM,  TSEP_RDA_ACC_367_FIT, 'red', linewidth=2.5) 
#ax.plot(TSEP_RDA_367_ACC_PPM,  TSEP_RDA_ACC_367_BSL, 'k', linewidth=2.5) 
#ax.plot(TSEP_RDA_367_ACC_PPM,  TSEP_RDA_ACC_367_RES, 'b', linewidth=2.5) 

# CLEAN
ax.get_xaxis().tick_bottom()
ax.set_xticks([]) 
ax.set_xticklabels([])
ax.set_yticks([]) 
ax.set_yticklabels([])
ax.legend(frameon=False)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['top'].set_visible(False)
#ax.tick_params(axis='x', labelsize=14,pad=8)
plt.xlim(0.3,3.67)
plt.ylim(-3.5e5, 3e6)
ax.xaxis.set_tick_params(size=11, width =2)
ax.tick_params(axis='x', direction='in', labelsize=20, )
ax.invert_xaxis()
ax.xaxis.set_tick_params(size=13, width =2)
#plt.xlabel('Frequency (ppm)',fontsize= 15, weight='bold')
#plt.savefig('/Users/kanaan/Desktop/Glu_Paper/Figures_python/tsep_corrected.png',dpi=dpi, transparent=True, bbox_inches='tight')
plt.savefig(os.path.join(savefigdir, 'spec_str_fit'),dpi=dpi, transparent=True, bbox_inches='tight')

# %%
# Initialize
fig, ax = plt.subplots(1)
fig.set_size_inches([21,15.5])

# PLOT
ppm, fit, res, bsl, pha = get_lcmodel_coords(TSEP_TWX_STR_367, 'twix_367')
ppm, fit, res, bsl, pha = get_lcmodel_coords(TSEP_TWX_STR_367, 'twix_367')

#ax.plot(ppm,  fit, 'red', linewidth=4) 
#ax.plot(FMEP_TWX_400_THA_PPM, FMEP_TWX_THA_400_RES, 'blue',  linewidth=2.5) 
ax.plot(FMEP_TWX_367_THA_PPM, FMEP_TWX_THA_367_RES, 'blue',  linewidth=2.5) 

#ax.plot(ppm,  bsl, 'k', linewidth=2.5) 
#ax.plot(ppm,  res, 'b', linewidth=2.5) 

#ax.plot(TSEP_RDA_367_ACC_PPM,  TSEP_RDA_ACC_367_FIT, 'red', linewidth=2.5) 
#ax.plot(TSEP_RDA_367_ACC_PPM,  TSEP_RDA_ACC_367_BSL, 'k', linewidth=2.5) 
#ax.plot(TSEP_RDA_367_ACC_PPM,  TSEP_RDA_ACC_367_RES, 'b', linewidth=2.5) 

# CLEAN
ax.get_xaxis().tick_bottom()
#ax.set_xticks([]) 
#ax.set_xticklabels([])
ax.set_yticks([]) 
ax.set_yticklabels([])
ax.legend(frameon=False)
#ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['top'].set_visible(False)
#ax.tick_params(axis='x', labelsize=14,pad=8)
plt.xlim(0.3,3.67)
plt.ylim(-3.5e5, 3e6)
ax.tick_params(axis='x', direction='in', labelsize=29, )
ax.invert_xaxis()
ax.xaxis.set_tick_params(size=13, width =2)
#plt.xlabel('Frequency (ppm)',fontsize= 15, weight='bold')
#plt.savefig('/Users/kanaan/Desktop/Glu_Paper/Figures_python/tsep_ppmst.png',dpi=dpi, transparent=True, bbox_inches='tight')
plt.savefig(os.path.join(savefigdir, 'spec_str_res'),dpi=dpi, transparent=True, bbox_inches='tight')

# %%
# Initialize
fig, ax = plt.subplots(1)
fig.set_size_inches([21,15.5])

# PLOT
ppm, fit, res, bsl, pha = get_lcmodel_coords(TSEP_TWX_STR_367, 'twix_367')
ppm, fit, res, bsl, pha = get_lcmodel_coords(TSEP_TWX_STR_367, 'twix_367')

#ax.plot(ppm,  fit, 'red', linewidth=4) 
#ax.plot(FMEP_TWX_400_THA_PPM, FMEP_TWX_THA_400_RES, 'blue',  linewidth=2.5) 
#ax.plot(FMEP_TWX_367_THA_PPM, FMEP_TWX_THA_367_FIT, 'red',  linewidth=2.5) 
ax.plot(FMEP_TWX_367_THA_PPM, FMEP_TWX_THA_367_BSL, 'k',  linewidth=2.5) 

#ax.plot(ppm,  bsl, 'k', linewidth=2.5) 
#ax.plot(ppm,  res, 'b', linewidth=2.5) 

#ax.plot(TSEP_RDA_367_ACC_PPM,  TSEP_RDA_ACC_367_FIT, 'red', linewidth=2.5) 
#ax.plot(TSEP_RDA_367_ACC_PPM,  TSEP_RDA_ACC_367_BSL, 'k', linewidth=2.5) 
#ax.plot(TSEP_RDA_367_ACC_PPM,  TSEP_RDA_ACC_367_RES, 'b', linewidth=2.5) 

# CLEAN
ax.get_xaxis().tick_bottom()
ax.set_xticks([]) 
ax.set_xticklabels([])
ax.set_yticks([]) 
ax.set_yticklabels([])
ax.legend(frameon=False)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['top'].set_visible(False)
#ax.tick_params(axis='x', labelsize=14,pad=8)
plt.xlim(0.3,3.67)
plt.ylim(-3.5e5, 3e6)
ax.xaxis.set_tick_params(size=11, width =2)
ax.tick_params(axis='x', direction='in', labelsize=20, )
ax.invert_xaxis()
ax.xaxis.set_tick_params(size=13, width =2)
#plt.savefig('/Users/kanaan/Desktop/Glu_Paper/Figures_python/tsep_ppmst_short_spec.png',dpi=300, transparent=True, bbox_inches='tight')
plt.savefig(os.path.join(savefigdir, 'spec_str_bsl'),dpi=dpi, transparent=True, bbox_inches='tight')
