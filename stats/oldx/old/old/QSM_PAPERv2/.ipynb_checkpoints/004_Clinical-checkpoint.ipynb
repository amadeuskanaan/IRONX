# %%
# %matplotlib inline
import os 
import sys
import numpy as np
from numpy import mean, std
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import ttest_rel, ttest_ind, mannwhitneyu, wilcoxon, spearmanr,pearsonr, fisher_exact,kstest
from scipy.stats import ks_2samp, kstest, anderson, anderson_ksamp, levene
from statsmodels.sandbox.stats.multicomp import fdrcorrection0
from sklearn import preprocessing
import statsmodels.api as sm
pd.options.display.max_columns = 999
import statsmodels.formula.api as smf
import scipy.stats as ss 
import math 
from outliers import smirnov_grubbs as grubbs

plt.rcParams['font.family'] = 'Myriad Pro'
sns.set_style('white')

datadir       = '/Users/kanaan/Google Drive/TS-EUROTRAIN/RESULTS_QSM/Oct_19'
mrsdir        = '/Users/kanaan/SCR/Dataframes_20150820/REVISION_DF'
clinical_dir  = '/Users/kanaan/SCR/Dataframes_20150820/DF_clinical/'
save_fig_dir  = '/Users/kanaan/Google Drive/TS-EUROTRAIN/Papers/2016_QSM_paper/Figures_python'

measures = ['Puta', 'Caud', 'Thal', 'Pall',
            'SN', 'STN', 'RN',  'GPi' , 'GPe',  
            'DN','Hipp', 'Accu', 'Amyg', 
            'STR_cMOT', 'STR_rMOT','AAN_PPN','AAN_VTA',
            'BrainStem', 'BasalGanglia', 'ALL_NUCLEI'
            ]
clinical = ['CLN_BAI','CLN_BAI_clinically_significant',
            'CLN_BAI_severity','CLN_BDI12','CLN_BDI12_clinically_significant',
            'CLN_BDI12_severity','CLN_Birthday','CLN_CAARS_Score_ADHS_Symptoms_Total_Cat_G_T_Score',
            'CLN_DSM4_ADHD_Score','CLN_DSM4_Attention','CLN_DSM4_Hyperactivity',
            'CLN_DSM4_clinically_significant_ADHD','CLN_Diag_ADHD','CLN_Diag_AQ',
            'CLN_Diag_Anxiety','CLN_Diag_Depression','CLN_Diag_OCD','CLN_Ferritin',
            'CLN_MADRS','CLN_MADRS_clinically_significant','CLN_MADRS_severity',
            'CLN_OCIR_Control','CLN_OCIR_Control_clinically_significant','CLN_OCIR_Hoarding',
            'CLN_OCIR_Hoarding_clinically_significant','CLN_OCIR_Mental_Neutralisation',
            'CLN_OCIR_Mental_Neutralisation_clinically_significant','CLN_OCIR_Thoughts',
            'CLN_OCIR_Thoughts_clinically_significant','CLN_OCIR_Tidy','CLN_OCIR_Tidy_clinically_significant',
            'CLN_OCIR_WASH_clinically_significant','CLN_OCIR_Wash',#'CLN_OCIR_total score',
            'CLN_RVTRS',
            'CLN_THC_occasional',
            'CLN_YBOCS_Totalscore_Items_1to10',
            'CLN_YBOCS_Totalscore_Items_1to10_clinically_significant','CLN_YBOCS_compulsions',
            'CLN_YBOCS_compulsions_sig','CLN_YBOCS_obsessions','CLN_YBOCS_obsessions_sig',
            'CLN_YGTSS_Motoric_Score','CLN_YGTSS_Total_Score_incl_Impairment',
            'CLN_YGTSS_Total_Tic_Score','CLN_YGTSS_Vocal_Score','CLN_medication',
            'CLN_puts','CLN_puts_meaning','CLN_qol_scale',
            'CLN_qol_score',]

drop_c = ['WSKT','SC1T','LL5T', 'GSAT'] 
# WSKT,SC1T,LL5T Young Females scanned extra for MRS review. 
# GSAT removed since HSPP female removed 
drop_p = ['AA8P', 'RA9P', 'STDP','NL2P','HSPP', 'DF2P'] 
# AA8P motion outliers via mehalonobis distance for Quality metrics 
# rest – mehalonobis distance for SN,STN,Puta

# %%
def get_all_dfs(img, population, study_id, trt=False):
    quant = 'median'
    QSM = pd.read_csv(os.path.join(datadir, '%s_%s_%s_%s.csv'%(img, quant, population, study_id)),index_col = 0)
    QSM['Gender']  = QSM['Gender'].map({' F': 1, ' M': 0})
    
    CLN = pd.read_csv(os.path.join(clinical_dir, 'clinical_%s_a.csv'%(population)), index_col=0)
    CLN.columns = ['CLN_' + str(col) for col in CLN.columns]    

    def get_mrs(vox):
        if trt == False:
            df = pd.read_csv(os.path.join(mrsdir, 'moco_df_%s_%s_%s.csv'%(vox, population, study_id)),index_col = 0)
        elif trt == True:
            df = pd.read_csv(os.path.join(mrsdir, 'moco_df_%s_%s_trt_%s.csv'%(vox, population, study_id)),index_col = 0)
        df.columns = ['%s_'%vox + str(col) for col in df.columns]
        return df
    df = pd.concat([QSM, get_mrs('STR'), CLN], axis=1, join_axes=[QSM.index])
    df['L_BrainStem']    = (df['L_STN'] + df['L_SN'] +  df['L_RN']) / 3
    df['R_BrainStem']    = (df['R_STN'] + df['R_SN'] +  df['R_RN']) / 3
    df['L_BasalGanglia'] = (df['L_Puta'] + df['L_Caud'] +  df['L_Pall'] +  df['L_Accu']) / 4
    df['R_BasalGanglia'] = (df['R_Puta'] + df['R_Caud'] +  df['R_Pall'] +  df['R_Accu']) / 4
    df['ALL_NUCLEI'] = (df['BrainStem'] + df['BasalGanglia']) / 2
    df['L_ALL_NUCLEI'] = (df['L_BrainStem'] + df['L_BasalGanglia']) / 2
    df['R_ALL_NUCLEI'] = (df['R_BrainStem'] + df['R_BasalGanglia']) / 2
    df['ALL_NUCLEI'] = (df['BrainStem'] + df['BasalGanglia']) / 2
    return df

controls_a = get_all_dfs('QSM', 'controls', 'a').drop(drop_c, axis = 0) 
patients_a = get_all_dfs('QSM', 'patients', 'a').drop(drop_p, axis = 0)
controls_b = get_all_dfs('QSM', 'controls', 'b', trt=True)#.drop(drop_c, axis = 0) 
patients_b = get_all_dfs('QSM', 'patients', 'b', trt=True)#.drop(drop_p, axis = 0) 

controls_a['Population'] = 0
patients_a['Population'] = 1
    
controls_b.index = controls_b.index + 'b'
patients_b.index = patients_b.index + 'b'

DF_ALL =pd.concat([controls_a, patients_a], axis=0)

# %%
def grubbs_outliers(df, measure, alpha = 0.15):
    from outliers import smirnov_grubbs as grubbs
    return [str(i) for i in df.index if i not in grubbs.test(df[measure], alpha).index] 

def gESD_outliers(df, measure, maxOLs =10, alpha = 0.05):
    from PyAstronomy import pyasl
    index = pyasl.generalizedESD(df[measure],maxOLs = maxOLs, alpha =alpha, fullOutput=True)[1]
    return [df.index[i] for i in index] 

def plot_partial_correlation(data, x, y, regressors = None, color = None, annotate = None, fig_name = None, 
                             dpi = 100, labels = True, jitter = None,fit_reg=True, scatter=1,
                             plot_marg = 1, xlim = None, ylim = None):
    
    regressors_columns = [data[regressor] for regressor in regressors]
    df_reg = pd.concat(regressors_columns, axis = 1).dropna(axis=0) 
    df = pd.concat([df_reg, data[x], data[y]], axis=1).dropna()
    
    # inititlize grid and plot regression and margins 
    grid = sns.JointGrid(x, y, data=df)#,xlim=xlim, ylim=ylim)#, size=size, ratio=ratio, space=space, #) 
    
    if plot_marg:
        grid.plot_marginals(sns.distplot, color = color, hist=False, kde = True, rug = 0, kde_kws={'shade':True})  
    
    grid.plot_joint(sns.regplot, fit_reg=fit_reg, scatter= scatter, color = color, x_partial = df[regressors], y_jitter = jitter)
    if labels:
        grid.set_axis_labels(x, y, fontsize= 15, weight='bold', color='blue', labelpad=10)
    else:
        grid.set_axis_labels(None,None)
        
    ## calculate regression parameters 
    
    formula = [ '%s ~ %s'%(y,x) + ' + %s'%regressor for regressor in regressors][0]
    model   = smf.ols(formula=formula, data= df)
    result = model.fit() 
    p_val  = np.round(result.pvalues[1], 3)
    pcor   = math.copysign(np.round(np.sqrt(result.rsquared), 3) , result.params[1])
    if annotate:
        plt.annotate('R=%s, P=%s' %(pcor, p_val), xy = annotate, fontsize = 13,  color='r')
    if fig_name:
        plt.savefig(os.path.join(save_fig_dir, fig_name), dpi = dpi, bbox_inches='tight', transparent = True)
    return result

def plot_joint(df,m1,m2, drop = []):
    DF  = pd.DataFrame([df[m1] , df[m2]] ).T.dropna()
    sns.jointplot(x=m1, y=m2, data=DF.drop(drop, axis = 0), kind = 'reg')

# %%
def plt_resid(data, x, y, regressors = None, color = None, annotate = None, fig_name = None, 
              dpi = 100, labels = True, jitter = None,fit_reg=True, scatter=1,
              plot_marg = 1, xlim = None, ylim = None):

    def get_resid(df,measure, regressors):
        formula = [ '%s ~ %s'%(measure,regressors[0])  + ' + %s'%regressor for regressor in regressors[1:]][0]#  
        res= smf.ols(formula=formula, data= df).fit().resid
        return res
    
    x_resid = get_resid(data,x, regressorsx)
    y_resid = get_resid(data,y, regressorsx)
    df = pd.concat([x_resid, y_resid], axis=1).dropna()
    df.columns = [x,y]
    
    grid = sns.JointGrid(x, y, data=df,xlim=xlim, ylim=ylim)#, size=size, ratio=ratio, space=space, #) 
    
    if plot_marg:
        grid.plot_marginals(sns.distplot, color = color, hist=False, kde = True, rug = 0, kde_kws={'shade':True})  
    
    grid.plot_joint(sns.regplot, fit_reg=fit_reg, scatter= scatter, color = color, y_jitter = jitter)
    if labels:
        grid.set_axis_labels(x, y, fontsize= 15, weight='bold', color='blue', labelpad=10)
    else:
        grid.set_axis_labels(None,None)
    formula = [ '%s ~ %s'%(y,x)][0]
    model   = smf.ols(formula=formula, data= df)
    result = model.fit() 
    p_val  = np.round(result.pvalues[1], 3)
    pcor   = math.copysign(np.round(np.sqrt(result.rsquared), 3) , result.params[1])
    if annotate:
        plt.annotate('R=%s, P=%s' %(pcor, p_val), xy = annotate, fontsize = 13,  color='r')

    if fig_name:
        plt.savefig(os.path.join(save_fig_dir, fig_name), dpi = dpi, bbox_inches='tight', transparent = True)

# %%
def return_correlation_tables(data, regressors, metabolites, clinical_measures):
    
    print 'Bonferroni threshold =',  0.05/ (len(clinical_measures) * len(metabolites) )
    
    regressors_columns = [data[regressor] for regressor in regressors]
    df_reg = pd.concat(regressors_columns, axis = 1).dropna(axis=0) 
    
    
    def make_multiple_reg(data, x, y):
        #print np.log((data[y] + 10))
        x_out = gESD_outliers(data, x)
        y_out = gESD_outliers(data, y)
        #print x, x_out 
        #print y, y_out
        df = pd.concat([df_reg, data[x].drop(x_out,axis=0), data[y].drop(y_out,axis=0) ], axis=1)
        #df = df.dropna()
        #df[x] = (df[x] - np.mean(dfx[x]) )/  np.std(dfx[x])
        
        formula = [ '%s ~ %s'%(y,x) + ' + %s'%regressor for regressor in regressors][0]
        model   = smf.ols(formula=formula, data= df)
        result = model.fit() 
        p_val  = np.round(result.pvalues[1], 3)
        pcor   = math.copysign(np.round(np.sqrt(result.rsquared), 3) , result.params[1])
        
        if p_val < 0.06:
            print x, y, 'P_val=', p_val, 'R =', pcor
        return pcor, p_val
    
    stats_df = pd.DataFrame(index = clinical_measures,  columns=metabolites)   
    
    for clinical in clinical_measures:
        for metabolite in metabolites:
            p_cor, p_val = make_multiple_reg(data,  clinical, metabolite )
            #p_cor, p_val = spearmanr(data[clinical], data[metabolite])
            stats_df.loc['%s'%clinical][metabolite] = np.round(p_cor,3)
            stats_df.loc['%s'%clinical][metabolite] = np.round(p_val,3)
    return stats_df

# %%
clinical = ['CLN_RVTRS','CLN_YGTSS_Motoric_Score','CLN_YGTSS_Total_Score_incl_Impairment',
            'CLN_YGTSS_Total_Tic_Score','CLN_YGTSS_Vocal_Score',
           # 'CLN_puts','CLN_qol_score'
           ]

measures = ['Puta', 'Caud', 'Thal', 'Pall', 
            'SN', 'STN', 'RN',  'GPi' , 'GPe',  
            'DN','Hipp', 'Accu', 'Amyg', 
            'STR_cMOT', 'STR_rMOT','AAN_PPN','AAN_VTA',
            'BrainStem','BasalGanglia', 'ALL_NUCLEI', 
           ]

#measures = ['L_' + str(i) for i in measures]    
measures.append('CLN_Ferritin')
res = return_correlation_tables(patients_a, ['Age', 'Gender', 'QI1_MAG'], measures, clinical)
res
# Out:
# Bonferroni threshold = 0.00047619047619
# CLN_RVTRS Caud P_val= 0.045 R = 0.519
# CLN_RVTRS AAN_VTA P_val= 0.01 R = 0.588
# CLN_YGTSS_Motoric_Score Accu P_val= 0.022 R = -0.656
# CLN_YGTSS_Vocal_Score Amyg P_val= 0.043 R = -0.471
#                                         Puta   Caud   Thal   Pall     SN  \
# CLN_RVTRS                              0.884  0.122  0.805  0.491   0.91
# CLN_YGTSS_Motoric_Score                0.801  0.626   0.66  0.488  0.726
# CLN_YGTSS_Total_Score_incl_Impairment  0.323  0.291  0.964  0.903  0.972
# CLN_YGTSS_Total_Tic_Score              0.672  0.688  0.584  0.863  0.581
# CLN_YGTSS_Vocal_Score                  0.853  0.833  0.587  0.869  0.261
#
#                                          STN     RN    GPi    GPe     DN  \
# CLN_RVTRS                              0.608  0.188  0.819  0.353  0.403
# CLN_YGTSS_Motoric_Score                0.583  0.694  0.284  0.628   0.87
# CLN_YGTSS_Total_Score_incl_Impairment  0.323  0.998  0.867  0.713  0.722
# CLN_YGTSS_Total_Tic_Score               0.29  0.468  0.572  0.873   0.36
# CLN_YGTSS_Vocal_Score                   0.33  0.441  0.986  0.556  0.106
#
#                                         Hipp   Accu   Amyg STR_cMOT STR_rMOT  \
# CLN_RVTRS                              0.908  0.402  0.459    0.587    0.372
# CLN_YGTSS_Motoric_Score                0.718  0.299  0.319     0.53    0.621
# CLN_YGTSS_Total_Score_incl_Impairment  0.365  0.899  0.148    0.787    0.986
# CLN_YGTSS_Total_Tic_Score              0.283   0.92   0.04    0.685    0.317
# CLN_YGTSS_Vocal_Score                  0.221  0.962  0.036    0.712    0.227
#
#                                       AAN_PPN AAN_VTA BrainStem BasalGanglia  \
# CLN_RVTRS                               0.664   0.004     0.494        0.714
# CLN_YGTSS_Motoric_Score                  0.47   0.846     0.741        0.651
# CLN_YGTSS_Total_Score_incl_Impairment   0.291       1     0.511        0.738
# CLN_YGTSS_Total_Tic_Score               0.737   0.692     0.251        0.922
# CLN_YGTSS_Vocal_Score                   0.809   0.724     0.164        0.877
#
#                                       ALL_NUCLEI CLN_Ferritin
# CLN_RVTRS                                  0.938        0.509
# CLN_YGTSS_Motoric_Score                    0.811        0.059
# CLN_YGTSS_Total_Score_incl_Impairment      0.493        0.469
# CLN_YGTSS_Total_Tic_Score                  0.298         0.11
# CLN_YGTSS_Vocal_Score                      0.237        0.209

# %%
clinical = ['CLN_RVTRS','CLN_YGTSS_Motoric_Score','CLN_YGTSS_Total_Score_incl_Impairment',
            'CLN_YGTSS_Total_Tic_Score','CLN_YGTSS_Vocal_Score',
           # 'CLN_puts','CLN_qol_score'
           ]

measures = ['Puta', 'Caud', 'Thal', 'Pall', 
            'SN', 'STN', 'RN',  'GPi' , 'GPe',  
            'DN','Hipp', 'Accu', 'Amyg', 
            'STR_cMOT', 'STR_rMOT','AAN_PPN','AAN_VTA',
            'BrainStem','BasalGanglia', 'ALL_NUCLEI', 
           ]

#measures = ['L_' + str(i) for i in measures]    
measures.append('CLN_Ferritin')
res = return_correlation_tables(patients_a, ['Age', 'Gender', 'QI1_MAG'], measures, clinical)
res
# Out:
# Bonferroni threshold = 0.00047619047619
# CLN_RVTRS Caud P_val= 0.045 R = 0.519
# CLN_RVTRS AAN_VTA P_val= 0.01 R = 0.588
# CLN_YGTSS_Motoric_Score Accu P_val= 0.022 R = -0.656
# CLN_YGTSS_Vocal_Score Amyg P_val= 0.043 R = -0.471
#                                         Puta   Caud   Thal   Pall     SN  \
# CLN_RVTRS                                0.5  0.045  0.847  0.297   0.22
# CLN_YGTSS_Motoric_Score                0.991  0.413  0.472  0.337  0.509
# CLN_YGTSS_Total_Score_incl_Impairment   0.34  0.447  0.615  0.956  0.838
# CLN_YGTSS_Total_Tic_Score              0.833  0.796   0.38  0.804  0.721
# CLN_YGTSS_Vocal_Score                  0.761  0.874  0.416  0.791  0.329
#
#                                          STN     RN    GPi    GPe     DN  \
# CLN_RVTRS                              0.666  0.313  0.567  0.291  0.612
# CLN_YGTSS_Motoric_Score                0.894  0.621  0.137  0.531  0.677
# CLN_YGTSS_Total_Score_incl_Impairment  0.302  0.763  0.409    0.8  0.622
# CLN_YGTSS_Total_Tic_Score              0.455  0.667  0.429  0.828  0.412
# CLN_YGTSS_Vocal_Score                  0.229   0.33  0.844  0.459  0.128
#
#                                         Hipp   Accu   Amyg STR_cMOT STR_rMOT  \
# CLN_RVTRS                              0.655  0.543   0.74    0.721    0.581
# CLN_YGTSS_Motoric_Score                0.353  0.022  0.323    0.436    0.734
# CLN_YGTSS_Total_Score_incl_Impairment  0.228  0.107  0.128    0.755    0.866
# CLN_YGTSS_Total_Tic_Score              0.237  0.186  0.069    0.716    0.553
# CLN_YGTSS_Vocal_Score                  0.263  0.545  0.043    0.983    0.516
#
#                                       AAN_PPN AAN_VTA BrainStem BasalGanglia  \
# CLN_RVTRS                               0.872    0.01     0.899        0.222
# CLN_YGTSS_Motoric_Score                 0.158    0.75     0.552        0.655
# CLN_YGTSS_Total_Score_incl_Impairment   0.293   0.609     0.496        0.713
# CLN_YGTSS_Total_Tic_Score               0.598   0.409     0.489        0.896
# CLN_YGTSS_Vocal_Score                   0.893   0.314     0.148        0.917
#
#                                       ALL_NUCLEI CLN_Ferritin
# CLN_RVTRS                                  0.683        0.879
# CLN_YGTSS_Motoric_Score                    0.537        0.645
# CLN_YGTSS_Total_Score_incl_Impairment      0.516        0.864
# CLN_YGTSS_Total_Tic_Score                  0.647        0.934
# CLN_YGTSS_Vocal_Score                      0.272        0.678

# %%
df = patients_a#pd.concat([patients_a, patients_b], axis=0)
x = 'CLN_YGTSS_Motoric_Score'
y = 'Accu'
#plot_joint(df,x,y, drop = [])
plot_partial_correlation(df, x, y, regressors = ['Age', 'Gender', 'QI1_MAG'], color = 'r', 
                         annotate = (17,0.017), fig_name = None, 
                         dpi = 100, labels = True, jitter = None,fit_reg=True, scatter=1, plot_marg = 1)

# %%
df = patients_a#pd.concat([patients_a, patients_b], axis=0)
y = 'CLN_YGTSS_Motoric_Score'
x = 'Accu'
#plot_joint(df,x,y, drop = [])
plot_partial_correlation(df, x, y, regressors = ['Age', 'Gender', 'QI1_MAG'], color = 'r', 
                         annotate = (0,0), fig_name = None, 
                         dpi = 100, labels = True, jitter = None,fit_reg=True, scatter=1, plot_marg = 1)

# %%
df = patients_a#pd.concat([patients_a, patients_b], axis=0)
x = 'BrainStem'
y = 'CLN_qol_score'
#plot_joint(df,x,y, drop = [])
plot_partial_correlation(df, x, y, regressors = ['Age', 'Gender'], color = 'r', 
                         annotate = (0.07,110), fig_name = None, 
                         dpi = 100, labels = True, jitter = None,fit_reg=True, scatter=1, plot_marg = 1)

# %%
sns.jointplot(df['CLN_YGTSS_Total_Tic_Score'],df['BrainStem'])

# %%
sns.jointplot(df['CLN_YGTSS_Total_Tic_Score'], np.log10(df['STN']), kind = 'reg')

# %%
sns.lmplot('CLN_YGTSS_Total_Tic_Score', 'ALL_NUCLEI',df,  logx=1)
# Out:
# /Users/kanaan/anaconda/lib/python2.7/site-packages/seaborn/linearmodels.py:267: RuntimeWarning: divide by zero encountered in log
#   grid = np.c_[np.ones(len(grid)), np.log(grid)]

# %%
def get_polfit_r(X,y,d):
    coef = np.polyfit(X,y,d)
    results = {}
    results['polynomial'] = coef.tolist()
    p = np.poly1d(coef)
    yhat = p(X)
    ybar = np.sum(y)/len(y)
    ssreg = np.sum((yhat-ybar)**2)
    sstot = np.sum((y - ybar)**2)
    ssreg / sstot
    results['determination'] = ssreg / sstot
    r = np.sqrt(results['determination'])
    N = len(VV.index)
    t = r/(np.sqrt((1-r**2) / (N-2)))
    p = ss.t.sf(t,df= (N-2) ) * 2
    return r, p

# %%
m1 = 'L_GPi'
m2 = 'CLN_YGTSS_Motoric_Score'
XX = patients_a.drop(['SA5U', 'DF2P'])
VV = pd.DataFrame([XX[m1],XX[m2] ]).T.dropna()

order= 1
print get_polfit_r(X = VV[m1], y = VV[m2], d=order)
sns.lmplot(x=m1, y=m2, data=VV,order=order, truncate= 0, ci = 95)
#plt.xlim(-0.01, 0.14)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-b245d0866dde> in <module>()
#       1 m1 = 'L_GPi'
#       2 m2 = 'CLN_YGTSS_Motoric_Score'
# ----> 3 XX = patients_a.drop(['SA5U', 'DF2P'])
#       4 VV = pd.DataFrame([XX[m1],XX[m2] ]).T.dropna()
#       5
#
# /Users/kanaan/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in drop(self, labels, axis, level, inplace, errors)
#    1905                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1906             else:
# -> 1907                 new_axis = axis.drop(labels, errors=errors)
#    1908             dropped = self.reindex(**{axis_name: new_axis})
#    1909             try:
#
# /Users/kanaan/anaconda/lib/python2.7/site-packages/pandas/indexes/base.pyc in drop(self, labels, errors)
#    3260             if errors != 'ignore':
#    3261                 raise ValueError('labels %s not contained in axis' %
# -> 3262                                  labels[mask])
#    3263             indexer = indexer[~mask]
#    3264         return self.delete(indexer)
#
# ValueError: labels ['DF2P'] not contained in axis

# %%
m1 = 'CLN_YGTSS_Motoric_Score'
m2 = 'L_GPi'
x = df[m1].dropna()
y = df[m2]

# %%
dfx = pd.concat([x,y],axis = 1).dropna()
dfx[m1] = (dfx[m1] - np.mean(dfx[m1]) )/  np.std(dfx[m1])

# %%
sns.jointplot(dfx[m1],dfx[m2])

# %%
#preprocessing.scale(dfx['CLN_RVTRS'])

# %%
def return_correlation_tables(data, regressors, metabolites, clinical_measures):
    
    print 'Bonferroni threshold =',  0.05/ (len(clinical_measures) * len(metabolites) )
    
    regressors_columns = [data[regressor] for regressor in regressors]
    df_reg = pd.concat(regressors_columns, axis = 1).dropna(axis=0) 
    
    
    def make_multiple_reg(data, x, y):
        #print np.log((data[y] + 10))
        x_out = gESD_outliers(data, x)
        y_out = gESD_outliers(data, y)
        #print x, x_out 
        #print y, y_out
        df = pd.concat([df_reg, data[x].drop(x_out,axis=0), data[y].drop(y_out,axis=0) ], axis=1)
        df = df.dropna()
        df[x] = (df[x] - np.mean(df[x]) )/  np.std(df[x])
        
        formula = [ '%s ~ %s'%(y,x) + ' + %s'%regressor for regressor in regressors][0]
        model   = smf.ols(formula=formula, data= df)
        result = model.fit() 
        p_val  = np.round(result.pvalues[1], 3)
        pcor   = math.copysign(np.round(np.sqrt(result.rsquared), 3) , result.params[1])
        
        if p_val < 0.05:
            print x, y, 'P_val=', p_val, 'R =', pcor
        return pcor, p_val
    
    stats_df = pd.DataFrame(index = clinical_measures,  columns=metabolites)   
    
    for clinical in clinical_measures:
        for metabolite in metabolites:
            p_cor, p_val = make_multiple_reg(data,  clinical, metabolite )
            p_cor, p_val = spearmanr(data[clinical], data[metabolite])
            stats_df.loc['%s'%clinical][metabolite] = np.round(p_cor,3)
            #stats_df.loc['%s'%clinical][metabolite] = np.round(p_val,3)
    return stats_df

# %%
clinical = ['CLN_RVTRS','CLN_YGTSS_Motoric_Score','CLN_YGTSS_Total_Score_incl_Impairment',
            'CLN_YGTSS_Total_Tic_Score','CLN_YGTSS_Vocal_Score',
            'CLN_puts','CLN_qol_score', ]

measures = ['Puta', 'Caud', 'Thal',
            'SN', 'STN', 'RN',  'GPi' , 'GPe',  
            'DN','Hipp', 'Accu', 'Amyg', 
            #'STR_cMOT', 'STR_rMOT','AAN_PPN','AAN_VTA',
            'BrainStem','BasalGanglia', 'ALL_NUCLEI', 'CLN_Ferritin'
           ]

#measures = ['L_' + str(i) for i in measures]    
measures.append('CLN_Ferritin')
res = return_correlation_tables(patients_a.drop(['SA5U'], axis =0), ['Age', 'Gender'], measures, clinical)
res
# Out:
# Bonferroni threshold = 0.000420168067227
# CLN_RVTRS Caud P_val= 0.043 R = 0.534
# CLN_RVTRS CLN_Ferritin P_val= 0.042 R = 0.614
# CLN_RVTRS CLN_Ferritin P_val= 0.042 R = 0.614
# CLN_YGTSS_Motoric_Score Accu P_val= 0.03 R = -0.657
#                                         Puta   Caud   Thal     SN    STN  \
# CLN_RVTRS                              0.599  0.043  0.971  0.249  0.732
# CLN_YGTSS_Motoric_Score                 0.98  0.428  0.484  0.522  0.888
# CLN_YGTSS_Total_Score_incl_Impairment  0.371  0.447  0.578  0.853  0.291
# CLN_YGTSS_Total_Tic_Score              0.932  0.766  0.306   0.75  0.404
# CLN_YGTSS_Vocal_Score                  0.912  0.926  0.293  0.356  0.171
# CLN_puts                               0.224  0.181  0.505  0.388  0.472
# CLN_qol_score                          0.357  0.679  0.942  0.187  0.301
#
#                                           RN    GPi    GPe     DN   Hipp  \
# CLN_RVTRS                              0.304  0.671   0.36  0.625  0.697
# CLN_YGTSS_Motoric_Score                0.632  0.145  0.545  0.686  0.367
# CLN_YGTSS_Total_Score_incl_Impairment  0.774  0.383  0.839  0.634  0.232
# CLN_YGTSS_Total_Tic_Score              0.682  0.356  0.919  0.425  0.226
# CLN_YGTSS_Vocal_Score                  0.341  0.691  0.571  0.131  0.233
# CLN_puts                               0.472  0.627  0.174  0.329   0.26
# CLN_qol_score                          0.635  0.145  0.459  0.949  0.599
#
#                                         Accu   Amyg BrainStem BasalGanglia  \
# CLN_RVTRS                              0.582  0.864     0.898         0.28
# CLN_YGTSS_Motoric_Score                 0.03  0.313     0.562        0.668
# CLN_YGTSS_Total_Score_incl_Impairment  0.128  0.145     0.503        0.751
# CLN_YGTSS_Total_Tic_Score              0.207  0.095     0.486        0.807
# CLN_YGTSS_Vocal_Score                  0.561   0.07     0.139        0.942
# CLN_puts                               0.161  0.317     0.294        0.196
# CLN_qol_score                          0.159  0.128     0.417        0.251
#
#                                       ALL_NUCLEI CLN_Ferritin CLN_Ferritin
# CLN_RVTRS                                  0.731        0.042        0.042
# CLN_YGTSS_Motoric_Score                     0.55        0.502        0.502
# CLN_YGTSS_Total_Score_incl_Impairment      0.535        0.318        0.318
# CLN_YGTSS_Total_Tic_Score                  0.675        0.326        0.326
# CLN_YGTSS_Vocal_Score                      0.294        0.358        0.358
# CLN_puts                                   0.197        0.911        0.911
# CLN_qol_score                              0.292        0.776        0.776

# %%
sns.jointplot( 'CLN_YGTSS_Motoric_Score', 'Puta', patients_a.drop(['SA5U'], axis =0), kind = 'reg')

# %%
df = patients_a#pd.concat([patients_a, patients_b], axis=0)
x = 'CLN_YGTSS_Motoric_Score'
y = 'L_GPi'
#plot_joint(df,x,y, drop = [])
plot_partial_correlation(df, x, y, regressors = ['Age', 'Gender'], color = 'r', 
                         annotate = (17,0.17), fig_name = None, 
                         dpi = 100, labels = True, jitter = None,fit_reg=True, scatter=1, plot_marg = 1)

# %%
patients_a.CLN_Ferritin
# Out:
# BE9P     86.07
# HJEP     76.43
# BATP     50.67
# LA9P    126.10
# RMJP       NaN
# LT5P    120.10
# CM5P     42.69
# CF1P     20.51
# SM6U    124.60
# RL7P     48.19
# SGKP       NaN
# HHQP    182.40
# SA5U    562.80
# THCP    117.10
# PC5P     31.87
# SBQP       NaN
# NT6P     51.63
# TT3P       NaN
# CB4P       NaN
# YU1P       NaN
# SULP    183.80
# KDDP     74.30
# Name: CLN_Ferritin, dtype: float64

# %%
CLN = pd.read_csv(os.path.join(clinical_dir, 'clinical_%s_a.csv'%('patients')), index_col=0).drop(['SA5U', 'FL3P', 'DF2P'], axis = 0)
CLNc = pd.read_csv(os.path.join(clinical_dir, 'clinical_%s_a.csv'%('controls')), index_col=0).drop([], axis = 0)

# %%
len(CLNc.Ferritin.dropna())
# Out:
# 30

# %%
CLN.Ferritin.dropna()
# Out:
# TSEP     95.13
# FMEP    159.90
# WO2P    268.20
# RSIP    145.30
# LJ9P    104.50
# HRPP    103.90
# HMXP     56.47
# EW3P    260.70
# GSAP     88.90
# HHQP    182.40
# HJEP     76.43
# LA9P    126.10
# LT5P    120.10
# KDDP     74.30
# EB2P     73.03
# THCP    117.10
# PC5P     31.87
# HSPP     37.98
# KHRP     57.59
# BE9P     86.07
# CM5P     42.69
# SULP    183.80
# WJAP     82.23
# RRDP    207.10
# NT6P     51.63
# NF??    165.60
# CF1P     20.51
# SM6U    124.60
# RL7P     48.19
# BATP     50.67
# NL2P     59.90
# AA8P    156.70
# STDP     98.63
# Name: Ferritin, dtype: float64

# %%
clinical = ['CLN_RVTRS','CLN_YGTSS_Motoric_Score','CLN_YGTSS_Total_Score_incl_Impairment',
            'CLN_YGTSS_Total_Tic_Score','CLN_YGTSS_Vocal_Score',
            'CLN_puts','CLN_qol_score']

sns.jointplot( 'Ferritin', 'YGTSS_Total_Tic_Score', CLN, kind = 'reg')

# %%
CLN.Ferritin
# Out:
# TSEP     95.13
# FMEP    159.90
# WO2P    268.20
# RSIP    145.30
# LJ9P    104.50
# HRPP    103.90
# HMXP     56.47
# EW3P    260.70
# GSAP     88.90
# HHQP    182.40
# HJEP     76.43
# LA9P    126.10
# LT5P    120.10
# KDDP     74.30
# EB2P     73.03
# THCP    117.10
# PNXX       NaN
# PC5P     31.87
# HSPP     37.98
# KHRP     57.59
# BE9P     86.07
# CM5P     42.69
# SULP    183.80
# WJAP     82.23
# RRDP    207.10
# NT6P     51.63
# NF??    165.60
# CF1P     20.51
# SM6U    124.60
# RL7P     48.19
# BATP     50.67
# NL2P     59.90
# AA8P    156.70
# STDP     98.63
# SBQP       NaN
# RMJP       NaN
# SGKP       NaN
# YU1P       NaN
# CB4P       NaN
# TT3P       NaN
# RA9P       NaN
# NaN        NaN
# NaN        NaN
# Name: Ferritin, dtype: float64

# %%
CLN.drop(['SA5U'],axis=0)
# Out:
#        Age  Birthday  YGTSS_Total_Tic_Score  YGTSS_Motoric_Score  \
# TSEP  18.0   1/28/90                   11.0                  9.0
# FMEP  34.0    1/3/80                   26.0                 13.0
# WO2P  48.0    5/9/65                   31.0                 18.0
# RSIP  57.0  12/31/57                   23.0                 12.0
# LJ9P  36.0  12/21/78                   28.0                 19.0
# HRPP  45.0   6/18/69                   15.0                  9.0
# HMXP  23.0   8/16/90                   28.0                 14.0
# EW3P  39.0  11/25/74                   22.0                 11.0
# GSAP  41.0   12/2/72                   16.0                  9.0
# FL3P  54.0   9/23/60                   25.0                  9.0
# HHQP  36.0   6/20/78                   28.0                 17.0
# HJEP  21.0   9/15/92                   14.0                 14.0
# LA9P  22.0   9/23/91                   15.0                 10.0
# LT5P  27.0  10/20/86                   26.0                 16.0
# KDDP  53.0    6/8/61                   15.0                 13.0
# EB2P  32.0  11/12/81                   21.0                 12.0
# THCP  42.0   7/17/72                    9.0                  9.0
# PNXX  20.0   8/19/94                   13.0                  7.0
# PC5P  45.0   10/3/69                   12.0                 12.0
# HSPP  52.0    1/9/63                   25.0                 13.0
# KHRP  58.0  11/27/56                   28.0                 12.0
# BE9P  18.0    7/9/96                    3.0                  3.0
# DF2P  56.0   2/24/58                   32.0                 18.0
# CM5P  27.0  10/27/87                   12.0                 12.0
# SULP  51.0  12/12/62                   22.0                 14.0
# WJAP  56.0  10/27/58                   27.0                 13.0
# RRDP  45.0   6/17/69                   18.0                 15.0
# NT6P  49.0   6/10/65                   21.0                 18.0
# NF??  34.0   6/24/80                   38.0                 21.0
# CF1P  28.0   11/8/86                   28.0                 13.0
# SM6U  29.0   4/10/85                   27.0                 13.0
# RL7P  30.0   12/7/84                   20.0                  9.0
# BATP  22.0   8/31/92                   10.0                  5.0
# NL2P  54.0    2/2/61                   27.0                 13.0
# AA8P  50.0   10/2/64                   36.0                 19.0
# STDP  44.0    5/5/70                   34.0                 17.0
# SBQP  46.0    2/2/69                   24.0                 13.0
# RMJP  22.0   1/14/93                   39.0                 21.0
# SGKP  36.0   9/10/78                   15.0                 10.0
# YU1P  48.0    4/2/67                   37.0                 21.0
# CB4P  47.0   5/20/68                   14.0                 14.0
# TT3P  46.0   7/23/68                   26.0                 14.0
# RA9P  50.0   9/24/64                   21.0                 11.0
# NaN    NaN       NaN                    NaN                  NaN
# NaN    NaN       NaN                    NaN                  NaN
#
#       YGTSS_Vocal_Score  YGTSS_Total_Score_incl_Impairment DSM4_ADHD_Score  \
# TSEP                2.0                               21.0             9+7
# FMEP               13.0                               46.0             7+5
# WO2P               13.0                               71.0             6+2
# RSIP               11.0                               33.0             0+4
# LJ9P               19.0                               58.0             8+7
# HRPP                6.0                               35.0             0+0
# HMXP               14.0                               38.0             0+1
# EW3P               11.0                               32.0             6+8
# GSAP                7.0                               36.0             5+5
# FL3P               16.0                               45.0             8+4
# HHQP               11.0                               58.0             0+0
# HJEP                0.0                               71.0             6+6
# LA9P                5.0                               35.0             3+0
# LT5P               10.0                               56.0             5+4
# KDDP                2.0                               25.0             1+0
# EB2P                9.0                               61.0             7+4
# THCP                0.0                               29.0             0+1
# PNXX                6.0                               23.0             2+0
# PC5P                0.0                               22.0             0+2
# HSPP               12.0                               55.0             1+2
# KHRP               16.0                               68.0             5+6
# BE9P                0.0                                3.0             6+9
# DF2P               14.0                               72.0             8+2
# CM5P                0.0                               32.0             7+7
# SULP                8.0                               42.0             0+1
# WJAP               14.0                               67.0             9+2
# RRDP                3.0                               58.0             2+1
# NT6P                3.0                               51.0             4+3
# NF??               17.0                               78.0             8+9
# CF1P               15.0                               48.0             8+4
# SM6U               14.0                               57.0             4+0
# RL7P               11.0                               40.0             0+0
# BATP                5.0                               20.0             1+0
# NL2P               14.0                               67.0             5+2
# AA8P               17.0                               56.0             7+0
# STDP               17.0                               64.0             7+3
# SBQP               11.0                               34.0             6+8
# RMJP               18.0                               79.0             2+1
# SGKP                5.0                               25.0             0+0
# YU1P               16.0                               44.0             6+5
# CB4P                0.0                               34.0             5+0
# TT3P               12.0                               46.0             5+6
# RA9P               10.0                               51.0             5+3
# NaN                 NaN                                NaN             NaN
# NaN                 NaN                                NaN             NaN
#
#       DSM4_Attention  DSM4_Hyperactivity  \
# TSEP             1.0                 1.0
# FMEP             1.0                 0.0
# WO2P             1.0                 0.0
# RSIP             0.0                 0.0
# LJ9P             1.0                 1.0
# HRPP             0.0                 0.0
# HMXP             0.0                 0.0
# EW3P             1.0                 1.0
# GSAP             0.0                 0.0
# FL3P             1.0                 0.0
# HHQP             0.0                 0.0
# HJEP             1.0                 1.0
# LA9P             0.0                 0.0
# LT5P             0.0                 0.0
# KDDP             0.0                 0.0
# EB2P             1.0                 0.0
# THCP             0.0                 0.0
# PNXX             0.0                 0.0
# PC5P             0.0                 0.0
# HSPP             0.0                 0.0
# KHRP             0.0                 1.0
# BE9P             1.0                 1.0
# DF2P             1.0                 0.0
# CM5P             1.0                 1.0
# SULP             0.0                 0.0
# WJAP             1.0                 0.0
# RRDP             0.0                 0.0
# NT6P             0.0                 0.0
# NF??             1.0                 1.0
# CF1P             1.0                 0.0
# SM6U             0.0                 0.0
# RL7P             0.0                 0.0
# BATP             0.0                 0.0
# NL2P             0.0                 0.0
# AA8P             1.0                 0.0
# STDP             1.0                 0.0
# SBQP             1.0                 1.0
# RMJP             0.0                 0.0
# SGKP             0.0                 0.0
# YU1P             1.0                 0.0
# CB4P             0.0                 0.0
# TT3P             0.0                 1.0
# RA9P             0.0                 0.0
# NaN              NaN                 NaN
# NaN              NaN                 NaN
#
#       CAARS_Score_ADHS_Symptoms_Total_Cat_G_T_Score  \
# TSEP                                           90.0
# FMEP                                            NaN
# WO2P                                           70.0
# RSIP                                           55.0
# LJ9P                                           72.0
# HRPP                                           37.0
# HMXP                                           31.0
# EW3P                                           63.0
# GSAP                                           32.0
# FL3P                                           64.0
# HHQP                                           35.0
# HJEP                                           57.0
# LA9P                                           57.0
# LT5P                                           58.0
# KDDP                                           45.0
# EB2P                                           69.0
# THCP                                           42.0
# PNXX                                           38.0
# PC5P                                           35.0
# HSPP                                            NaN
# KHRP                                           52.0
# BE9P                                           51.0
# DF2P                                           58.0
# CM5P                                           54.0
# SULP                                           39.0
# WJAP                                            NaN
# RRDP                                           55.0
# NT6P                                           40.0
# NF??                                           72.0
# CF1P                                           44.0
# SM6U                                            NaN
# RL7P                                           45.0
# BATP                                           32.0
# NL2P                                           40.0
# AA8P                                            NaN
# STDP                                           63.0
# SBQP                                            NaN
# RMJP                                           40.0
# SGKP                                           49.0
# YU1P                                           58.0
# CB4P                                           81.0
# TT3P                                           60.0
# RA9P                                           64.0
# NaN                                             NaN
# NaN                                             NaN
#
#      DSM4_clinically_significant_ADHD  OCIR_Wash  \
# TSEP                              yes        0.0
# FMEP                       not usable        2.0
# WO2P                              yes        2.0
# RSIP                              no         1.0
# LJ9P                              yes        1.0
# HRPP                               no        0.0
# HMXP                               no        0.0
# EW3P                               no        0.0
# GSAP                               no        1.0
# FL3P                               no        0.0
# HHQP                               no        0.0
# HJEP                               no        0.0
# LA9P                               no        3.0
# LT5P                               no        0.0
# KDDP                               no        0.0
# EB2P                              yes        0.0
# THCP                               no        0.0
# PNXX                               no        0.0
# PC5P                               no        0.0
# HSPP                       not usable        1.0
# KHRP                               no        5.0
# BE9P                               no        2.0
# DF2P                               no        4.0
# CM5P                               no        0.0
# SULP                               no        1.0
# WJAP                       not usable        0.0
# RRDP                               no        0.0
# NT6P                               no        0.0
# NF??                              yes        0.0
# CF1P                               no        1.0
# SM6U                       not usable        0.0
# RL7P                               no        0.0
# BATP                               no        0.0
# NL2P                               no        1.0
# AA8P                       not usable        0.0
# STDP                               no        0.0
# SBQP                       not usable        0.0
# RMJP                               no        0.0
# SGKP                               no        0.0
# YU1P                               no        7.0
# CB4P                              yes        3.0
# TT3P                               no        0.0
# RA9P                               no        5.0
# NaN                               NaN        NaN
# NaN                               NaN        NaN
#
#      OCIR_WASH_clinically_significant  OCIR_Thoughts  \
# TSEP                               no            1.0
# FMEP                               no            1.0
# WO2P                               no            6.0
# RSIP                               no            1.0
# LJ9P                               no            8.0
# HRPP                               no            1.0
# HMXP                               no            0.0
# EW3P                               no            0.0
# GSAP                               no            1.0
# FL3P                               no            3.0
# HHQP                               no            0.0
# HJEP                               no            2.0
# LA9P                               no            8.0
# LT5P                               no            3.0
# KDDP                               no            0.0
# EB2P                               no            4.0
# THCP                               no            0.0
# PNXX                               no            2.0
# PC5P                               no            0.0
# HSPP                               no            6.0
# KHRP                              yes            5.0
# BE9P                               no            0.0
# DF2P                              yes            7.0
# CM5P                               no            4.0
# SULP                               no            0.0
# WJAP                               no           10.0
# RRDP                               no            3.0
# NT6P                               no            1.0
# NF??                               no            0.0
# CF1P                               no            1.0
# SM6U                               no            4.0
# RL7P                               no            4.0
# BATP                               no            0.0
# NL2P                               no            2.0
# AA8P                               no            5.0
# STDP                               no            4.0
# SBQP                               no            5.0
# RMJP                               no            0.0
# SGKP                               no            1.0
# YU1P                              yes           11.0
# CB4P                               no            5.0
# TT3P                               no            5.0
# RA9P                              yes            8.0
# NaN                               NaN            NaN
# NaN                               NaN            NaN
#
#      OCIR_Thoughts_clinically_significant  OCIR_Hoarding  \
# TSEP                                   no            0.0
# FMEP                                   no            0.0
# WO2P                                  yes            6.0
# RSIP                                   no            1.0
# LJ9P                                  yes            6.0
# HRPP                                   no            1.0
# HMXP                                   no            1.0
# EW3P                                   no            1.0
# GSAP                                   no            5.0
# FL3P                                   no            0.0
# HHQP                                   no            2.0
# HJEP                                   no            3.0
# LA9P                                  yes            1.0
# LT5P                                   no            0.0
# KDDP                                   no            0.0
# EB2P                                   no            4.0
# THCP                                   no            3.0
# PNXX                                   no            3.0
# PC5P                                   no            0.0
# HSPP                                  yes            1.0
# KHRP                                   no            2.0
# BE9P                                   no            3.0
# DF2P                                  yes           10.0
# CM5P                                   no            0.0
# SULP                                   no            7.0
# WJAP                                  yes           12.0
# RRDP                                   no            2.0
# NT6P                                   no            0.0
# NF??                                   no            1.0
# CF1P                                   no            2.0
# SM6U                                   no            4.0
# RL7P                                   no            0.0
# BATP                                   no            0.0
# NL2P                                   no            2.0
# AA8P                                   no            7.0
# STDP                                   no            4.0
# SBQP                                   no            3.0
# RMJP                                   no            0.0
# SGKP                                   no            3.0
# YU1P                                  yes            6.0
# CB4P                                   no            6.0
# TT3P                                   no            3.0
# RA9P                                  yes            2.0
# NaN                                   NaN            NaN
# NaN                                   NaN            NaN
#
#      OCIR_Hoarding_clinically_significant  OCIR_Tidy  \
# TSEP                                   no        3.0
# FMEP                                   no        1.0
# WO2P                                  yes        7.0
# RSIP                                   no        4.0
# LJ9P                                  yes        3.0
# HRPP                                   no        0.0
# HMXP                                   no        0.0
# EW3P                                   no        3.0
# GSAP                                   no        7.0
# FL3P                                   no        4.0
# HHQP                                   no        2.0
# HJEP                                   no        3.0
# LA9P                                   no        3.0
# LT5P                                   no        7.0
# KDDP                                   no        9.0
# EB2P                                   no        2.0
# THCP                                   no        3.0
# PNXX                                   no        4.0
# PC5P                                   no        2.0
# HSPP                                   no        6.0
# KHRP                                   no        6.0
# BE9P                                   no        3.0
# DF2P                                  yes       10.0
# CM5P                                   no        0.0
# SULP                                  yes        9.0
# WJAP                                  yes       12.0
# RRDP                                   no        7.0
# NT6P                                   no        3.0
# NF??                                   no        4.0
# CF1P                                   no        4.0
# SM6U                                   no        0.0
# RL7P                                   no        5.0
# BATP                                   no        0.0
# NL2P                                   no        2.0
# AA8P                                  yes        2.0
# STDP                                   no        2.0
# SBQP                                   no        5.0
# RMJP                                   no        0.0
# SGKP                                   no        0.0
# YU1P                                  yes        8.0
# CB4P                                  yes        7.0
# TT3P                                   no        0.0
# RA9P                                   no       11.0
# NaN                                   NaN        NaN
# NaN                                   NaN        NaN
#
#      OCIR_Tidy_clinically_significant  OCIR_Mental_Neutralisation  \
# TSEP                               no                         5.0
# FMEP                               no                         0.0
# WO2P                               no                         6.0
# RSIP                               no                         2.0
# LJ9P                               no                         3.0
# HRPP                               no                         0.0
# HMXP                               no                         0.0
# EW3P                               no                         0.0
# GSAP                               no                         0.0
# FL3P                               no                         0.0
# HHQP                               no                         1.0
# HJEP                               no                         3.0
# LA9P                               no                         0.0
# LT5P                               no                         1.0
# KDDP                              yes                         0.0
# EB2P                               no                         0.0
# THCP                               no                         1.0
# PNXX                               no                         1.0
# PC5P                               no                         0.0
# HSPP                               no                         4.0
# KHRP                               no                         6.0
# BE9P                               no                         0.0
# DF2P                              yes                         2.0
# CM5P                               no                         1.0
# SULP                              yes                         9.0
# WJAP                              yes                         6.0
# RRDP                               no                         2.0
# NT6P                               no                         0.0
# NF??                               no                         0.0
# CF1P                               no                         2.0
# SM6U                               no                         0.0
# RL7P                               no                         1.0
# BATP                               no                         1.0
# NL2P                               no                         0.0
# AA8P                               no                         0.0
# STDP                               no                         1.0
# SBQP                               no                         0.0
# RMJP                               no                         0.0
# SGKP                               no                         0.0
# YU1P                              yes                         3.0
# CB4P                               no                         4.0
# TT3P                               no                         0.0
# RA9P                              yes                         7.0
# NaN                               NaN                         NaN
# NaN                               NaN                         NaN
#
#      OCIR_Mental_Neutralisation_clinically_significant  OCIR_Control  \
# TSEP                                               yes           2.0
# FMEP                                                no           0.0
# WO2P                                               yes           3.0
# RSIP                                                no           2.0
# LJ9P                                                no           4.0
# HRPP                                                no           0.0
# HMXP                                                no           1.0
# EW3P                                                no           2.0
# GSAP                                                no           2.0
# FL3P                                                no           6.0
# HHQP                                                no           2.0
# HJEP                                                no           2.0
# LA9P                                                no           9.0
# LT5P                                                no           2.0
# KDDP                                                no           0.0
# EB2P                                                no           5.0
# THCP                                                no           0.0
# PNXX                                                no           1.0
# PC5P                                                no           1.0
# HSPP                                               yes           7.0
# KHRP                                               yes           7.0
# BE9P                                                no           2.0
# DF2P                                                no           8.0
# CM5P                                                no           4.0
# SULP                                               yes           8.0
# WJAP                                               yes          12.0
# RRDP                                                no           8.0
# NT6P                                                no           3.0
# NF??                                                no           3.0
# CF1P                                                no           4.0
# SM6U                                                no           2.0
# RL7P                                                no           5.0
# BATP                                                no           2.0
# NL2P                                                no           0.0
# AA8P                                                no           4.0
# STDP                                                no           3.0
# SBQP                                                no           2.0
# RMJP                                                no           0.0
# SGKP                                                no           0.0
# YU1P                                                no          11.0
# CB4P                                               yes           6.0
# TT3P                                                no           2.0
# RA9P                                               yes          12.0
# NaN                                                NaN           NaN
# NaN                                                NaN           NaN
#
#      OCIR_Control_clinically_significant  OCIR_total score  YBOCS_obsessions  \
# TSEP                                  no              11.0               0.0
# FMEP                                  no               4.0               0.0
# WO2P                                  no              30.0              11.0
# RSIP                                  no              11.0               0.0
# LJ9P                                  no              25.0              16.0
# HRPP                                  no               2.0               0.0
# HMXP                                  no               2.0               0.0
# EW3P                                  no               6.0               0.0
# GSAP                                  no              16.0               0.0
# FL3P                                 yes              13.0               0.0
# HHQP                                  no               7.0               0.0
# HJEP                                  no              13.0               2.0
# LA9P                                 yes              24.0              10.0
# LT5P                                  no              13.0               0.0
# KDDP                                  no               9.0               0.0
# EB2P                                  no              15.0               0.0
# THCP                                  no               7.0               0.0
# PNXX                                  no              11.0               0.0
# PC5P                                  no               3.0               0.0
# HSPP                                 yes              25.0               6.0
# KHRP                                 yes              31.0               8.0
# BE9P                                  no              10.0               0.0
# DF2P                                 yes              41.0               0.0
# CM5P                                  no               9.0               0.0
# SULP                                 yes              35.0               0.0
# WJAP                                 yes              62.0               0.0
# RRDP                                 yes              22.0               1.0
# NT6P                                  no               7.0               0.0
# NF??                                  no               8.0               0.0
# CF1P                                  no              14.0               0.0
# SM6U                                  no              10.0               0.0
# RL7P                                  no              15.0               0.0
# BATP                                  no               3.0               0.0
# NL2P                                  no               7.0               0.0
# AA8P                                  no              18.0               6.0
# STDP                                  no              14.0               0.0
# SBQP                                  no              15.0               0.0
# RMJP                                  no               0.0               0.0
# SGKP                                  no               4.0               0.0
# YU1P                                 yes              46.0               0.0
# CB4P                                 yes              31.0               0.0
# TT3P                                  no              10.0               0.0
# RA9P                                 yes              45.0               0.0
# NaN                                  NaN               NaN               NaN
# NaN                                  NaN               NaN               NaN
#
#      YBOCS_obsessions_sig  YBOCS_compulsions YBOCS_compulsions_sig  \
# TSEP                   no                0.0                    no
# FMEP                   no                0.0                    no
# WO2P                  yes                9.0                    no
# RSIP                   no                0.0                    no
# LJ9P                  yes               10.0                   yes
# HRPP                   no                0.0                    no
# HMXP                   no                0.0                    no
# EW3P                   no                0.0                    no
# GSAP                   no                9.0                    no
# FL3P                   no               13.0                   yes
# HHQP                   no               12.0                   yes
# HJEP                   no                4.0                    no
# LA9P                  yes                9.0                    no
# LT5P                   no                0.0                    no
# KDDP                   no                0.0                    no
# EB2P                   no                0.0                    no
# THCP                   no                0.0                    no
# PNXX                   no                0.0                    no
# PC5P                   no                0.0                    no
# HSPP                   no                0.0                    no
# KHRP                   no                8.0                    no
# BE9P                   no                0.0                    no
# DF2P                   no               11.0                   yes
# CM5P                   no                0.0                    no
# SULP                   no                4.0                    no
# WJAP                   no               15.0                   yes
# RRDP                   no                4.0                    no
# NT6P                   no                0.0                    no
# NF??                   no                0.0                    no
# CF1P                   no                0.0                    no
# SM6U                   no                0.0                    no
# RL7P                   no                0.0                    no
# BATP                   no                0.0                    no
# NL2P                   no                0.0                    no
# AA8P                   no                6.0                    no
# STDP                   no                7.0                    no
# SBQP                   no                0.0                    no
# RMJP                   no                0.0                    no
# SGKP                   no                0.0                    no
# YU1P                   no                0.0                    no
# CB4P                   no                0.0                    no
# TT3P                   no                0.0                    no
# RA9P                   no               10.0                   yes
# NaN                   NaN                NaN                   NaN
# NaN                   NaN                NaN                   NaN
#
#       YBOCS_Totalscore_Items_1to10  \
# TSEP                           0.0
# FMEP                           0.0
# WO2P                          20.0
# RSIP                           0.0
# LJ9P                          26.0
# HRPP                           0.0
# HMXP                           0.0
# EW3P                           0.0
# GSAP                           9.0
# FL3P                          13.0
# HHQP                          12.0
# HJEP                           6.0
# LA9P                          19.0
# LT5P                           0.0
# KDDP                           0.0
# EB2P                           0.0
# THCP                           0.0
# PNXX                           0.0
# PC5P                           0.0
# HSPP                           6.0
# KHRP                          16.0
# BE9P                           0.0
# DF2P                          11.0
# CM5P                           0.0
# SULP                           4.0
# WJAP                          15.0
# RRDP                           4.0
# NT6P                           0.0
# NF??                           0.0
# CF1P                           0.0
# SM6U                           0.0
# RL7P                           0.0
# BATP                           0.0
# NL2P                           0.0
# AA8P                          12.0
# STDP                           7.0
# SBQP                           0.0
# RMJP                           0.0
# SGKP                           0.0
# YU1P                           0.0
# CB4P                           0.0
# TT3P                           0.0
# RA9P                          10.0
# NaN                            NaN
# NaN                            NaN
#
#      YBOCS_Totalscore_Items_1to10_clinically_significant  BDI12  \
# TSEP                                                 no    12.0
# FMEP                                                 no    13.0
# WO2P                                                yes    18.0
# RSIP                                                 no     0.0
# LJ9P                                                yes     7.0
# HRPP                                                 no    14.0
# HMXP                                                 no     1.0
# EW3P                                                 no     0.0
# GSAP                                                 no     4.0
# FL3P                                                 no    12.0
# HHQP                                                 no     0.0
# HJEP                                                 no    20.0
# LA9P                                                yes    17.0
# LT5P                                                 no     4.0
# KDDP                                                 no     7.0
# EB2P                                                 no    36.0
# THCP                                                 no     0.0
# PNXX                                                 no     2.0
# PC5P                                                 no    11.0
# HSPP                                                 no    44.0
# KHRP                                                yes    16.0
# BE9P                                                 no     8.0
# DF2P                                                 no    29.0
# CM5P                                                 no    16.0
# SULP                                                 no     3.0
# WJAP                                                 no    37.0
# RRDP                                                 no    19.0
# NT6P                                                 no    20.0
# NF??                                                 no     6.0
# CF1P                                                 no     0.0
# SM6U                                                 no    38.0
# RL7P                                                 no     4.0
# BATP                                                 no     3.0
# NL2P                                                 no     4.0
# AA8P                                                 no    11.0
# STDP                                                 no     8.0
# SBQP                                                 no     7.0
# RMJP                                                 no    14.0
# SGKP                                                 no     9.0
# YU1P                                                 no    37.0
# CB4P                                                 no    24.0
# TT3P                                                 no    11.0
# RA9P                                                 no    31.0
# NaN                                                 NaN     NaN
# NaN                                                 NaN     NaN
#
#      BDI12_clinically_significant BDI12_severity  MADRS  \
# TSEP                           no              -    4.0
# FMEP                           no              -    4.0
# WO2P                          yes           mild   18.0
# RSIP                           no              -    0.0
# LJ9P                           no              -   14.0
# HRPP                          yes           mild    9.0
# HMXP                           no              -    0.0
# EW3P                           no              -    3.0
# GSAP                           no              -    3.0
# FL3P                           no              -    6.0
# HHQP                           no              -    0.0
# HJEP                          yes         medium    3.0
# LA9P                          yes           mild    7.0
# LT5P                           no              -   11.0
# KDDP                           no              -    3.0
# EB2P                          yes        massive   28.0
# THCP                           no              -    2.0
# PNXX                           no              -    1.0
# PC5P                           no              -    0.0
# HSPP                          yes        massive   15.0
# KHRP                          yes           mild    8.0
# BE9P                           no              -    0.0
# DF2P                          yes        massive   16.0
# CM5P                          yes           mild    3.0
# SULP                           no              -    1.0
# WJAP                          yes        massive   13.0
# RRDP                          yes           mild   14.0
# NT6P                          yes         medium   25.0
# NF??                           no              -    3.0
# CF1P                           no              -    1.0
# SM6U                          yes        massive   24.0
# RL7P                           no              -    4.0
# BATP                           no              -    4.0
# NL2P                           no              -   10.0
# AA8P                           no              -   13.0
# STDP                           no              -   14.0
# SBQP                           no              -    3.0
# RMJP                          yes           mild    6.0
# SGKP                           no              -    9.0
# YU1P                          yes        massive   19.0
# CB4P                          yes         medium   13.0
# TT3P                           no              -   11.0
# RA9P                          yes        massive   10.0
# NaN                           NaN            NaN    NaN
# NaN                           NaN            NaN    NaN
#
#      MADRS_clinically_significant     MADRS_severity   BAI  \
# TSEP                           no        no symptoms   3.0
# FMEP                           no        no symptoms   7.0
# WO2P                          yes      mild symptoms  24.0
# RSIP                           no        no symptoms   7.0
# LJ9P                          yes      mild symptoms  18.0
# HRPP                          yes      mild symptoms   2.0
# HMXP                           no        no symptoms   0.0
# EW3P                           no        no symptoms   0.0
# GSAP                           no        no symptoms   7.0
# FL3P                           no        no symptoms  13.0
# HHQP                           no        no symptoms   0.0
# HJEP                           no        no symptoms   8.0
# LA9P                          yes      mild symptoms  10.0
# LT5P                          yes      mild symptoms   4.0
# KDDP                           no        no symptoms   2.0
# EB2P                          yes  moderate symptoms  36.0
# THCP                           no        no symptoms   2.0
# PNXX                           no        no symptoms   1.0
# PC5P                           no        no symptoms   4.0
# HSPP                          yes      mild symptoms  34.0
# KHRP                          yes      mild symptoms  18.0
# BE9P                           no        no symptoms  12.0
# DF2P                          yes      mild symptoms  15.0
# CM5P                           no        no symptoms  11.0
# SULP                           no        no symptoms   0.0
# WJAP                          yes      mild symptoms  29.0
# RRDP                          yes      mild symptoms   4.0
# NT6P                          yes  moderate symptoms  10.0
# NF??                           no        no symptoms  10.0
# CF1P                           no        no symptoms  15.0
# SM6U                          yes  moderate symptoms  47.0
# RL7P                           no        no symptoms  11.0
# BATP                           no        no symptoms  12.0
# NL2P                          yes      mild symptoms   9.0
# AA8P                          yes      mild symptoms   9.0
# STDP                          yes      mild symptoms   4.0
# SBQP                           no        no symptoms  34.0
# RMJP                           no        no symptoms   8.0
# SGKP                          yes      mild symptoms   7.0
# YU1P                          yes      mild symptoms  15.0
# CB4P                          yes      mild symptoms   7.0
# TT3P                          yes      mild symptoms  17.0
# RA9P                          yes      mild symptoms  42.0
# NaN                           NaN                NaN   NaN
# NaN                           NaN                NaN   NaN
#
#      BAI_clinically_significant BAI_severity  puts              puts_meaning  \
# TSEP                         no      minimum  35.0  extremely high intensity
# FMEP                         no      minimum  18.0          medium intensity
# WO2P                        yes       medium  25.0            high intensity
# RSIP                         no      minimum  21.0          medium intensity
# LJ9P                        yes       medium  30.0            high intensity
# HRPP                         no      minimum  24.0          medium intensity
# HMXP                         no      minimum  24.0          medium intensity
# EW3P                         no      minimum  23.0          medium intensity
# GSAP                         no      minimum  21.0          medium intensity
# FL3P                        yes         mild  18.0          medium intensity
# HHQP                         no      minimum  19.0          medium intensity
# HJEP                        yes         mild  26.0            high intensity
# LA9P                        yes         mild  22.0          medium intensity
# LT5P                         no      minimum  11.0            mild intensity
# KDDP                         no      minimum  18.0          medium intensity
# EB2P                        yes      serious  18.0          medium intensity
# THCP                         no      minimum  18.0          medium intensity
# PNXX                         no      minimum  20.0          medium intensity
# PC5P                         no      minimum  18.0          medium intensity
# HSPP                        yes      serious  10.0            mild intensity
# KHRP                        yes       medium  23.0          medium intensity
# BE9P                        yes         mild  10.0            mild intensity
# DF2P                        yes         mild  24.0          medium intensity
# CM5P                        yes         mild  23.0          medium intensity
# SULP                         no      minimum  16.0          medium intensity
# WJAP                        yes      serious  25.0            high intensity
# RRDP                         no      minimum  21.0          medium intensity
# NT6P                        yes         mild  21.0          medium intensity
# NF??                        yes         mild  30.0            high intensity
# CF1P                        yes         mild  13.0          medium intensity
# SM6U                        yes      serious  28.0            high intensity
# RL7P                        yes         mild  22.0          medium intensity
# BATP                        yes         mild  21.0          medium intensity
# NL2P                        yes         mild  18.0          medium intensity
# AA8P                        yes         mild  31.0  extremely high intensity
# STDP                         no      minimum  24.0          medium intensity
# SBQP                        yes      serious  12.0          medium intensity
# RMJP                        yes         mild  14.0          medium intensity
# SGKP                         no      minimum  11.0            mild intensity
# YU1P                        yes         mild  29.0            high intensity
# CB4P                         no      minimum  16.0          medium intensity
# TT3P                        yes       medium  24.0          medium intensity
# RA9P                        yes      serious  31.0  extremely high intensity
# NaN                         NaN          NaN   NaN                       NaN
# NaN                         NaN          NaN   NaN                       NaN
#
#       qol_score  qol_scale qol_clinical meaning  RVTRS  Diag_ADHD  Diag_OCD  \
# TSEP       13.0       95.0      extremely happy    3.0        1.0       0.0
# FMEP       19.0       80.0                happy   16.0        0.0       0.0
# WO2P       60.0       20.0    extremely unhappy   17.0        1.0       1.0
# RSIP        8.0       90.0      extremely happy    9.0        0.0       0.0
# LJ9P       33.0       60.0         medium happy   15.0        1.0       1.0
# HRPP       11.0       45.0         medium happy    3.0        0.0       0.0
# HMXP        7.0       90.0      extremely happy    6.0        0.0       0.0
# EW3P       18.0       90.0      extremely happy    8.0        1.0       0.0
# GSAP       10.0       60.0         medium happy   16.0        0.0       1.0
# FL3P       18.0       60.0         medium happy   18.0        1.0       1.0
# HHQP        0.0       80.0                happy   15.0        0.0       1.0
# HJEP       23.0       40.0              unhappy   12.0        0.0       1.0
# LA9P       32.0       75.0                happy   11.0        0.0       1.0
# LT5P       23.0       70.0                happy   12.0        0.0       0.0
# KDDP       20.0       80.0                happy    5.0        0.0       0.0
# EB2P       57.0       25.0              unhappy   14.0        1.0       0.0
# THCP        9.0       80.0                happy    4.0        0.0       0.0
# PNXX        3.0      100.0      extremely happy    5.0        0.0       0.0
# PC5P       19.0      100.0      extremely happy    NaN        0.0       0.0
# HSPP       52.0       30.0              unhappy   16.0        0.0       1.0
# KHRP       58.0       50.0         medium happy   11.0        0.0       1.0
# BE9P        5.0       60.0         medium happy    6.0        0.0       0.0
# DF2P       53.0       40.0              unhappy    5.0        1.0       1.0
# CM5P       25.0       75.0                happy    5.0        0.0       0.0
# SULP       13.0       75.0                happy   17.0        0.0       1.0
# WJAP       84.0       40.0              unhappy   13.0        1.0       1.0
# RRDP       38.0       45.0         medium happy   10.0        0.0       1.0
# NT6P       47.0       10.0    extremely unhappy    9.0        0.0       0.0
# NF??       42.0       65.0                happy   17.0        1.0       0.0
# CF1P       14.0       50.0         medium happy    6.0        0.0       0.0
# SM6U       66.0       10.0    extremely unhappy    6.0        0.0       0.0
# RL7P       20.0       35.0              unhappy   13.0        0.0       0.0
# BATP        8.0       90.0      extremely happy    6.0        0.0       0.0
# NL2P       33.0       70.0                happy    3.0        0.0       0.0
# AA8P       34.0       45.0         medium happy   18.0        1.0       1.0
# STDP       39.0       50.0         medium happy    5.0        1.0       0.0
# SBQP       52.0       80.0                happy    8.0        1.0       0.0
# RMJP       34.0       60.0         medium happy   13.0        0.0       0.0
# SGKP       19.0       70.0                happy    5.0        0.0       0.0
# YU1P       67.0       20.0    extremely unhappy   12.0        1.0       0.0
# CB4P       62.0       45.0         medium happy    5.0        1.0       0.0
# TT3P       33.0       75.0                happy    0.0        1.0       0.0
# RA9P       57.0       65.0                happy    8.0        1.0       1.0
# NaN         NaN        NaN                  NaN    NaN        NaN       NaN
# NaN         NaN        NaN                  NaN    NaN        NaN       NaN
#
#       Diag_Depression  Diag_Anxiety  Diag_AQ        medication THC_occasional  \
# TSEP              0.0           0.0      0.0   methylphenidate              0
# FMEP              0.0           0.0      0.0             naive              0
# WO2P              1.0           1.0      1.0         non_psych              0
# RSIP              0.0           0.0      0.0             naive              0
# LJ9P              0.0           1.0      0.0             naive              0
# HRPP              1.0           0.0      0.0         non_psych              0
# HMXP              0.0           0.0      0.0         non_psych              0
# EW3P              0.0           0.0      0.0   other-Triptaine              0
# GSAP              0.0           0.0      0.0         non_psych              0
# FL3P              0.0           0.0      0.0     antipsychotic              0
# HHQP              0.0           0.0      0.0             naive              0
# HJEP              0.0           1.0      0.0             naive              0
# LA9P              1.0           1.0      0.0     antipsychotic            THC
# LT5P              0.0           0.0      0.0   methylphenidate            THC
# KDDP              0.0           0.0      0.0         non_psych              0
# EB2P              1.0           1.0      0.0  other-anxiolytic              0
# THCP              0.0           0.0      0.0             naive              0
# PNXX              0.0           0.0      0.0             naive              0
# PC5P              0.0           0.0      0.0             naive              0
# HSPP              1.0           1.0      0.0         non_psych              0
# KHRP              1.0           1.0      0.0             naive              0
# BE9P              0.0           0.0      0.0  other-anxiolytic              0
# DF2P              1.0           1.0      1.0             naive              0
# CM5P              0.0           0.0      0.0        unreported              0
# SULP              0.0           0.0      0.0             naive              0
# WJAP              1.0           1.0      1.0         non_psych              0
# RRDP              1.0           0.0      0.0             naive              0
# NT6P              1.0           0.0      0.0             naive              0
# NF??              0.0           0.0      0.0             naive              0
# CF1P              0.0           0.0      0.0             naive              0
# SM6U              1.0           1.0      0.0    benzodiazepene              0
# RL7P              0.0           1.0      0.0         non_psych              0
# BATP              0.0           0.0      1.0         non_psych              0
# NL2P              0.0           0.0      0.0             naive              0
# AA8P              0.0           0.0      1.0              SSRI              0
# STDP              0.0           0.0      0.0             naive            THC
# SBQP              0.0           1.0      0.0             naive              0
# RMJP              0.0           1.0      0.0         non_psych              0
# SGKP              0.0           0.0      0.0         non_psych              0
# YU1P              1.0           0.0      0.0         non_psych              0
# CB4P              1.0           0.0      0.0             naive              0
# TT3P              0.0           1.0      0.0             naive              0
# RA9P              1.0           1.0      0.0         non_psych              0
# NaN               NaN           NaN      NaN               NaN            NaN
# NaN               NaN           NaN      NaN               NaN            NaN
#
#       Ferritin Unnamed: 54 Unnamed: 55 Unnamed: 56
# TSEP     95.13        TSEP  Tsep140726         NaN
# FMEP    159.90        FMEP  Fmep140615         NaN
# WO2P    268.20        WO2P  Wo2p140614         NaN
# RSIP    145.30        RSIP  Rsip140614         NaN
# LJ9P    104.50        LJ9P  Lj9p140615         NaN
# HRPP    103.90        HRPP  Hrpp140621         NaN
# HMXP     56.47        HMXP  Hmxp140727         NaN
# EW3P    260.70        EW3P  Ew3p140727         NaN
# GSAP     88.90        GSAP         NaN         NaN
# FL3P    616.80        FL3P  Fl3p140816         NaN
# HHQP    182.40        HHQP  Hhqp140906         NaN
# HJEP     76.43        HJEP  Hjep140906         NaN
# LA9P    126.10        LA9P  La9p140906         NaN
# LT5P    120.10        LT5P  Lt5p140920         NaN
# KDDP     74.30        KDDP  Kdpp140927         NaN
# EB2P     73.03        EB2P  Eb2p140927         NaN
# THCP    117.10        THCP  Thcp141012         NaN
# PNXX       NaN        PNXX         NaN         NaN
# PC5P     31.87        PC5P  Pc5p141101         NaN
# HSPP     37.98        HSPP  Hspp141101       39,07
# KHRP     57.59        KHRP  Khrp141115         NaN
# BE9P     86.07        BE9P  Be9p141115         NaN
# DF2P    395.30        DF2P  Df2p150117         NaN
# CM5P     42.69        CM5P  Cm5p150124         NaN
# SULP    183.80        SULP  Sulp150124         NaN
# WJAP     82.23        WJAP  Wjap141206         NaN
# RRDP    207.10        RRDP  Rrdp150117         NaN
# NT6P     51.63        NT6P  Nt6p150124         NaN
# NF??    165.60        NF??  Nf3p150124         NaN
# CF1P     20.51        CF1P  Cf1p150124         NaN
# SM6U    124.60        SM6U  Sm6u150314         NaN
# RL7P     48.19        RL7P  Rl7p150321         NaN
# BATP     50.67        BATP  Batp150321         NaN
# NL2P     59.90        NL2P  Nl2p151017         NaN
# AA8P    156.70        AA8P  Aa8p150321         NaN
# STDP     98.63        STDP  Stdp150328         NaN
# SBQP       NaN        SBQP         NaN         NaN
# RMJP       NaN        RMJP         NaN         NaN
# SGKP       NaN        SGKP         NaN         NaN
# YU1P       NaN        YU1P         NaN         NaN
# CB4P       NaN        CB4P         NaN         NaN
# TT3P       NaN        TT3P         NaN         NaN
# RA9P       NaN        RA9P         NaN         NaN
# NaN        NaN         NaN         NaN         NaN
# NaN        NaN         NaN         NaN         NaN

# %%
ttest_ind(CLNc.Ferritin.dropna(), CLN.Ferritin.dropna())
# Out:
# (2.0523499729500507, 0.044433375083867917)

# %%
sns.distplot(CLNc.Ferritin.dropna(), color='r')
sns.distplot(CLN.Ferritin.dropna(), color='b')

# %%
print np.mean(CLNc.Ferritin.dropna())
print np.mean(CLN.Ferritin.dropna())
# Out:
# 163.836
# 107.824848485
