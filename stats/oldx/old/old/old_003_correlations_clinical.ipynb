# %%
# %matplotlib inline
import os 
import numpy as np
from numpy import mean, std
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import ttest_rel, ttest_ind, mannwhitneyu, wilcoxon, spearmanr,pearsonr, fisher_exact,kstest
from scipy.stats import ks_2samp, kstest, anderson, anderson_ksamp, levene
from statsmodels.sandbox.stats.multicomp import fdrcorrection0
from sklearn import preprocessing
import statsmodels.api as sm
pd.options.display.max_columns = 999
import statsmodels.formula.api as smf
import scipy.stats as ss 
from sklearn.decomposition import TruncatedSVD, PCA
import math 
from outliers import smirnov_grubbs as grubbs
sns.set_style('white')

workspace_dir  = '/Users/kanaan/Google Drive/TS-EUROTRAIN/RESULTS_QSMv3/AUG5'
#workspace_dir  = '/scr/malta3/workspace/project_iron/phenotypic'
pheno_dir      = os.path.join(workspace_dir, 'phenotypic')
clinical_dir   = os.path.join(workspace_dir, 'DF_clinical')
save_fig_dir   = '/Users/kanaan/Google Drive/TS-EUROTRAIN/Papers/2016_QSM_paper/Figures_python_v2'

dpi = 50
pca_mult = 10
cmap_b = ["#1300ff", "#87d6e9"]

# %%
def get_df(popname):
    df = pd.read_csv(os.path.join(pheno_dir, 'df_%s_qc_PCA.csv'%popname),index_col = 1)
    return df 

patients = get_df('patients')
patients.head()
# Out:
#            Unnamed: 0  Age  Gender     Group   SNR_MAG   CNR_MAG   FBER_MAG  \
# Row.names
# BATP                1   22       0  Patients  2.194736  0.099240   4.217127
# BE9P                2   18       0  Patients  2.615788  0.138203   6.980852
# CB4P                3   47       0  Patients  2.740942  0.117760   3.898556
# CF1P                4   28       1  Patients  2.960693  0.094840  11.196657
# CM5P                5   27       0  Patients  2.889796  0.186730   6.908375
#
#             EFC_MAG  FWHM_MAG   QI1_MAG  R_Caud  R_Puta   R_Pall  R_Amyg  \
# Row.names
# BATP       0.651460   4.51889  0.376896  13.624 -15.795   96.397  -9.046
# BE9P       0.625762   3.79525  0.314843  -5.605 -36.403   86.695 -35.032
# CB4P       0.648337   3.32977  0.403306  28.997  14.031  105.506 -12.662
# CF1P       0.560392   3.37357  0.242554  31.474  34.131   79.744 -19.282
# CM5P       0.633059   3.48994  0.318794  16.542 -14.661   46.758 -46.628
#
#            R_Hipp  R_Accu  R_Thal  L_Caud  L_Puta  L_Pall  L_Amyg  L_Hipp  \
# Row.names
# BATP      -14.158 -28.587 -28.590   7.472  -7.845  83.228 -45.384 -19.867
# BE9P      -22.898 -51.548 -42.211   3.846 -35.613  90.525 -42.220 -14.546
# CB4P        6.337 -16.980 -13.145  33.379   5.436  97.049 -51.276  14.246
# CF1P        5.045 -13.299 -12.864  27.425  39.794  81.721 -15.898  -7.496
# CM5P      -31.665 -68.906 -54.210   5.831 -21.855  41.874 -41.759 -31.016
#
#            L_Accu  L_Thal    L_BG    R_BG     R_RN     R_SN   R_STN    R_DN  \
# Row.names
# BATP      -21.172 -31.326   9.313  11.152  111.562  118.102  30.427  73.421
# BE9P      -42.468 -47.179  -1.270  -7.023   49.006   91.236   9.375  21.780
# CB4P      -22.826  -2.166  27.661  31.152  198.931  145.860  44.322  43.323
# CF1P        1.694 -19.988  37.862  36.902  138.658  121.521  81.963  76.107
# CM5P      -59.072 -46.183  -6.377   3.396   77.727  126.052  10.283  18.545
#
#              R_GPi    R_GPe     L_RN     L_SN   L_STN     L_DN    L_GPi  \
# Row.names
# BATP       108.931  104.859  103.081  102.500  34.054  113.985  100.801
# BE9P       121.505  115.656   44.792   85.533   9.722   44.387  115.069
# CB4P        96.634  129.256  128.883  106.459 -23.957   42.861  127.246
# CF1P        89.499  105.904  142.342  113.032  50.592   76.617   88.834
# CM5P        46.786   68.315   69.813   87.401  -0.508   30.810   34.490
#
#              L_GPe     L_BS     R_BS  THA7_0  THA7_1  THA7_2  THA7_3  THA7_4  \
# Row.names
# BATP        87.658  108.925  112.325 -35.732 -35.732 -27.427  -9.522 -50.612
# BE9P       103.300   86.558   81.214 -34.575 -34.575 -34.747 -41.450 -55.880
# CB4P       114.711  116.640  154.338 -48.825 -48.825 -41.448  12.167 -16.240
# CF1P       101.420  132.360  127.145 -49.942 -49.942 -42.638  14.660 -38.492
# CM5P        38.010   97.043  113.438 -77.052 -77.052 -72.486 -26.498 -68.146
#
#            THA7_5  THA7_6  THA7_7  STR3_MOTOR  STR3_LIMBIC  STR3_EXEC  \
# Row.names
# BATP      -53.041  -7.483 -18.866       4.154      -10.412    -10.248
# BE9P      -52.882 -39.642 -32.371     -24.692      -36.809    -21.542
# CB4P      -58.061  -3.305   7.121      20.796       10.466      9.018
# CF1P      -63.524   3.280  -5.769      46.500        8.665     27.655
# CM5P      -98.439 -35.241 -30.650      -4.856      -46.260     -9.438
#
#            MRS_ACC  MRS_THA  MRS_STR  MRSc_ACC  MRSc_THA  MRSc_STR      GM  \
# Row.names
# BATP       -48.973  -33.419  -31.491   -50.444   -33.983   -14.906 -27.060
# BE9P       -49.701  -46.518  -20.022   -52.040   -48.523   -12.992 -33.735
# CB4P       -34.858  -27.178  -18.158   -36.177    -9.231   -12.144  -9.113
# CF1P       -31.369  -29.157   10.401   -31.948   -24.833    27.808 -17.619
# CM5P       -74.609  -69.216  -34.780   -74.313   -48.958   -15.785 -43.044
#
#                WM     CSF     Caud     Puta      Pall     Amyg     Hipp  \
# Row.names
# BATP      -37.464 -18.601  10.5480 -11.8200   89.8125 -27.2150 -17.0125
# BE9P      -40.758 -24.059  -0.8795 -36.0080   88.6100 -38.6260 -18.7220
# CB4P      -14.603 -12.640  31.1880   9.7335  101.2775 -31.9690  10.2915
# CF1P      -25.778  -2.008  29.4495  36.9625   80.7325 -17.5900  -1.2255
# CM5P      -54.830 -30.967  11.1865 -18.2580   44.3160 -44.1935 -31.3405
#
#               Accu     Thal        SN      STN        RN       DN       GPi  \
# Row.names
# BATP      -24.8795 -29.9580  110.3010  32.2405  107.3215  93.7030  104.8660
# BE9P      -47.0080 -44.6950   88.3845   9.5485   46.8990  33.0835  118.2870
# CB4P      -19.9030  -7.6555  126.1595  10.1825  163.9070  43.0920  111.9400
# CF1P       -5.8025 -16.4260  117.2765  66.2775  140.5000  76.3620   89.1665
# CM5P      -63.9890 -50.1965  106.7265   4.8875   73.7700  24.6775   40.6380
#
#                 GPe       BG        BS  L_Caud_Puta  R_Caud_Puta  Caud_Puta  \
# Row.names
# BATP        96.2585  10.2325  110.6250      -0.1865      -1.0855   -0.63600
# BE9P       109.4780  -4.1465   83.8860     -15.8835     -21.0040  -18.44375
# CB4P       121.9835  29.4065  135.4890      19.4075      21.5140   20.46075
# CF1P       103.6620  37.3820  129.7525      33.6095      32.8025   33.20600
# CM5P        53.1625  -1.4905  105.2405      -8.0120       0.9405   -3.53575
#
#                 ALL    QC_PCA   Chi_PCA  CLN_Age CLN_Birthday  \
# Row.names
# BATP       60.42875  0.230647  0.168824       22      8/31/92
# BE9P       39.86975  0.194365  0.117568       18       7/9/96
# CB4P       82.44775  0.171919  0.208121       47      5/20/68
# CF1P       83.56725  0.172640  0.197151       28      11/8/86
# CM5P       51.87500  0.179342  0.127326       27     10/27/87
#
#            CLN_YGTSS_Total_Tic_Score  CLN_YGTSS_Motoric_Score  \
# Row.names
# BATP                              10                        5
# BE9P                               3                        3
# CB4P                              14                       14
# CF1P                              28                       13
# CM5P                              12                       12
#
#            CLN_YGTSS_Vocal_Score  CLN_YGTSS_Total_Score_incl_Impairment  \
# Row.names
# BATP                           5                                     20
# BE9P                           0                                      3
# CB4P                           0                                     34
# CF1P                          15                                     48
# CM5P                           0                                     32
#
#            CLN_DSM4_ADHD_Score  CLN_DSM4_Attention  CLN_DSM4_Hyperactivity  \
# Row.names
# BATP                         1                   0                       0
# BE9P                        15                   1                       1
# CB4P                         5                   0                       0
# CF1P                        12                   1                       0
# CM5P                        14                   1                       1
#
#            CLN_CAARS_Score_ADHS_Symptoms_Total_Cat_G_T_Score  \
# Row.names
# BATP                                                    32.0
# BE9P                                                    51.0
# CB4P                                                    81.0
# CF1P                                                    44.0
# CM5P                                                    54.0
#
#           CLN_DSM4_clinically_significant_ADHD  CLN_OCIR_Wash  \
# Row.names
# BATP                                        no              0
# BE9P                                        no              2
# CB4P                                       yes              3
# CF1P                                        no              1
# CM5P                                        no              0
#
#           CLN_OCIR_WASH_clinically_significant  CLN_OCIR_Thoughts  \
# Row.names
# BATP                                        no                  0
# BE9P                                        no                  0
# CB4P                                        no                  5
# CF1P                                        no                  1
# CM5P                                        no                  4
#
#           CLN_OCIR_Thoughts_clinically_significant  CLN_OCIR_Hoarding  \
# Row.names
# BATP                                            no                  0
# BE9P                                            no                  3
# CB4P                                            no                  6
# CF1P                                            no                  2
# CM5P                                            no                  0
#
#           CLN_OCIR_Hoarding_clinically_significant  CLN_OCIR_Tidy  \
# Row.names
# BATP                                            no              0
# BE9P                                            no              3
# CB4P                                           yes              7
# CF1P                                            no              4
# CM5P                                            no              0
#
#           CLN_OCIR_Tidy_clinically_significant  \
# Row.names
# BATP                                        no
# BE9P                                        no
# CB4P                                        no
# CF1P                                        no
# CM5P                                        no
#
#            CLN_OCIR_Mental_Neutralisation  \
# Row.names
# BATP                                    1
# BE9P                                    0
# CB4P                                    4
# CF1P                                    2
# CM5P                                    1
#
#           CLN_OCIR_Mental_Neutralisation_clinically_significant  \
# Row.names
# BATP                                                      no
# BE9P                                                      no
# CB4P                                                     yes
# CF1P                                                      no
# CM5P                                                      no
#
#            CLN_OCIR_Control CLN_OCIR_Control_clinically_significant  \
# Row.names
# BATP                      2                                      no
# BE9P                      2                                      no
# CB4P                      6                                     yes
# CF1P                      4                                      no
# CM5P                      4                                      no
#
#            CLN_OCIR_total_score  CLN_YBOCS_obsessions  \
# Row.names
# BATP                          3                     0
# BE9P                         10                     0
# CB4P                         31                     0
# CF1P                         14                     0
# CM5P                          9                     0
#
#           CLN_YBOCS_obsessions_sig  CLN_YBOCS_compulsions  \
# Row.names
# BATP                            no                      0
# BE9P                            no                      0
# CB4P                            no                      0
# CF1P                            no                      0
# CM5P                            no                      0
#
#           CLN_YBOCS_compulsions_sig  CLN_YBOCS_Totalscore_Items_1to10  \
# Row.names
# BATP                             no                                 0
# BE9P                             no                                 0
# CB4P                             no                                 0
# CF1P                             no                                 0
# CM5P                             no                                 0
#
#           CLN_YBOCS_Totalscore_Items_1to10_clinically_significant  CLN_BDI12  \
# Row.names
# BATP                                                      no               3
# BE9P                                                      no               8
# CB4P                                                      no              24
# CF1P                                                      no               0
# CM5P                                                      no              16
#
#           CLN_BDI12_clinically_significant CLN_BDI12_severity  CLN_MADRS  \
# Row.names
# BATP                                    no                  -          4
# BE9P                                    no                  -          0
# CB4P                                   yes             medium         13
# CF1P                                    no                  -          1
# CM5P                                   yes               mild          3
#
#           CLN_MADRS_clinically_significant CLN_MADRS_severity  CLN_BAI  \
# Row.names
# BATP                                    no        no symptoms       12
# BE9P                                    no        no symptoms       12
# CB4P                                   yes      mild symptoms        7
# CF1P                                    no        no symptoms       15
# CM5P                                    no        no symptoms       11
#
#           CLN_BAI_clinically_significant CLN_BAI_severity  CLN_puts  \
# Row.names
# BATP                                 yes             mild        21
# BE9P                                 yes             mild        10
# CB4P                                  no          minimum        16
# CF1P                                 yes             mild        13
# CM5P                                 yes             mild        23
#
#            CLN_puts_meaning  CLN_qol_score  CLN_qol_scale  \
# Row.names
# BATP       medium intensity              8             90
# BE9P         mild intensity              5             60
# CB4P       medium intensity             62             45
# CF1P       medium intensity             14             50
# CM5P       medium intensity             25             75
#
#           CLN_qol_clinical.meaning  CLN_RVTRS  CLN_Diag_ADHD  CLN_Diag_OCD  \
# Row.names
# BATP               extremely happy          6              0             0
# BE9P                  medium happy          6              0             0
# CB4P                  medium happy          5              1             0
# CF1P                  medium happy          6              0             0
# CM5P                         happy          5              0             0
#
#            CLN_Diag_Depression  CLN_Diag_Anxiety  CLN_Diag_AQ  \
# Row.names
# BATP                         0                 0            1
# BE9P                         0                 0            0
# CB4P                         1                 0            0
# CF1P                         0                 0            0
# CM5P                         0                 0            0
#
#              CLN_medication CLN_THC_occasional  CLN_Ferritin CLN_Unnamed..54  \
# Row.names
# BATP              non_psych                  0         50.67            BATP
# BE9P       other-anxiolytic                  0         86.07            BE9P
# CB4P                  naive                  0           NaN            CB4P
# CF1P                  naive                  0         20.51            CF1P
# CM5P             unreported                  0         42.69            CM5P
#
#           CLN_Unnamed..55  CLN_Unnamed..56  STR_Age STR_Gender  STR_FWHM  \
# Row.names
# BATP           Batp150321              NaN     22.0          M   5.79228
# BE9P           Be9p141115              NaN     18.0          M   4.55988
# CB4P                  NaN              NaN      NaN        NaN       NaN
# CF1P           Cf1p150124              NaN     28.0          M   8.13384
# CM5P           Cm5p150124              NaN     27.0          M   9.36624
#
#            STR_SNR  STR_Shift  STR_Ph0  STR_Ph1  STR_GM  STR_WM  STR_CSF  \
# Row.names
# BATP          23.0      0.014     78.0     -1.5    73.6    26.4      0.0
# BE9P          23.0      0.037     79.0      1.8    75.4    24.5      0.0
# CB4P           NaN        NaN      NaN      NaN     NaN     NaN      NaN
# CF1P          22.0      0.023    104.0      9.3    72.4    27.4      0.2
# CM5P          21.0      0.057      8.0      5.2    72.6    27.4      0.0
#
#            STR_AllTissue    STR_FD   STR_FD1   STR_FD2  STR_fdrift  \
# Row.names
# BATP               100.0  0.136510  0.134738  0.138265    2.157439
# BE9P                99.9  0.149829  0.108921  0.190351    2.005244
# CB4P                 NaN       NaN       NaN       NaN         NaN
# CF1P               100.0  0.090722  0.070974  0.110284    3.391145
# CM5P               100.0  0.284820  0.299045  0.270729         NaN
#
#            STR_pdrift   STR_Cre  STR_Cre.  STR_tCho  STR_tCho.   STR_NAA  \
# Row.names
# BATP         1.295484  6.252160       3.0  1.330777        4.0  7.355605
# BE9P         5.258449  6.289172       3.0  1.567612        3.0  6.692777
# CB4P              NaN       NaN       NaN       NaN        NaN       NaN
# CF1P         2.478657  6.360573       3.0  1.345466        3.0  6.393820
# CM5P              NaN  7.233337       3.0  1.615473        3.0  7.717565
#
#            STR_NAA.  STR_NAAG  STR_NAAG.  STR_tNAA  STR_tNAA.  STR_mIno  \
# Row.names
# BATP            4.0  0.719367       53.0  8.074971        4.0  3.109990
# BE9P            3.0  0.000000      999.0  6.692777        3.0  3.723989
# CB4P            NaN       NaN        NaN       NaN        NaN       NaN
# CF1P            3.0  0.000000      999.0  6.393820        3.0  3.271716
# CM5P            3.0  0.000000      999.0  7.717565        3.0  2.757088
#
#            STR_mIno.   STR_Glu  STR_Glu.   STR_Gln  STR_Gln.   STR_Glx  \
# Row.names
# BATP             7.0  6.417210       8.0  2.096856      32.0  8.515104
# BE9P             6.0  6.242362       8.0  2.270801      28.0  8.513163
# CB4P             NaN       NaN       NaN       NaN       NaN       NaN
# CF1P             9.0  5.933557       8.0  2.745997      25.0  8.679554
# CM5P             9.0  6.219260       8.0  1.646580      38.0  7.865840
#
#            STR_Glx.  STR_Glu_Cre  STR_Gln_Cre  STR_Glx_Cre  STR_GABA  \
# Row.names
# BATP           10.0     1.066075     0.347746     1.413821  2.169519
# BE9P            9.0     1.032939     0.375520     1.408458  1.562411
# CB4P            NaN          NaN          NaN          NaN       NaN
# CF1P           10.0     0.969359     0.448835     1.418194  2.042615
# CM5P           10.0     0.891725     0.236411     1.127098  2.327816
#
#            STR_GABA.   STR_Asp  STR_Asp.   STR_Tau  STR_Tau.   STR_Lac  \
# Row.names
# BATP            20.0  1.384755      35.0  0.905177      40.0  0.000000
# BE9P            25.0  0.415048     106.0  1.193133      28.0  0.000000
# CB4P             NaN       NaN       NaN       NaN       NaN       NaN
# CF1P            22.0  0.157923     274.0  0.097144     389.0  0.000000
# CM5P            22.0  0.000000     999.0  0.000000     999.0  0.290329
#
#            STR_Lac.  STR_Ala  STR_Ala.  STR_Asp.1  STR_Asp..1  STR_Scy  \
# Row.names
# BATP          999.0      0.0     999.0      1.334        35.0      0.0
# BE9P          999.0      0.0     999.0      0.399       106.0      0.0
# CB4P            NaN      NaN       NaN        NaN         NaN      NaN
# CF1P          999.0      0.0     999.0      0.152       274.0      0.0
# CM5P          163.0      0.0     999.0      0.000       999.0      0.0
#
#            STR_Scy.  STR_Glc  STR_Glc.  STR_Gua  STR_Gua. STR_dtype  \
# Row.names
# BATP          999.0      NaN       NaN      NaN       NaN      TWIX
# BE9P          999.0      NaN       NaN      NaN       NaN      TWIX
# CB4P            NaN      NaN       NaN      NaN       NaN       NaN
# CF1P          999.0      NaN       NaN      NaN       NaN      TWIX
# CM5P          999.0      NaN       NaN      NaN       NaN       RDA
#
#            STR_Cre_absCRLB  STR_tCho_absCRLB  STR_mIno_absCRLB  \
# Row.names
# BATP                  0.19              0.05              0.22
# BE9P                  0.19              0.05              0.22
# CB4P                   NaN               NaN               NaN
# CF1P                  0.19              0.04              0.29
# CM5P                  0.22              0.05              0.25
#
#            STR_tNAA_absCRLB  STR_Glu_absCRLB  STR_Gln_absCRLB  \
# Row.names
# BATP                   0.32             0.51             0.67
# BE9P                   0.20             0.50             0.64
# CB4P                    NaN              NaN              NaN
# CF1P                   0.19             0.47             0.69
# CM5P                   0.23             0.50             0.63
#
#            STR_Glx_absCRLB  STR_GABA_absCRLB  STR_Gln_Glu  THA_Age THA_Gender  \
# Row.names
# BATP                  0.85              0.43     0.326755     22.0          M
# BE9P                  0.77              0.39     0.363773     18.0          M
# CB4P                   NaN               NaN          NaN     47.0          M
# CF1P                  0.87              0.45     0.462791     28.0          M
# CM5P                  0.79              0.51     0.264755     27.0          M
#
#            THA_FWHM  THA_SNR  THA_Shift  THA_Ph0  THA_Ph1  THA_GM  THA_WM  \
# Row.names
# BATP        4.55988     18.0      0.052      7.0      3.1    93.9     0.3
# BE9P        4.55988     24.0      0.047     12.0      3.9    92.7     0.4
# CB4P        5.79228     17.0      0.047     58.0      8.3    82.6     8.2
# CF1P        5.17608     24.0      0.052      6.0      5.4    86.3     3.6
# CM5P        5.91552     20.0      0.057     14.0      5.9    83.5     9.4
#
#            THA_CSF  THA_AllTissue    THA_FD   THA_FD1   THA_FD2  THA_fdrift  \
# Row.names
# BATP           5.8          100.0  0.136510  0.134738  0.138265    1.270768
# BE9P           6.9          100.0  0.149829  0.108921  0.190351    1.625819
# CB4P           9.2          100.0  0.857230  0.738322  0.975016    3.278691
# CF1P          10.1          100.0  0.090722  0.070974  0.110284    1.245788
# CM5P           7.1          100.0  0.284820  0.299045  0.270729         NaN
#
#            THA_pdrift   THA_Cre  THA_Cre.  THA_tCho  THA_tCho.   THA_NAA  \
# Row.names
# BATP         7.900148  6.555388       3.0  1.882689        3.0  8.161344
# BE9P         7.377930  5.309220       3.0  1.722312        3.0  7.094641
# CB4P        52.201508  5.304499       3.0  1.355581        3.0  6.314769
# CF1P         7.882278  6.593707       3.0  1.789348        3.0  7.832395
# CM5P              NaN  6.237760       3.0  2.059896        2.0  7.874062
#
#            THA_NAA.  THA_NAAG  THA_NAAG.  THA_tNAA  THA_tNAA.  THA_mIno  \
# Row.names
# BATP            4.0  0.871027       42.0  9.031238        3.0  4.365344
# BE9P            3.0  0.971884       23.0  8.066526        3.0  4.332745
# CB4P            4.0  0.874945       34.0  7.189713        4.0  3.560442
# CF1P            3.0  0.337501      101.0  8.169896        3.0  4.125803
# CM5P            3.0  0.502164       64.0  8.376225        3.0  3.837395
#
#            THA_mIno.   THA_Glu  THA_Glu.   THA_Gln  THA_Gln.   THA_Glx  \
# Row.names
# BATP             6.0  7.015853       8.0  2.152617      33.0  9.168470
# BE9P             7.0  6.663203       7.0  1.670677      34.0  8.333880
# CB4P             6.0  5.401326       9.0  3.295626      18.0  8.696952
# CF1P             6.0  7.055550       7.0  2.670404      23.0  9.725954
# CM5P             6.0  5.922342       8.0  1.383512      44.0  7.305854
#
#            THA_Glx.  THA_Glu_Cre  THA_Gln_Cre  THA_Glx_Cre  THA_GABA  \
# Row.names
# BATP            9.0     1.213541     0.372001     1.586676  2.199117
# BE9P            9.0     1.440041     0.361445     1.801486  1.596093
# CB4P            8.0     1.187592     0.724454     1.912046  1.294918
# CF1P            8.0     1.267110     0.479607     1.746716  2.471456
# CM5P           11.0     1.081758     0.252790     1.333409  2.179458
#
#            THA_GABA.   THA_Asp  THA_Asp.   THA_Tau  THA_Tau.   THA_Lac  \
# Row.names
# BATP            21.0  0.000000     999.0  0.000000     999.0  0.000000
# BE9P            21.0  0.841076      51.0  0.561100      56.0  0.629946
# CB4P            29.0  0.212320     201.0  0.000000     999.0  0.256650
# CF1P            17.0  0.808819      55.0  0.000000     999.0  0.268817
# CM5P            20.0  0.136643     351.0  0.216352     144.0  0.413346
#
#            THA_Lac.  THA_Ala  THA_Ala.  THA_Asp.1  THA_Asp..1  THA_Scy  \
# Row.names
# BATP          999.0      0.0     999.0      0.000       999.0      0.0
# BE9P           43.0      0.0     999.0      0.733        51.0      0.0
# CB4P          123.0      0.0     999.0      0.182       201.0      0.0
# CF1P          143.0      0.0     999.0      0.683        55.0      0.0
# CM5P           79.0      0.0     999.0      0.120       351.0      0.0
#
#            THA_Scy.  THA_Glc  THA_Glc.  THA_Gua  THA_Gua. THA_dtype  \
# Row.names
# BATP          999.0      NaN       NaN      NaN       NaN      TWIX
# BE9P          999.0      NaN       NaN      NaN       NaN      TWIX
# CB4P          999.0      NaN       NaN      NaN       NaN      TWIX
# CF1P          999.0      NaN       NaN      NaN       NaN      TWIX
# CM5P          999.0      NaN       NaN      NaN       NaN       RDA
#
#            THA_Cre_absCRLB  THA_tCho_absCRLB  THA_mIno_absCRLB  \
# Row.names
# BATP                  0.20              0.06              0.26
# BE9P                  0.16              0.05              0.30
# CB4P                  0.16              0.04              0.21
# CF1P                  0.20              0.05              0.25
# CM5P                  0.19              0.04              0.23
#
#            THA_tNAA_absCRLB  THA_Glu_absCRLB  THA_Gln_absCRLB  \
# Row.names
# BATP                   0.27             0.56             0.71
# BE9P                   0.24             0.47             0.57
# CB4P                   0.29             0.49             0.59
# CF1P                   0.25             0.49             0.61
# CM5P                   0.25             0.47             0.61
#
#            THA_Glx_absCRLB  THA_GABA_absCRLB  THA_Gln_Glu  ACC_Age ACC_Gender  \
# Row.names
# BATP                  0.83              0.46     0.306822     22.0          M
# BE9P                  0.75              0.34     0.250732     18.0          M
# CB4P                  0.70              0.38     0.610151     47.0          M
# CF1P                  0.78              0.42     0.378483     28.0          M
# CM5P                  0.80              0.44     0.233609     27.0          M
#
#            ACC_FWHM  ACC_SNR  ACC_Shift  ACC_Ph0  ACC_Ph1  ACC_GM  ACC_WM  \
# Row.names
# BATP        4.06692     27.0      0.052     -6.0     -4.0    84.1    10.4
# BE9P        3.45072     36.0      0.061     -6.0     -2.1    81.4    10.2
# CB4P        3.45072     31.0      0.037    -13.0     -2.0    61.4    14.4
# CF1P        2.83452     37.0      0.056      4.0     -2.5    84.3     9.3
# CM5P        4.06692     37.0      0.062    -11.0     -2.2    68.6    11.2
#
#            ACC_CSF  ACC_AllTissue    ACC_FD   ACC_FD1   ACC_FD2  ACC_fdrift  \
# Row.names
# BATP           5.5          100.0  0.136510  0.134738  0.138265    1.750276
# BE9P           8.3           99.9  0.149829  0.108921  0.190351    1.480091
# CB4P          24.2          100.0  0.857230  0.738322  0.975016    1.022036
# CF1P           6.3           99.9  0.090722  0.070974  0.110284    2.309630
# CM5P          20.2          100.0  0.284820  0.299045  0.270729    1.187371
#
#            ACC_pdrift   ACC_Cre  ACC_Cre.  ACC_tCho  ACC_tCho.   ACC_NAA  \
# Row.names
# BATP         3.493590  6.704505       2.0  1.985857        3.0  8.022819
# BE9P         5.471705  6.148470       2.0  1.633368        3.0  7.464847
# CB4P         9.553413  7.528540       2.0  1.806128        3.0  8.668303
# CF1P         5.473748  6.785043       2.0  1.703882        2.0  7.831762
# CM5P         3.428427  6.977481       2.0  1.865778        2.0  8.380123
#
#            ACC_NAA.  ACC_NAAG  ACC_NAAG.  ACC_tNAA  ACC_tNAA.  ACC_mIno  \
# Row.names
# BATP            3.0  0.683198       28.0  8.706016        2.0  5.538261
# BE9P            2.0  0.804580       17.0  8.269427        2.0  5.677018
# CB4P            2.0  0.506715       38.0  9.175018        2.0  5.816814
# CF1P            2.0  0.724912       19.0  8.556674        2.0  5.583631
# CM5P            2.0  0.448581       39.0  8.828704        2.0  5.647618
#
#            ACC_mIno.   ACC_Glu  ACC_Glu.   ACC_Gln  ACC_Gln.    ACC_Glx  \
# Row.names
# BATP             4.0  8.519283       6.0  2.275462      23.0  10.795863
# BE9P             4.0  8.138020       5.0  2.039116      20.0  10.177136
# CB4P             4.0  8.465617       6.0  2.236489      22.0  10.702105
# CF1P             4.0  8.613131       5.0  1.615809      25.0  10.228940
# CM5P             3.0  8.520387       5.0  1.045365      44.0   9.565752
#
#            ACC_Glx.  ACC_Glu_Cre  ACC_Gln_Cre  ACC_Glx_Cre  ACC_GABA  \
# Row.names
# BATP            7.0     1.421185     0.379057     1.800242  1.487157
# BE9P            6.0     1.525014     0.382694     1.907709  1.323293
# CB4P            7.0     1.560406     0.412314     1.972719  1.931071
# CF1P            6.0     1.432887     0.268737     1.702753  1.489345
# CM5P            7.0     1.615685     0.198487     1.814172  1.655382
#
#            ACC_GABA.   ACC_Asp  ACC_Asp.   ACC_Tau  ACC_Tau.   ACC_Lac  \
# Row.names
# BATP            22.0  0.884467      49.0  1.662708      18.0  0.588154
# BE9P            20.0  1.089296      33.0  1.498502      17.0  0.331976
# CB4P            17.0  1.014819      41.0  1.048137      26.0  0.606670
# CF1P            18.0  1.111080      31.0  1.543544      16.0  0.334227
# CM5P            18.0  1.243852      29.0  1.708312      16.0  0.407560
#
#            ACC_Lac.  ACC_Ala  ACC_Ala.  ACC_Asp.1  ACC_Asp..1  ACC_Scy  \
# Row.names
# BATP           40.0      0.0     999.0      0.791        49.0      0.0
# BE9P           53.0      0.0     999.0      0.945        33.0      0.0
# CB4P           39.0      0.0     999.0      0.731        41.0      0.0
# CF1P           52.0      0.0     999.0      0.984        31.0      0.0
# CM5P           55.0      0.0     999.0      0.940        29.0      0.0
#
#            ACC_Scy.  ACC_Glc  ACC_Glc.  ACC_Gua  ACC_Gua. ACC_dtype  \
# Row.names
# BATP          999.0      NaN       NaN      NaN       NaN      TWIX
# BE9P          999.0      NaN       NaN      NaN       NaN      TWIX
# CB4P          999.0      NaN       NaN      NaN       NaN      TWIX
# CF1P          999.0      NaN       NaN      NaN       NaN      TWIX
# CM5P          999.0      NaN       NaN      NaN       NaN       RDA
#
#            ACC_Asp_absCRLB  ACC_Cre_absCRLB  ACC_tCho_absCRLB  \
# Row.names
# BATP                  0.43             0.13              0.06
# BE9P                  0.36             0.12              0.05
# CB4P                  0.42             0.15              0.05
# CF1P                  0.34             0.14              0.03
# CM5P                  0.36             0.14              0.04
#
#            ACC_mIno_absCRLB  ACC_NAA_absCRLB  ACC_NAAG_absCRLB  \
# Row.names
# BATP                   0.22             0.24              0.19
# BE9P                   0.23             0.15              0.14
# CB4P                   0.23             0.17              0.19
# CF1P                   0.22             0.16              0.14
# CM5P                   0.17             0.17              0.17
#
#            ACC_tNAA_absCRLB  ACC_Glu_absCRLB  ACC_Gln_absCRLB  \
# Row.names
# BATP                   0.17             0.51             0.52
# BE9P                   0.17             0.41             0.41
# CB4P                   0.18             0.51             0.49
# CF1P                   0.17             0.43             0.40
# CM5P                   0.18             0.43             0.46
#
#            ACC_Glx_absCRLB  ACC_GABA_absCRLB  ACC_Tau_absCRLB  \
# Row.names
# BATP                  0.76              0.33             0.30
# BE9P                  0.61              0.26             0.25
# CB4P                  0.75              0.33             0.27
# CF1P                  0.61              0.27             0.25
# CM5P                  0.67              0.30             0.27
#
#            ACC_Lac_absCRLB  ACC_Gln_Glu       PC1       PC2       PC3  \
# Row.names
# BATP                  0.24     0.267095  2.008555 -1.048664  0.559707
# BE9P                  0.18     0.250567  2.276005 -1.557010  1.314098
# CB4P                  0.24     0.264185 -1.256346 -0.947071  0.006429
# CF1P                  0.17     0.187598  0.858412  0.704895  0.354106
# CM5P                  0.22     0.122690  0.931804 -0.922405 -0.224390
#
#                 PC4       PC5       PC6     PC6.1       PC8
# Row.names
# BATP       0.906298 -0.596420  0.433480 -0.135150 -0.179630
# BE9P       0.150499 -0.716511  0.053209 -0.359599 -0.104390
# CB4P      -2.090284  0.543071  0.202032  0.303029 -0.510440
# CF1P       1.344103  1.102583  0.330716 -0.051823  0.222566
# CM5P      -0.609950  0.048330 -0.629096 -0.157840  0.051519

# %%
def detect_outlier_subjects(df,measure,m=2):
    upper = np.mean(df[measure]) + m * np.std(df[measure])
    lower = np.mean(df[measure]) - m * np.std(df[measure])

    for subject in df.index:
        if df.loc[subject][measure] > upper:
            print subject
        elif df.loc[subject][measure] < lower:
            print subject

def grubbs_outliers(df, measure, alpha = 0.15):
    from outliers import smirnov_grubbs as grubbs
    return [str(i) for i in df.index if i not in grubbs.test(df[measure], alpha).index] 

def reject_outliers(data, m=3):
    return data[abs(data - np.mean(data)) < m * np.std(data)]


def gESD_outliers(df, measure, maxOLs =10, alpha = 0.05):
    from PyAstronomy import pyasl
    index = pyasl.generalizedESD(df[measure],maxOLs = maxOLs, alpha =alpha, fullOutput=True)[1]
    return [df.index[i] for i in index] 

def gESD_outliersx(df, maxOLs =10, alpha = 0.05):
    from PyAstronomy import pyasl
    index = pyasl.generalizedESD(df,maxOLs = maxOLs, alpha =alpha, fullOutput=True)[1]
    return [df.index[i] for i in index] 

def sortdf(df,m):
    return df.sort(m)[m]
 
def plot_partial_correlation(data, x, y,xlim = None, ylim = None, regressors = None, color = None, annotate = 0, fig_name = None, 
                             dpi = 100, labels = True, jitter = None,fit_reg=True, scatter=1,
                             plot_marg = 1, ci = 95, lstyle='-',lw=2.5):
    
    regressors_columns = [data[regressor] for regressor in regressors]
    df_reg = pd.concat(regressors_columns, axis = 1).dropna(axis=0) 
    df = pd.concat([df_reg, data[x], data[y]], axis=1).dropna()
    
    # inititlize grid and plot regression and margins 
    grid = sns.JointGrid(x, y, data=df,xlim=xlim, ylim=ylim)#, size=size, ratio=ratio, space=space, #) 
    
    if plot_marg:
        grid.plot_marginals(sns.distplot, color = color, hist=False, kde = True, rug = 0, kde_kws={'shade':True})  
    
    grid.plot_joint(sns.regplot, fit_reg=fit_reg, scatter= scatter, color = color, x_partial = df[regressors], y_jitter = jitter, 
                    ci = ci, line_kws={'linestyle': lstyle, 'lw':lw}, scatter_kws={"s": 25})
    if labels:
        grid.set_axis_labels()
        #grid.set_axis_labels(x, y, fontsize= 15, weight='bold', color='blue', labelpad=10)
    else:
        grid.set_axis_labels()
    
    ## calculate regression parameters 
    
    formula = [ '%s ~ %s'%(y,x) + ' + %s'%regressor for regressor in regressors][0]
    model   = smf.ols(formula=formula, data= df)
    result = model.fit() 
    p_val  = np.round(result.pvalues[1], 7)
    pcor   = math.copysign(np.round(np.sqrt(result.rsquared), 3) , result.params[1])
    plt.ylabel(y)
    plt.xlabel(x)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    
    if annotate == 1:
        annotate = (plt.xlim()[1]*0.6,  plt.ylim()[1]*0.95)
        plt.annotate('R=%s, P=%s' %(pcor, p_val), xy = annotate, fontsize = 13,  color='r')
    elif annotate == 0:
        pass
    else:
        plt.annotate('R=%s, P=%s' %(pcor, p_val), xy = annotate, fontsize = 13,  color='r')
    
    grid.set_axis_labels()
    plt.xticks(fontsize=12, weight='bold')
    plt.yticks(fontsize=12, weight='bold')
    
    if fig_name:
        plt.savefig(os.path.join(save_fig_dir, fig_name), dpi = dpi, bbox_inches='tight', transparent = True)
    

    print pcor, p_val
    return result

# %%
sns.palplot(sns.color_palette("Blues"))
bmap = sns.color_palette("Blues")

# %%
sns.palplot(sns.cubehelix_palette(8))
cube = sns.cubehelix_palette(8)

# %%
sns.palplot(sns.color_palette("coolwarm", 7))
coolwarm = sns.color_palette("coolwarm", 7)

# %%
sns.palplot(sns.color_palette("BrBG", 7))
bgmap = sns.color_palette("BrBG", 7)

# %%
sns.palplot(sns.color_palette("hls", 8))
sns.palplot(sns.color_palette("Paired"))

blue = sns.color_palette("Paired")[1]
green = sns.color_palette("Paired")[3]
red = sns.color_palette("Paired")[5]

# %% [markdown]
# # Correlation Matrix

# %%
df = patients.drop([], axis = 0 )
cln_metrics = [df['CLN_YGTSS_Motoric_Score'],
               df['CLN_YGTSS_Vocal_Score'], 
               df['CLN_RVTRS'],
               df['CLN_puts'],
               df['CLN_qol_score'],
               df['CLN_DSM4_ADHD_Score'], 
               df['CLN_CAARS_Score_ADHS_Symptoms_Total_Cat_G_T_Score'], 
               df['CLN_YBOCS_Totalscore_Items_1to10'],  
               df['CLN_OCIR_total_score'],
               df['CLN_BDI12'],  
               #df['CLN_BAI'],  
               df['CLN_MADRS'],
              ]

df = pd.concat(cln_metrics,  axis=1)
corr = df.corr('spearman')
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask, k = 1)] = True
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
cmap = 'seismic'
sns.heatmap(corr, cmap = cmap ,
            mask=mask,square=True, vmin = -.7, vmax = .7,
            linewidths=.5, cbar_kws={"shrink": 1}, ax=ax, annot = True, annot_kws={"size":15})
ticks  =  [x + .5 for x in range(0,11)]
labelx = ['YGTSS-Motor', 'YGTSS-Vocal', 'RVTRS', 'PUTS', 'QOL', 'DSM4-ADHD', 'CAARS','Y-BOCS', 'OCI-R', 'BDI-12', 'MADRS']
plt.xticks(ticks, labelx, fontsize = 15, weight='bold')
plt.yticks(ticks[::-1], labelx, fontsize = 15, weight='bold')
# Out:
# ([<matplotlib.axis.YTick at 0x11e30a810>,
#   <matplotlib.axis.YTick at 0x11e30ab10>,
#   <matplotlib.axis.YTick at 0x11e371850>,
#   <matplotlib.axis.YTick at 0x11e371dd0>,
#   <matplotlib.axis.YTick at 0x11e367510>,
#   <matplotlib.axis.YTick at 0x11de8e2d0>,
#   <matplotlib.axis.YTick at 0x11e38a290>,
#   <matplotlib.axis.YTick at 0x11e38a990>,
#   <matplotlib.axis.YTick at 0x11e3960d0>,
#   <matplotlib.axis.YTick at 0x11e3967d0>,
#   <matplotlib.axis.YTick at 0x11e396ed0>],
#  <a list of 11 Text yticklabel objects>)

# %% [markdown]
# # MOTOR

# %%
df = patients
df['PC2'] = df['PC2'] * -1

detect_outlier_subjects(df,'PC2',m=2)

plot_partial_correlation(df.drop([],axis=0), 
                        'PC2', 'ALL', 
                         xlim = None,#(-.6,.6), 
                         ylim = None, regressors = ['Age','Gender','QC_PCA'], 
                         color = red, #annotate = (.23,0.3),
                         dpi = 100, labels = 0, jitter = 0.0001,fit_reg=True, scatter=1,
                         plot_marg = 1, ci = 95, lstyle='-',lw=2.5,
                         fig_name = 'clinical_PCA_chi_tics.png'
                        )
# Out:
# HHQP
# -0.424 0.0721065

# %%
df = patients
df['PC1'] = df['PC2'] * -1

detect_outlier_subjects(df,'PC2',m=2)

plot_partial_correlation(df.drop([],axis=0), 
                        'PC2', 'ALL', 
                         xlim = None,#(-.6,.6), 
                         ylim = None, regressors = ['Age','Gender','QC_PCA'], 
                         color = red, #annotate = (.23,0.3),
                         dpi = 100, labels = 0, jitter = 0.0001,fit_reg=True, scatter=1,
                         plot_marg = 1, ci = 95, lstyle='-',lw=2.5,
                         fig_name = 'clinical_PCA_chi_tics.png'
                        )

# %%
# Take PCA of quality metrics
from sklearn.decomposition import TruncatedSVD, KernelPCA
df = patients.drop([], axis = 0 )
cln_metrics = ['CLN_YGTSS_Motoric_Score',
               'CLN_YGTSS_Vocal_Score',#, 
               #'CLN_YGTSS_Total_Score_incl_Impairment',
               #'CLN_YGTSS_Total_Tic_Score',
               'CLN_RVTRS',
               #'CLN_qol_score',
               'CLN_puts',
               'CLN_DSM4_ADHD_Score',
               #'CLN_CAARS_Score_ADHS_Symptoms_Total_Cat_G_T_Score',
               #'CLN_YBOCS_Totalscore_Items_1to10', 
               'CLN_OCIR_total_score',
               #'CLN_BAI', 
               'CLN_BDI12', 
               'CLN_MADRS'
              ]

#df = pd.concat([df[cln] for cln in cln_metrics], axis = 1).dropna()
#df = pd.concat([df,patients.ALL, patients.Age, patients.Gender, patients.QC_PCA], axis =1)

pca = PCA(n_components=8)
#data = np.array(np.asarray([df[cln] for cln in cln_metrics]))
data = np.array(np.asarray([preprocessing.scale(df[cln]) for cln in cln_metrics]))
pca.fit(data)
df['CLN_PCA'] = pca.components_[1, :] *-1#pca_mult
print 'CLN PC1 explained variance:',pca.explained_variance_ratio_
var =  pca.explained_variance_ratio_[0] + pca.explained_variance_ratio_[1] + pca.explained_variance_ratio_[2] 
print 'explained variance by PC1,2,3=',var
print ''
detect_outlier_subjects(df,'CLN_PCA',m=2)

plot_partial_correlation(df.drop(['BE9P', 'RL7P'],axis=0), 
                        'CLN_PCA', 'ALL', 
                         xlim = (-.6,.6), 
                         ylim = None, regressors = ['Age','Gender','QC_PCA'], 
                         color = red, #annotate = (.23,0.3),
                         dpi = 100, labels = 0, jitter = 0.0001,fit_reg=True, scatter=1,
                         plot_marg = 1, ci = 95, lstyle='-',lw=2.5,
                         fig_name = 'clinical_PCA_chi_tics.png'
                        )
for i in cln_metrics:
    print i, np.round(pearsonr(df.CLN_PCA, df[i])[0],2), np.round(pearsonr(df.CLN_PCA, df[i])[1],4)

# %%
plt.plot(range(1,9) , pca.explained_variance_)
plt.ylim(0,5)

# %%
df.CLN_PCA
# Out:
# BE9P    0.181570
# HJEP    0.119471
# RMJP   -0.445075
# BATP    0.062081
# LT5P   -0.253146
# CM5P    0.251838
# CF1P   -0.173374
# SM6U    0.229729
# RL7P   -0.191284
# EB2P    0.119362
# SGKP   -0.036787
# HHQP   -0.421211
# SA5U    0.058133
# THCP    0.055568
# PC5P    0.150523
# SBQP   -0.108426
# TT3P    0.174040
# NT6P    0.094366
# CB4P    0.186855
# YU1P    0.046711
# RA9P    0.256599
# SULP   -0.357561
# KDDP    0.000017
# Name: CLN_PCA, dtype: float64

# %%
df.ALL.sort_values()
# Out:
# SM6U     29.82075
# PC5P     32.08300
# BE9P     39.86975
# YU1P     46.13650
# LT5P     50.66750
# NT6P     51.76525
# CM5P     51.87500
# HJEP     57.61400
# KDDP     58.22600
# EB2P     58.31400
# BATP     60.42875
# TT3P     60.97450
# SA5U     61.21525
# RMJP     63.81950
# HHQP     64.62225
# SGKP     64.69900
# THCP     65.11825
# RA9P     66.65850
# CB4P     82.44775
# CF1P     83.56725
# SBQP     88.33800
# SULP     94.14075
# RL7P    110.38825
# Name: ALL, dtype: float64

# %%
csv = pd.read_csv('/Users/kanaan/Desktop/CSV.csv', index_col=0)
csv.ALL

# %%
plot_partial_correlation(csv.drop(['RMJP'],axis=0), 
                        'FAC1_1', 'ALL', 
                         xlim = None,#(-8,8), 
                         ylim = None, regressors = ['Age','QC_PCA'], 
                         color = red, #annotate = (.23,0.3),
                         dpi = 100, labels = 0, jitter = 0.0001,fit_reg=True, scatter=1,
                         plot_marg = 1, ci = 95, lstyle='-',lw=2.5,
                        )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-179-79994c3d2b9c> in <module>()
#       5                          color = red, #annotate = (.23,0.3),
#       6                          dpi = 100, labels = 0, jitter = 0.0001,fit_reg=True, scatter=1,
# ----> 7                          plot_marg = 1, ci = 95, lstyle='-',lw=2.5,
#       8                         )
#
# <ipython-input-3-9373dd67f60f> in plot_partial_correlation(data, x, y, xlim, ylim, regressors, color, annotate, fig_name, dpi, labels, jitter, fit_reg, scatter, plot_marg, ci, lstyle, lw)
#      42
#      43     if plot_marg:
# ---> 44         grid.plot_marginals(sns.distplot, color = color, hist=False, kde = True, rug = 0, kde_kws={'shade':True})
#      45
#      46     grid.plot_joint(sns.regplot, fit_reg=fit_reg, scatter= scatter, color = color, x_partial = df[regressors], y_jitter = jitter,
#
# /Users/kanaan/anaconda/lib/python2.7/site-packages/seaborn/axisgrid.pyc in plot_marginals(self, func, **kwargs)
#    1750         kwargs["vertical"] = False
#    1751         plt.sca(self.ax_marg_x)
# -> 1752         func(self.x, **kwargs)
#    1753
#    1754         kwargs["vertical"] = True
#
# /Users/kanaan/anaconda/lib/python2.7/site-packages/seaborn/distributions.pyc in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     219     if kde:
#     220         kde_color = kde_kws.pop("color", color)
# --> 221         kdeplot(a, vertical=vertical, ax=ax, color=kde_color, **kde_kws)
#     222         if kde_color != color:
#     223             kde_kws["color"] = kde_color
#
# /Users/kanaan/anaconda/lib/python2.7/site-packages/seaborn/distributions.pyc in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, ax, **kwargs)
#     575         ax = plt.gca()
#     576
# --> 577     data = data.astype(np.float64)
#     578     if data2 is not None:
#     579         data2 = data2.astype(np.float64)
#
# ValueError: could not convert string to float:

# %%
# Take PCA of quality metrics
from sklearn.decomposition import TruncatedSVD, KernelPCA
df = patients.drop(['SA5U'], axis = 0 )
cln_metrics = ['CLN_YGTSS_Motoric_Score',
               'CLN_YGTSS_Vocal_Score',#, 
               'CLN_RVTRS',
               'CLN_puts',
               #'CLN_DSM4_ADHD_Score',
               #'CLN_YBOCS_Totalscore_Items_1to10', 
               #'CLN_OCIR_tota_score',
               #'CLN_BDI12', 
               #'CLN_BAI', 
               #'CLN_MADRS'
              ]
pca = PCA(n_components=4)
data = np.array(np.asarray([df[cln] for cln in cln_metrics]))
data = np.array(np.asarray([preprocessing.scale(df[cln]) for cln in cln_metrics]))
pca.fit(data)
df['CLN_PCA'] = pca.components_[0, :] *pca_mult
print 'CLN PC1 explained variance:',pca.explained_variance_ratio_

detect_outlier_subjects(df,'CLN_PCA',m=2)

plot_partial_correlation(df.drop([],axis=0), 
                        'CLN_PCA', 'CLN_Ferritin', 
                         xlim = (-8,8), 
                         ylim = None, regressors = ['Age','Gender','QC_PCA'], 
                         color = red, #annotate = (.23,0.3),
                         dpi = 100, labels = 0, jitter = 0.0001,fit_reg=True, scatter=1,
                         plot_marg = 1, ci = 95, lstyle='-',lw=2.5,
                         fig_name = 'clinical_PCA_cln_tics.png'
                        )

for i in cln_metrics:
    print i, pearsonr(df.CLN_PCA, df[i])
# Out:
# CLN PC1 explained variance: [  4.89040133e-01   2.81932890e-01   2.29026977e-01   1.51450051e-32]
# -0.474 0.132286
# CLN_YGTSS_Motoric_Score (-0.2978946453373672, 0.1781419334333284)
# CLN_YGTSS_Vocal_Score (-0.37946994986073546, 0.08154189994048501)
# CLN_RVTRS (-0.5773761894638596, 0.0048976013270154032)
# CLN_puts (0.7596926085282405, 4.1104983234231749e-05)

# %%
df.CLN_Ferritin
# Out:
# BE9P     86.07
# HJEP     76.43
# RMJP       NaN
# BATP     50.67
# LT5P    120.10
# CM5P     42.69
# CF1P     20.51
# SM6U    124.60
# RL7P     48.19
# EB2P     73.03
# SGKP       NaN
# HHQP    182.40
# THCP    117.10
# PC5P     31.87
# SBQP       NaN
# TT3P       NaN
# NT6P     51.63
# CB4P       NaN
# YU1P       NaN
# RA9P       NaN
# SULP    183.80
# KDDP     74.30
# Name: CLN_Ferritin, dtype: float64

# %%
df.CLN_PCA.sort_values()
# Out:
# RMJP   -4.786096
# LT5P   -3.409057
# CF1P   -3.096862
# SBQP   -2.721642
# SGKP   -1.452640
# HHQP   -1.361721
# SULP   -1.199666
# EB2P   -0.397416
# YU1P    0.054513
# CB4P    0.151161
# SA5U    0.151161
# BE9P    0.388942
# NT6P    0.404135
# TT3P    0.526468
# KDDP    0.599200
# PC5P    1.122265
# SM6U    1.574894
# THCP    1.678340
# BATP    2.476087
# CM5P    2.623232
# HJEP    3.153096
# RA9P    3.521604
# Name: CLN_PCA, dtype: float64

# %% [markdown]
# # Non-Motor

# %%
# Take PCA of quality metrics
from sklearn.decomposition import TruncatedSVD, KernelPCA
df = patients.drop(['RL7P'], axis = 0 )
df = pd.concat([controls, patients.drop(['RL7P'], axis = 0 )])
cln_metrics = ['CLN_YGTSS_Motoric_Score',
               'CLN_YGTSS_Vocal_Score',#, 
               #'CLN_RVTRS',
               'CLN_puts',
               #'CLN_qol_score',
               'CLN_DSM4_ADHD_Score',
               'CLN_YBOCS_Totalscore_Items_1to10', 
               #'CLN_OCIR_tota_score',
               'CLN_BDI12', 
               'CLN_BAI', 
               #'CLN_MADRS'
              ]
pca = PCA(n_components=5)
data = np.array(np.asarray([df[cln] for cln in cln_metrics]))
data = np.nannp.array(np.asarray([preprocessing.scale(df[cln]) for cln in cln_metrics]))
pca.fit(data)
df['CLN_PCA'] = pca.components_[3, :] * -1
print 'CLN PC1 explained variance:',pca.explained_variance_ratio_

detect_outlier_subjects(df,'CLN_PCA',m=2)

plot_partial_correlation(df.drop(['HHQP'],axis=0), 
                        'CLN_PCA', 'ALL', 
                         xlim = None,#(-7,7), 
                         ylim = None, regressors = ['Age','Gender','QC_PCA'], 
                         color = green, annotate = (.23,0.3),
                         dpi = 100, labels = 0, jitter = 0.0001,fit_reg=True, scatter=1,
                         plot_marg = 1, ci = 95, lstyle='-',lw=2.5,
                         fig_name = 'clinical_PCA_chi_comorbid.png'
                        )
print ''
for i in cln_metrics:
    print i, np.round(pearsonr(df.CLN_PCA, df[i])[0],2), np.round(pearsonr(df.CLN_PCA, df[i])[1],4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-119-6486d06175c5> in <module>()
#      17 pca = PCA(n_components=5)
#      18 data = np.array(np.asarray([df[cln] for cln in cln_metrics]))
# ---> 19 data = np.nan_to_num(np.array(np.asarray([preprocessing.scale(df[cln]) for cln in cln_metrics])))
#      20 pca.fit(data)
#      21 df['CLN_PCA'] = pca.components_[3, :] * -1
#
# /Users/kanaan/anaconda/lib/python2.7/site-packages/sklearn/preprocessing/data.pyc in scale(X, axis, with_mean, with_std, copy)
#     127     X = check_array(X, accept_sparse='csc', copy=copy, ensure_2d=False,
#     128                     warn_on_dtype=True, estimator='the scale function',
# --> 129                     dtype=FLOAT_DTYPES)
#     130     if sparse.issparse(X):
#     131         if with_mean:
#
# /Users/kanaan/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     405                              % (array.ndim, estimator_name))
#     406         if force_all_finite:
# --> 407             _assert_all_finite(array)
#     408
#     409     shape_repr = _shape_repr(array.shape)
#
# /Users/kanaan/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in _assert_all_finite(X)
#      56             and not np.isfinite(X).all()):
#      57         raise ValueError("Input contains NaN, infinity"
# ---> 58                          " or a value too large for %r." % X.dtype)
#      59
#      60
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
for i in cln_metrics:
    print i, pearsonr(df.CLN_PCA, df[i])
# Out:
# CLN_DSM4_ADHD_Score (0.27956641532929988, 0.20765198863519904)
# CLN_YBOCS_Totalscore_Items_1to10 (-0.76814253151379308, 2.9860122104191096e-05)
# CLN_OCIR_tota_score (-0.15898176121643348, 0.47976687684477159)
# CLN_BDI12 (0.54121906654890473, 0.0092906730846105384)
# CLN_BAI (0.46706494883930527, 0.028412112417341383)
# CLN_MADRS (0.73136434651869131, 0.00011003816296986397)

# %%
print np.dot( pca.components_[0], (df.CLN_puts / np.linalg.norm(df.CLN_puts)))
print np.dot( pca.components_[0], (df.CLN_YGTSS_Vocal_Score / np.linalg.norm(df.CLN_puts)))
print np.dot( pca.components_[0], (df.CLN_YGTSS_Motoric_Score / np.linalg.norm(df.CLN_puts)))
print np.dot( pca.components_[0], (df.CLN_RVTRS / np.linalg.norm(df.CLN_puts)))
# Out:
# 0.227335758081
# -0.109388409422
# -0.0643483584328
# -0.137530767107

# %%
for i in cln_metrics:
    sns.jointplot(df['CLN_PCA'], df[i], kind = 'reg')

# %%
pca.components_[0]
# Out:
# array([ 0.00636007,  0.32677988, -0.52121587,  0.23380396,  0.26557884,
#        -0.3542912 ,  0.14983221, -0.06319706, -0.17970005, -0.15770385,
#         0.00306182,  0.15759138,  0.10371981, -0.31247773,  0.03948043,
#         0.03745313,  0.00306182,  0.00145386,  0.35704728, -0.14530874,
#         0.04866998])

# %%
# Take PCA of quality metrics
from sklearn.decomposition import TruncatedSVD, KernelPCA
df = patients.drop([], axis = 0 )
cln_metrics = ['CLN_YGTSS_Motoric_Score',
               'CLN_YGTSS_Vocal_Score',#, 
               #'CLN_RVTRS',
               'CLN_puts',
               #'CLN_DSM4_ADHD_Score',
               #'CLN_YBOCS_Totalscore_Items_1to10', 
               #'CLN_OCIR_tota_score',
               #'CLN_BDI12', 
               #'CLN_BAI', 
               #'CLN_MADRS'
              ]
pca = PCA(n_components=3)
data = np.array(np.asarray([df[cln] for cln in cln_metrics]))
#data = np.array(np.asarray([preprocessing.scale(df[cln]) for cln in cln_metrics]))
pca.fit(data)
df['CLN_PCA'] = pca.components_[0, :] *pca_mult
print 'CLN PC1 explained variance:',pca.explained_variance_ratio_

pca = PCA(n_components=3)
chi_vars = ['L_Caud','L_Puta','L_Pall','L_SN','L_STN']
chi_vars = ['Caud','Puta','Pall','SN','STN', 'DN']
pca.fit(np.array(np.asarray([df[chi] for chi in chi_vars])))
df['BG_PCA'] = pca.components_[0, :] *pca_mult
print 'BG PC1 explained variance:',pca.explained_variance_ratio_

detect_outlier_subjects(df,'BG_PCA',m=2)
detect_outlier_subjects(df,'CLN_PCA',m=2)

plot_partial_correlation(df.drop(['RL7P', 'LT5P'], axis = 0), 
                        'CLN_PCA', 'ALL', 
                         xlim = (-7,7), 
                         ylim = None, regressors = ['Age','Gender','QC_PCA'], 
                         color = blue, annotate = (.23,0.3),
                         dpi = 100, labels = 0, jitter = 0.0001,fit_reg=True, scatter=1,
                         plot_marg = 1, ci = 95, lstyle='-',lw=2.5,
                         fig_name = 'clinical_PCA_chi_tics.png'
                        )

# %%
# Take PCA of quality metrics
from sklearn.decomposition import TruncatedSVD
df = patients.drop([], axis = 0 )
cln_metrics = ['CLN_YGTSS_Motoric_Score',
               'CLN_YGTSS_Vocal_Score',#, 
               #'CLN_RVTRS',
               'CLN_puts',
               #'CLN_DSM4_ADHD_Score',
               #'CLN_YBOCS_Totalscore_Items_1to10', 
               #'CLN_OCIR_tota_score',
               #'CLN_BDI12', 
               #'CLN_BAI', 
               #'CLN_MADRS'
              ]
pca = PCA(n_components=3)
data = np.array(np.asarray([df[cln] for cln in cln_metrics]))
data = np.array(np.asarray([preprocessing.scale(df[cln]) for cln in cln_metrics]))
pca.fit_transform(data)
df['CLN_PCA1'] = pca.components_[0, :] *pca_mult
df['CLN_PCA2'] = pca.components_[1, :] *pca_mult
df['CLN_PCA3'] = pca.components_[2, :] *pca_mult
print 'CLN PC1 explained variance:',pca.explained_variance_ratio_
# Out:
# CLN PC1 explained variance: [  6.37032956e-01   3.62967044e-01   1.73082161e-32]

# %%
plt.scatter(df['CLN_PCA1'].sort_index(), df['CLN_PCA2'].sort_index())

# %%
np.array(df['CLN_PCA1'].sort_index()).T
# Out:
# array([  2.53076113e+00,   4.05648316e-01,  -3.99313633e-03,
#         -3.03459073e+00,   2.50079478e+00,  -3.99412766e-01,
#         -1.41518360e+00,   2.99975789e+00,   4.87097715e-01,
#         -3.46173310e+00,   2.27447313e-01,   9.98919264e-01,
#          3.55117444e+00,   1.09459049e+00,  -4.80897508e+00,
#         -3.99313633e-03,  -2.71348493e+00,  -1.47839539e+00,
#          1.62640604e+00,  -1.24695494e+00,   1.60216256e+00,
#          5.34564980e-01,   7.39191173e-03])

# %%
pca = PCA(n_components=3)
data = np.array(np.asarray([df[cln] for cln in cln_metrics]))
data = np.array(np.asarray([preprocessing.scale(df[cln]) for cln in cln_metrics]))
pca.fit(data)
#plt.scatter(pca.components_[0, :],pca.components_[1, :] )
sns.barplot([0,1,2], pca.explained_variance_)

# %%
sns.jointplot(pca.components_[0, :], df.CLN_YGTSS_Motoric_Score, kind = 'reg')

# %%
from sklearn.decomposition import FactorAnalysis

fa_naive = FactorAnalysis(1)
fa_naive.fit(data)
fa_naive.components_, fa_naive.noise_variance_
# Out:
# (array([[ 0.14731241,  0.79067449, -1.26942656,  0.71259537, -0.90885169,
#           0.66646458, -0.77347064,  0.45942195, -0.08354845, -0.36961336,
#          -0.36856675, -0.00517322,  0.44035734,  0.26854073, -0.69657133,
#           0.1620527 ,  0.04629875, -0.00517322,  0.00258704,  0.96920475,
#          -0.31814138,  0.13302648]]),
#  array([  2.85423785e-01,   3.03895132e-01,   2.79633672e-06,
#           4.57453388e-01,   3.27071301e-03,   1.25221721e-01,
#           3.35206138e-01,   2.55001321e-01,   6.98850699e-02,
#           3.58253022e-02,   8.06082772e-03,   2.99861432e-01,
#           3.31593597e-03,   1.23925957e-01,   9.32609441e-02,
#           7.36143725e-02,   5.42529801e-01,   2.99861432e-01,
#           2.06242306e-02,   1.81667489e-01,   1.88495961e-07,
#           9.80975638e-02]))

# %%
# Take PCA of quality metrics
from sklearn.decomposition import TruncatedSVD, KernelPCA
df = patients.drop(['RL7P'], axis = 0 )
cln_metrics = [#'CLN_YGTSS_Motoric_Score',
               #'CLN_YGTSS_Vocal_Score',#, 
               #'CLN_RVTRS',
               #'CLN_puts',
               'CLN_DSM4_ADHD_Score',
               'CLN_YBOCS_Totalscore_Items_1to10', 
               'CLN_OCIR_tota_score',
               'CLN_BDI12', 
               'CLN_BAI', 
               #'CLN_MADRS'
              ]
pca = PCA(n_components=3)
data = np.array(np.asarray([df[cln] for cln in cln_metrics]))
data = np.array(np.asarray([preprocessing.scale(df[cln]) for cln in cln_metrics]))
pca.fit(data)
df['CLN_PCA'] = pca.components_[0, :] * -1
print 'CLN PC1 explained variance:',pca.explained_variance_ratio_

detect_outlier_subjects(df,'CLN_PCA',m=2)

plot_partial_correlation(df.drop(['HHQP'],axis=0), 
                        'CLN_PCA', 'ALL', 
                         xlim = None,#(-7,7), 
                         ylim = None, regressors = ['Age','Gender','QC_PCA'], 
                         color = blue, annotate = (.23,0.3),
                         dpi = 100, labels = 0, jitter = 0.0001,fit_reg=True, scatter=1,
                         plot_marg = 1, ci = 95, lstyle='-',lw=2.5,
                         fig_name = 'clinical_PCA_chi_nonmotor.png'
                        )
# Out:
# CLN PC1 explained variance: [ 0.43090404  0.28275363  0.20105414]
# HHQP
# -0.421 0.1885587

# %%
dfx = pd.concat([patients, controls])
pca.fit(np.array(np.asarray([dfx[qc] for qc in ['QI1_MAG', 'EFC_MAG', 'FWHM_MAG']])))
dfx['XX'] = pca.components_[0, :] *pca_mult
print 'PC1 explained variance:',pca.explained_variance_ratio_
# Out:
# PC1 explained variance: [  9.99792883e-01   2.07117194e-04   7.85829438e-33]

# %%
sns.distplot(df.CLN_DSM4_ADHD_Score)
sns.distplot(df.CLN_YBOCS_Totalscore_Items_1to10)
sns.distplot(df.CLN_OCIR_tota_score)
sns.distplot(df.CLN_BDI12)

# %%
df.CLN_YBOCS_Totalscore_Items_1to10
# Out:
# BE9P     0.0
# HJEP     6.0
# RMJP     0.0
# BATP     0.0
# LT5P     0.0
# CM5P     0.0
# CF1P     0.0
# SM6U     0.0
# EB2P     0.0
# SGKP     0.0
# HHQP    12.0
# SA5U     0.0
# THCP     0.0
# PC5P     0.0
# SBQP     0.0
# TT3P     0.0
# NT6P     0.0
# CB4P     0.0
# YU1P     0.0
# RA9P    10.0
# SULP     4.0
# KDDP     0.0
# Name: CLN_YBOCS_Totalscore_Items_1to10, dtype: float64

# %%
sns.distplot(df.CLN_DSM4_ADHD_Score)
#sns.distplot(df.CLN_RVTRS)
#sns.distplot(df.CLN_YGTSS_Vocal_Score)
sns.distplot(df.CLN_YGTSS_Motoric_Score)

# %%
sns.distplot(preprocessing.scale(df.CLN_puts))
sns.distplot(preprocessing.scale(df.CLN_RVTRS))
sns.distplot(preprocessing.scale(df.CLN_YGTSS_Vocal_Score))
sns.distplot(preprocessing.scale(df.CLN_YGTSS_Motoric_Score))
