# %%
# %matplotlib inline
import os
import math 
import numpy as np
import pandas as pd 
import seaborn as sns
import random
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
from scipy.stats import pearsonr, spearmanr, gaussian_kde
from sklearn import preprocessing
from sklearn.decomposition import TruncatedSVD, PCA
from sklearn.cross_decomposition import PLSRegression
from sklearn.preprocessing import scale, StandardScaler
from statsmodels.sandbox.stats.multicomp import fdrcorrection0
from matplotlib.colors import rgb2hex
import warnings
sns.set_style('white')
pd.options.display.max_rows = 5000
pd.options.display.max_columns = 999
warnings.filterwarnings('ignore')

ahba_dir     = '/Users/kanaaax/Google Drive/TS-EUROTRAIN/RESULTS_QSMv3/dataframes/AHBA/'
gsea_dir     = '/Users/kanaaax/Desktop/GSEA'
permute_dir  = '/Users/kanaaax/Google Drive/TS-EUROTRAIN/RESULTS_QSMv3/dataframes/permutations'
save_fig_dir = '/Users/kanaaax/Google Drive/TS-EUROTRAIN/Papers/2019_QSM_paper/Figures_python_v4'

background_genes = pd.read_csv(os.path.join(ahba_dir,'background_gene_list.txt'), sep='\t').GeneSymbol.values

# %%
#cmaps
from matplotlib import colors
cmap_drysdale = colors.ListedColormap(['#00ffff', '#00afff','#0000ff', '#260000', '#530000','#fe0000', '#ff6a00', '#ffff00'])
cmap_ted = colors.ListedColormap(['#00ffff', '#00afff','#0000ff', '#260000', '#530000','#fe0000', '#ff6a00','#ffff00', '#ffffff'])
cmap_rdbu = colors.ListedColormap(['#d73027', '#fc8d59', '#fee090', '#e0f3f8', '#91bfdb', '#4575b4'][::-1])
cmap_rdbu2 = colors.ListedColormap(['#cb1a1e', '#e1817f', '#f1bebe', '#e0f3f8', '#91bfdb', '#4575b4'][::-1])

first = int((128*2)-np.round(255*(1.-0.50)))
second = (256-first)
colors2 = plt.cm.viridis(np.linspace(0.2, .98, first))
colors3 = plt.cm.YlOrRd(np.linspace(0.3, 0.8, second))
colors4 = plt.cm.PuBu(np.linspace(0., 0.25, second))

colors2 = plt.cm.viridis(np.linspace(0.3, 1, first))
colors3 = plt.cm.hot_r(np.linspace(0.3, 0.7, second))

cols = np.vstack((colors2,colors3))
cmap_gradient = colors.LinearSegmentedColormap.from_list('my_colormap', cols)

num = 256
gradient = range(num)
for x in range(5):
    gradient = np.vstack((gradient, gradient))

fig, ax = plt.subplots(nrows=1)
ax.imshow(gradient, cmap=cmap_gradient, interpolation='nearest')
ax.set_axis_off()
fig.tight_layout()

plt.show()

# %%
def return_pls(samples,features, nuc):

    pls1 = pd.read_csv(os.path.join(ahba_dir, 'ahba_data/stats/%snuc_PLS1_weights_%s_chi_%s.csv'%(nuc,samples,features)), header=None).set_index(0)
    pls2 = pd.read_csv(os.path.join(ahba_dir, 'ahba_data/stats/%snuc_PLS2_weights_%s_chi_%s.csv'%(nuc,samples,features)), header=None).set_index(0)
    pls3 = pd.read_csv(os.path.join(ahba_dir, 'ahba_data/stats/%snuc_PLS3_weights_%s_chi_%s.csv'%(nuc,samples,features)), header=None).set_index(0)

    del pls1.index.name
    del pls2.index.name
    del pls3.index.name
    
    
    for df in [pls1,pls2,pls3]:
        
        q1=np.quantile(df[2], 0.05)
        q2=np.quantile(df[2], 0.95)
        
        df['quantiles']      = [i if i < q1 or i > q2 else np.nan for i in df[2]]
        df['non_quantiles']  = [np.nan if i < q1 or i > q2 else i for i in df[2]]
    
    return pls1, pls2, pls3

    
def return_score(samples,features,nuc):

    pls1 = pd.read_csv(os.path.join(ahba_dir, 'ahba_data/stats/%snuc_PLS1_scores_%s_chi%s.csv'%(nuc,samples,features)), header=None)
    pls2 = pd.read_csv(os.path.join(ahba_dir, 'ahba_data/stats/%snuc_PLS2_scores_%s_chi%s.csv'%(nuc,samples,features)), header=None)
    pls3 = pd.read_csv(os.path.join(ahba_dir, 'ahba_data/stats/%snuc_PLS3_scores_%s_chi%s.csv'%(nuc,samples,features)), header=None)
    chi  = pd.read_csv(os.path.join(ahba_dir, 'ahba_data/stats/%snuc_chi_%s%s.csv'%(nuc,samples[4:],features)), header=None)#.set_index(0)
    del pls1.index.name
    del pls2.index.name
    del pls3.index.name
    del chi.index.name
    
    return pls1, pls2,pls3, chi


nuc   = 'EXEC'
nval  = '48' 
motor_pls1, motor_pls2, motor_pls3     = return_pls('ahba20737', 'STR3_MOTOR_tstat_CP_1mm',  '48')
exec_pls1, exec_pls2, exec_pls3        = return_pls('ahba20737', 'STR3_EXEC_tstat_CP_1mm',  '48')
limbic_pls1, limbic_pls2, limbic_pls3  = return_pls('ahba20737', 'STR3_LIMBIC_tstat_CP_1mm',  '40')

motor_scores_pls1, motor_scores_pls2, motor_scores_pls3,chi = return_score('ahba20737', 'STR3_%s_tstat_CP_1mm'%nuc,  nval)

# %%
concat_quant = pd.DataFrame([motor_pls1['quantiles'].values, motor_pls2['quantiles'].values, motor_pls3['quantiles'].values, 
                             exec_pls1['quantiles'].values, exec_pls2['quantiles'].values,   exec_pls3['quantiles'].values,
                             limbic_pls1['quantiles'].values, limbic_pls2['quantiles'].values, limbic_pls3['quantiles'].values
                           ]).T
concat_quant.columns = ['motor1', 'motor2', 'motor3', 'exec1', 'exec2', 'exec3', 'limbic1', 'limbic2', 'limbic3']

concat_nonquant = pd.DataFrame([motor_pls1['non_quantiles'].values, motor_pls2['non_quantiles'].values, motor_pls3['non_quantiles'].values, 
                             exec_pls1['non_quantiles'].values, exec_pls2['non_quantiles'].values,   exec_pls3['non_quantiles'].values,
                             limbic_pls1['non_quantiles'].values, limbic_pls2['non_quantiles'].values, limbic_pls3['non_quantiles'].values
                           ]).T
concat_nonquant.columns = ['motor1', 'motor2', 'motor3', 'exec1', 'exec2', 'exec3', 'limbic1', 'limbic2', 'limbic3']



#scaler = preprocessing.MinMaxScaler()
#concat_pls_scale = pd.DataFrame(scaler.fit_transform(concat_pls), columns=concat_pls.columns, index=concat_pls.index)

# %%
f, ax = plt.subplots(figsize=(10, 10))

palette = ['r', 'r', 'r', 'b', 'b','b', 'g', 'g', 'g' ]

size    = 1.5
jitter  = 0.3
orient  = 'h'
sns.stripplot(data= concat_quant, palette=palette, orient = orient, jitter = jitter, size = size)
sns.stripplot(data= concat_nonquant, color='k', orient =orient, jitter = jitter, size = 1)

# %%
def plot_boot(pls, label, c= "#FA966B"):
    
    boot=pls[2]
    
    fig = plt.figure(figsize=(8, 6))
    ax = fig.add_subplot(111)
    sns.set_style("white")
    g = sns.distplot(boot, color='b', hist=1, bins = 30, norm_hist=1, kde_kws={'linewidth': 0},
                    hist_kws={"histtype": "barstacked", "linewidth": 0.3,
                              "alpha": 1, "color": c})

    q1=np.quantile(boot, 0.05)
    q2=np.quantile(boot, 0.95)
    plt.axvline(q1, color='k', linestyle='-.', linewidth=1)
    plt.axvline(q2, color='k', linestyle='-.', linewidth=1)
    #plt.xlim(-8,8)
    sns.despine(left=1)
    print q1,q2
    #histtype : {'bar', 'barstacked', 'step', 'stepfilled'}, optional
    
    glist5 = [i for i in pls.index if pls.loc[i][2] < np.round(q1,2) ]
    glist95 = [i for i in pls.index if pls.loc[i][2] > np.round(q2,2) ]
    
    print 'n_genes', len(glist5),  len(glist95), 
    
    fig.savefig(os.path.join(save_fig_dir,'PLOT_BOOT_%s_%s.png'%(label,nuc)), bbox_inches='tight', transparent = 1, dpi = 500)
    
    return glist5, glist95

# %%
def plot_boot_dist(boot,cmap,fname):
    fig = plt.figure(figsize=(12, 8))
    ax = fig.add_subplot(111)
    sns.set_style("white")
    #sns.distplot(boot, color=cmap, kde=0, bins =75)
    plt.hist(boot, color=cmap, bins =75)
    q1=np.quantile(boot, 0.05)
    q2=np.quantile(boot, 0.95)
    qm=np.quantile(boot, 0.5)
    plt.axvline(q1, color='k', linestyle='-.', linewidth=2, ymax=0.75)
    plt.axvline(q2, color='k', linestyle='-.', linewidth=2, ymax=0.75)
    #plt.axvline(qm, color='k', linestyle='-.', linewidth=2, ymax=0.75)
    #plt.xlim(-6,8)
    plt.xlabel('')
    plt.ylabel('')
    plt.xticks(fontsize=12, weight='bold')
    plt.yticks(fontsize=12, weight='bold')

    sns.despine(left=0,right=0,top=0)
    
    fig.savefig(os.path.join(save_fig_dir,'dist_boot_%s.png'%fname), bbox_inches='tight', transparent = 1, dpi = 500)

    print q1,qm,q2
    
    glist5 = [i for i in pd.DataFrame(boot).index if pd.DataFrame(boot).loc[i][2] < np.round(q1,2) ]
    glist95 = [i for i in pd.DataFrame(boot).index if pd.DataFrame(boot).loc[i][2] > np.round(q2,2) ]
    
    print 'n_genes', len(glist5),  len(glist95), 

    
def return_genes(boot):
    

    glist5 = [i for i in pd.DataFrame(boot).index if pd.DataFrame(boot).loc[i][2] < np.round(q1,2) ]
    glist95 = [i for i in pd.DataFrame(boot).index if pd.DataFrame(boot).loc[i][2] > np.round(q2,2) ]
    
    return glist5,glist95

# %%
plot_boot_dist(motor_pls1[2], 'lightgray', 'motor_pls1_g')
plot_boot_dist(motor_pls1[2], 'red', 'motor_pls1_r')
# Out:
# -1.8268717999999997 1.132254 5.281083400000001
# n_genes 1032 1039 -1.8268717999999997 1.132254 5.281083400000001
# n_genes 1032 1039

# %%
motor_pls1_5,motor_pls1_95 = return_genes(motor_pls1[2])
motor_pls2_5,motor_pls2_95 = return_genes(motor_pls2[2])
motor_pls3_5,motor_pls3_95 = return_genes(motor_pls3[2])

# %%
exec_pls1_5,exec_pls1_95 = return_genes(exec_pls1[2])
exec_pls2_5,exec_pls2_95 = return_genes(exec_pls2[2])
exec_pls3_5,exec_pls3_95 = return_genes(exec_pls3[2])

# %%
limbic_pls1_5,limbic_pls1_95 = return_genes(limbic_pls1[2])
limbic_pls2_5,limbic_pls2_95 = return_genes(limbic_pls2[2])
limbic_pls3_5,limbic_pls3_95 = return_genes(limbic_pls3[2])

# %%
sns.set_style("white")
g = sns.JointGrid(dfx.pls,dfx.chi, ratio=100)
g.plot_joint(sns.regplot, color='r')
g.ax_marg_x.set_axis_off()
g.ax_marg_y.set_axis_off()
g.fig.set_figwidth(8)
g.fig.set_figheight(6)
plt.xlabel('')
plt.ylabel('')
plt.xticks(fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')
sns.despine(left=0, top=0, right=0)
plt.savefig(os.path.join(save_fig_dir,'PLOT_BOOTCORR_MOTOR_PLS1.png'), bbox_inches='tight', transparent = 1, dpi = 500)

print pearsonr(dfx.pls, dfx.chi)
# Out:
# (0.7180798465612169, 9.178921861549668e-09)

# %%
for i in motor_pls1_5:
    print i
# Out:
# GRIP1
# ROPN1B
# GUCA1B
# TBC1D3
# AGBL3
# GPR173
# AC093283_3
# REG3G
# RCSD1
# ERC2
# LYPD6
# OS9
# LUZP1
# MIPEP
# CFHR4
# FEZF1
# SNTG2
# TPI1P2
# PTGER2
# CCK
# PLSCR3
# OR51E1
# WDR18
# CHRM1
# RARG
# SERTAD4
# PMAIP1
# LZTS2
# TMEM107
# MAN1B1
# LINC00032
# ZNF33A
# GFRA1
# TEX2
# GREM2
# REEP6
# ODC1
# VAT1
# TOR3A
# MTUS1
# LOC400752
# AGGF1
# NUDT16P
# SYT14
# TCEA3
# CTRB1
# PDS5A
# RFFL
# NUP62
# LPHN1
# D2HGDH
# HEATR7A
# GLTSCR2
# ARL11
# GPR52
# EML4
# CCDC39
# C5ORF62
# LRCH1
# FOXF2
# NDEL1
# TRIM49
# AC116655_15
# IL32
# COL5A1
# SCARF2
# WBP1
# RBP2
# C16orf42
# CLIC5
# PCDHGA7
# CCDC74A
# SHC2
# CCDC80
# PLA2R1
# PTCD1
# CASD1
# BBS5
# NAP1L4
# KIF20B
# MYADML2
# LINC00158
# SLC11A2
# RGMA
# PCDHGB5
# ANKRD18B
# MC3R
# ACOT11
# RND2
# PTPRF
# A2M
# LRRC66
# LRRTM1
# PRICKLE1
# SERPINH1
# GTSE1
# CCNB3
# TNFRSF18
# P4HA1
# TPRXL
# LOC285548
# CAPN11
# FAM126A
# HTR4
# TLR8
# ATP2B3
# STX8
# MAP9
# SLC30A2
# CHRNA7
# DYNC2H1
# CNKSR1
# P2RX7
# SYT9
# SPSB4
# IRS2
# TMC1
# SGSH
# SLC2A2
# ADCYAP1
# OR5A2
# RSPO2
# MFSD3
# CCDC84
# LOC415056
# LRRC59
# USP24
# LOC100292114
# KRT25
# LYZL2
# C2orf18
# ODZ2
# SPATC1
# MOB2
# KBTBD7
# CDC6
# IL1RAPL1
# NRP2
# TFAP2C
# NCAM1
# FREM1
# GABRE
# PHACTR1
# HOMER1
# HIST1H4D
# C3orf54
# LOR
# SPAG16
# AC093063_1
# FAM81A
# LOC643630
# SLC35F3
# AC023055_2
# FNBP4
# RG9MTD3
# AFG3L2
# GRIN2D
# ATP6V1C2
# EYA4
# SLC18A1
# NPTN
# VWA3A
# RAB6B
# CSNK1E
# C7orf62
# DVL3
# NR1H3
# INPP4A
# KCNB1
# LOC441601
# TEX28
# LINC00205
# PHF13
# MEIS3P2
# FAM25C
# DPY19L2
# OR1B1
# EPHA4
# HLA_DPB1
# ANKRD44
# WBP2
# C16orf73
# TPTE2P1
# GEFT
# LYRM1
# FER1L5
# NTS
# LOC653110
# IFNA6
# LYPD5
# HSPB2
# DTD1
# LOC728024
# RTN4RL2
# C7orf65
# LPXN
# ST6GAL1
# FAM151A
# AMAC1L2
# H1FX
# OR9A4
# PPARGC1B
# KIAA1881
# EPHA3
# MCTP1
# EPHA6
# CCDC30
# CXorf40A
# LUC7L2
# FBXO42
# WDR13
# OR13C2
# NPM3
# RALY
# TBXAS1
# IQCH
# CNTLN
# RTEL1
# UBE2A
# FSIP1
# GGCX
# EFTUD2
# FAM73B
# PYGM
# LOC440995
# BCAS3
# TRIM43
# SEPX1
# AGR2
# RGS6
# C20orf112
# OLFM2
# C3orf33
# LRRC45
# RASAL1
# CXorf21
# QRFP
# C1orf113
# MTMR8
# DCUN1D5
# GIN1
# GNG11
# NSDHL
# TROVE2
# UFSP2
# TTC23
# TBC1D23
# ANK1
# CCL2
# OR5AK2
# SUGT1P1
# VASH1
# C7orf28A
# FAM69B
# PLXNA2
# MEF2BNB_MEF2B
# UBASH3A
# PABPN1
# CYP4V2
# FABP6
# LOC646517
# FABP1
# TBC1D8B
# GJC3
# TSC2
# STAT3
# VDAC3
# JAK3
# ZP4
# S100PBP
# SNTB2
# CCDC23
# GALNTL5
# SEZ6
# SORCS2
# TMED5
# IGSF9
# NOVA1
# STAB2
# CLUL1
# PLK1S1
# RECQL5
# CSK
# TMEM33
# DMD
# GCGR
# GPLD1
# HMGCR
# CDKAL1
# LOC150197
# WBSCR16
# LOC727796
# TRNP1
# HCLS1
# PARP6
# FAM46B
# RWDD1
# C6orf164
# MON2
# ADRA1A
# MRPS5
# RCVRN
# FAM151B
# EFHC1
# SPIN3
# QKI
# FAU
# EID2
# CCDC73
# DLGAP1
# TMEM169
# FAM181B
# LOC728327
# ZCWPW2
# C11orf40
# NRGN
# PRPH
# BMPER
# CDCA5
# FHIT
# DRD2
# STOML2
# RILPL2
# WDR67
# ALG9
# KIT
# OLAH
# CDH19
# PBEF1
# LOC100288893
# TMEM158
# C1orf86
# NR4A2
# C1orf216
# RNF160
# ERN2
# NR2F1
# AP003108_2
# IRAK4
# AKAP3
# PRSS27
# FAM171A2
# FRRS1
# DDX19B
# WDR64
# POTEB
# C1orf146
# FAM148C
# CCDC152
# FAM75A3
# TTC9
# ZNRD1
# TRIM7
# EFCAB4B
# RP11_65D13_1
# CELF3
# DGCR9
# LOC100289349
# OPCML
# NTRK1
# C16orf86
# C17orf66
# FAM71E2
# C1orf172
# FOS
# CAV2
# MORF4L1
# CCR9
# H2AFZ
# PORCN
# KAL1
# FBXL20
# EGR4
# C11orf61
# ALDH1L1
# CA12
# NMUR2
# ZNF385D
# FLRT2
# RP3_410C9_1
# SEMA3G
# MAMSTR
# KRT39
# C21orf116
# C5orf24
# RNASE13
# NRBP2
# BCL7C
# KRT222
# OR5H6
# MCF2L2
# FAM19A1
# C2orf60
# LINC00086
# C8orf41
# ODZ1
# PLCXD3
# RP11_537P22_1
# LOC100130360
# WDR46
# PTPRO
# C2orf24
# SPATA7
# ADA
# CLIP2
# FAM74A3
# ZFPM1
# CUGBP1
# ZNF213
# CTD_2514K5_2
# NHP2L1
# FAM197Y9
# NKG7
# DNAJC9
# TTC28
# LRP11
# PLCXD2
# MARCO
# RASEF
# C14orf83
# TRIM35
# YWHAE
# ILDR1
# CEPT1
# SYT13
# C12orf70
# GPR85
# HTR2B
# MAFB
# C2orf65
# MPZL2
# C1QTNF8
# NODAL
# FH
# LOC100293983
# C21orf67
# CAD
# ACOT4
# MORN2
# CADPS
# PRKDC
# BRI3BP
# WNK2
# SPATA17
# OR11L1
# CAMK1D
# GABRA3
# RAP2A
# FAM223A
# C9orf169
# OR51L1
# TTC7B
# POTEH
# TRDMT1
# RASSF4
# HIST1H3E
# DSCR6
# AOX1
# LOC100288196
# RARS2
# DACH2
# AC009365_1
# IFITM5
# TOM1
# HPDL
# TRPC6
# ANKRD5
# BARX2
# ACSS3
# ABI3
# CMYA5
# KCNA3
# MIR31HG
# ALX3
# PRKCE
# CPNE7
# PRKCH
# C10orf62
# BFSP1
# DNAH3
# TMEM214
# FCN3
# KCNF1
# NAP1L2
# AK3L1
# ARFRP1
# FHOD1
# KBTBD5
# ODF4
# FAM117A
# KIAA1219
# LACRT
# AL096711_2
# SHANK1
# ZSWIM1
# SLCO4A1
# BTBD10
# OR13A1
# LOC642943
# FPR3
# GPN3
# LOXHD1
# C9orf131
# TTC24
# CHRNA2
# PRB4
# CXorf56
# CARTPT
# GSDMD
# LOC646890
# FER1L6
# ADAM2
# AC008537_3
# TMEM65
# DNASE1L3
# KLF4
# GALP
# RAPGEF3
# BBS10
# BARX1
# PRHOXNB
# GLCE
# TBC1D7
# ZNF596
# RFC2
# ZNF56
# DPM3
# GPC2
# ACBD7
# STX18
# CA7
# NLRP14
# C10orf92
# ZNF28
# C1orf156
# C3orf23
# IQCG
# HIST1H1A
# BRSK2
# PPP1R28
# HISPPD2A
# TAS2R39
# CLCNKB
# LOC100289230
# TSPY26P
# C1orf14
# TEK
# C18orf32
# DNAH5
# SLC25A30
# BHLHE41
# OSBP2
# RAB11B
# CTNNA1
# FAM7A3
# LNPEP
# FLJ37201
# WDR51B
# SIAH2
# TCTEX1D2
# C7orf55
# C1orf133
# OCM2
# CXCL17
# ANKDD1A
# NEK4
# C13orf37
# PABPC1L2A
# AC139768_2
# DIRAS2
# TEX101
# EFNB2
# CCL27
# GALNT2
# LGALS16
# PTH2
# MUC13
# CASC1
# SLC28A2
# LMBRD1
# SCN5A
# SNAP23
# RAB3B
# FAM5B
# BSG
# AC002351_1
# XPOT
# NSUN6
# HOMEZ
# CYAT1
# SVIP
# AC110814_1
# NRTN
# IRF3
# GPR150
# NRG2
# ACSL3
# C3orf64
# SUSD3
# CCDC43
# RASD2
# SYNE2
# CDH8
# COL24A1
# FAM182B
# SMAP2
# ZNF480
# PTPRM
# MPP3
# C4orf43
# CAGE1
# OR1L1
# RSG17
# KIAA1632
# MCHR1
# SLC44A4
# HIST1H4C
# TAF7
# RIBC1
# ISG20L2
# CALCOCO2
# KCNH4
# CNTNAP3
# E2F4
# KIAA0892
# RBP3
# RAB22A
# RUNX1_IT1
# TMEM46
# SLC25A42
# HECTD3
# PRKCDBP
# IP6K3
# MESP2
# IQGAP1
# C7orf59
# STXBP6
# DIRAS1
# HMX3
# ELOVL3
# C6orf100
# SLMO2
# TPH1
# HHIPL1
# NPSR1
# NAPA
# SLITRK3
# SCN4B
# DCK
# LOC100130797
# LOC728543
# EPB41L4A_AS1
# GAS2L2
# MEPCE
# GABRA2
# VWA2
# GNG13
# IL5
# LOC727967
# HMGCLL1
# BAIAP2L2
# FAM48B2
# C10orf78
# GNG3
# C1orf51
# UTS2
# GUCY1B2
# PAN3
# FAM154A
# AC074286_1
# ZNF280A
# PPP3CA
# TRHDE
# GLT8D1
# ZNF518A
# SLC5A2
# LY6G6F
# DCDC2B
# MBOAT2
# GRM7
# ST7_AS1
# AC013402_2
# C5orf33
# MUM1
# HIGD2A
# THSD7A
# LRG1
# SLC41A1
# PRKG1
# HSPG2
# SLC19A3
# MYPOP
# PYDC1
# SPATA16
# PCK2
# PIP5K1A
# ARSJ
# DLX6
# C21ORF119
# C6orf115
# MAP1S
# HTR6
# SPATA3
# UNC5CL
# CSTL1
# CBX3
# GYLTL1B
# NPTX1
# CAMK2B
# IL6ST
# C21orf2
# LINGO1
# FLJ40536
# VSTM1
# ASTL
# DNAH12
# RIMKLA
# SEPT10
# PRR15
# FLJ38723
# CARS2
# LIN54
# E2F2
# ANKRD58
# LRRTM2
# SCFD2
# ZNF710
# PCDH11X
# ETV3
# C6orf94
# CHGA
# MCOLN2
# TMEM66
# SLC2A12
# TXLNA
# ATIC
# WDR65
# PCDHB9
# RAB9A
# NEK1
# RPGRIP1L
# KCNT1
# GPR1
# FBXW5
# ODZ3
# ZNF509
# ZNF800
# ANKMY1
# EXD3
# LOC729603
# ANKRD31
# CCDC66
# KCTD9
# TMEM20
# IQSEC3
# KIAA1310
# KCNJ2_AS1
# RSPH3
# EGF
# ADCY9
# CYP4F29P
# LAMA2
# GSPT1
# NXF1
# RELL2
# CCRL2
# CHD2
# KCNU1
# MAPRE2
# CD226
# PTPN23
# RAPGEF6
# LZIC
# MYOZ1
# B2M
# CCKAR
# AK3
# LRRC4C
# COL27A1
# FXYD5
# PGM2
# LPAR2
# CDH1
# SYMPK
# IL27
# LRRFIP2
# ACVR1C
# LOC727930
# GPRC6A
# LOC728650
# SGCZ
# PNMA1
# PTPRN
# B3GALNT2
# CXXC1
# PRSS22
# N4BP1
# PKP1
# C3orf14
# SYNGR4
# MGAT4B
# SST
# LOC100129122
# TTC25
# HES4
# YWHAG
# C15orf42
# POTEC
# SPINT3
# ADRA1D
# ANAPC13
# ZNF227
# PGR
# VWA5B2
# DNAH7
# CYP4X1
# AVIL
# GRINL1A
# SLC39A9
# CNTN2
# PTPN7
# DACH1
# GRIN2A
# CHST9
# HRG
# CHSY1
# MAGEE1
# ARID3C
# ERC1
# RPRD2
# GABRP
# ACAD9
# DYDC1
# NANOGP8
# PCDH10
# DGKI
# NTN5
# RRAS
# DNAJC4
# LOC729164
# ZCCHC17
# ADD1
# CBLN3
# TMEM195
# ZNF232
# ADCY10
# LRRN2
# KIAA0317
# ANKRD54
# AKAP13
# MAML3
# SNAP47
# TTC39B
# CYP2C19
# PKHD1L1
# CRLS1
# DNTTIP2
# PTGES3
# HTT
# VSTM2B
# MEIS3P1
# RLBP1
# LPAR6
# NIPSNAP3A
# CNTN4
# LOC652859
# SYTL4
# CACNA1C
# CCDC146
# HTR1F
# C6orf108
# NEFM
# SLC7A9
# CAP1
# NCRNA00117
# BMPR1B
# SLC27A1
# SEPT2
# TRPC5OS
# C5orf35
# SYT15
# OPRL1
# SPRR2E
# GABRB2
# C5orf46
# CCDC64B
# TDRD3
# PROK1
# CXorf58
# GRIK1
# RP11_90D4_2
# ASB13
# LRFN4
# AC091565_3
# BMP4
# ARHGAP26
# RPS6KA5
# CSRNP2
# HPCAL1
# LINC00472
# PGAM5
# RAB27A
# GANC
# VIM
# HECTD1
# RAB35
# PCDH24
# CACNG2
# SLC26A7
# LGALS9C
# SLC26A3
# KITLG
# RNF19A
# LOC100133161
# FZD2
# ARHGAP5
# RALGPS1
# FRMPD3
# AC004241_1
# NTRK3
# FSHR
# CXorf27
# LOC729683
# SCN3A
# LOC100131785
# CNTNAP4
# EGFEM1P
# CCIN
# DLX4
# SCN1B
# SP9
# SYS1
# CDK5
# DYTN
# KIAA1244
# AC078847_1
# KYNU
# EEPD1
# B4GALT5
# GPR21
# IL13RA1
# ZCCHC11
# FBXL19_AS1
# PPP4R2
# ZAR1L
# GPR78
# SLC4A1
# PRLHR
# SAMD15
# LONRF1
# CDC42EP2
# MAP3K14
# CPNE3
# GPR82
# ARNTL
# EPHA5
# CSMD2
# BIRC2
# RWDD4A
# SYT3
# SCAF11
# FAM65A
# XIST
# NOL3
# SCN2B
# PLXNA3
# PCDH7
# ANKRD30A
# SYT1
# GRM4
# FGF12
# CD34
# MARCH3
# GABRG2
# MED12
# PFN4
# GABRA1
# BEND3
# C11orf75
# DYRK2
# CHKB
# SSTR1
# SCAND2
# GABRA6
# ZNF830
# TRPC3
# RSF1
# C2orf78
# C6orf138
# C5orf4
# OPRD1
# NUDT10
# CREM
# PTPRQ
# UNC13B
# NPY
# GPR25
# TNFAIP8L2
# ST6GALNAC4
# PLXNB3
# SCN8A
# KIAA2018
# KCNH6
# MAD1L1
# TOMM22
# NUDT1
# SELT
# SH3RF2
# AC078937_4
# GLRA1
# KCNIP3
# KCNG2
# NPFFR1
# SGCG
# SLFNL1
# GLRA2
# RP11_23D24_1
# RBM23
# GCSH
# MIR22HG
# GABRA4
# DLG5
# RP4_783C10_1
# STX19
# FIGNL2
# SYN1
# GRHPR
# NIPAL1
# PPAPR3
# PTPRN2
# GRM6
# CCM2

# %%
GO_GABA = ['GABRA4', 'GABRA6', 'GABRA1', 'GABRG2', 'GABRB2', 'GABRP', 'GABRA2', 'GABRA3', 'GABRE', 'GABRD', 'GABRR1', 'GABRQ', 'GABRB1', 'GABRR3', 'GABRR2', 'GABRA5', 'GABRB3', 'GABBR2']              

dfx = motor_pls1.drop([1,'quantiles', 'non_quantiles'], axis =1).sort_values(by=[2]).reset_index()#.set_index('index')
dfx = dfx.drop([i for i in dfx.index if dfx.loc[i]['index'] not in GO_GABA ], axis = 0)
dfx
# Out:
#         index         2
# 11     GABRA4 -4.217921
# 48     GABRA6 -3.649393
# 55     GABRA1 -3.601956
# 58     GABRG2 -3.589977
# 148    GABRB2 -3.109303
# 201     GABRP -2.938067
# 377    GABRA2 -2.548812
# 585    GABRA3 -2.229298
# 890     GABRE -1.954866
# 1487    GABRD -1.578625
# 3311   GABRR1 -0.829532
# 5119    GABRQ -0.278561
# 6549   GABRB1  0.132776
# 6604   GABRR3  0.149105
# 7291   GABRR2  0.336817
# 7443   GABRB3  0.382686
# 7926   GABRA5  0.510723
# 17866  GABBR2  3.911451

# %%
11: GABRA4     -4.25
49: GABRA6     -3.66
55: GABRA1     -3.62
62: GABRG2     -3.58
125: GABRB3   -3.1
166: GABRP     -2.9
326: GABRA2  -2.6
531: GABRA3   -2.2
786: GABRE     -2.0
1335: GABRD   -1.6
2921: GABRR1 -0.83
4488: GABRQ  -0.30
5716: GABRB1 0.13
5768: GABRR3 0.15
6376: GABRR2  0.51
6937: GABRA5  0.63
7332: GABRB3  0.62
15596: GABBR2 3.9
# Out:
#   File "<ipython-input-294-61432c70d327>", line 1
#     11: GABRA4     -4.25
#       ^
# SyntaxError: invalid syntax

# %%
11
49
55
62
125
166
326
531
786
1335
2921
4488
5716
5768
6376
6937
7332
15596

# %%
-4.25
-3.66
-3.62
-3.58
-3.1
-2.9
-2.6
-2.2
-2.0
-1.6
-0.83
-0.30
0.13
0.15
0.51
0.63
0.62
3.9
# Out:
# 8.545573
