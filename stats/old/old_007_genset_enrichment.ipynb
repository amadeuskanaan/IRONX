# %%
# %matplotlib inline
import os
import math 
import numpy as np
import pandas as pd 
import seaborn as sns
import random
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
from scipy.stats import pearsonr, spearmanr, gaussian_kde
from sklearn.decomposition import TruncatedSVD, PCA
from sklearn.preprocessing import scale
from statsmodels.sandbox.stats.multicomp import fdrcorrection0
from matplotlib.colors import rgb2hex
import warnings
sns.set_style('white')
pd.options.display.max_rows = 2000
pd.options.display.max_columns = 999
warnings.filterwarnings('ignore')

ahba_dir     = '/Users/kanaaax/Google Drive/TS-EUROTRAIN/RESULTS_QSMv3/dataframes/AHBA/'
gsea_dir     = '/Users/kanaaax/Desktop/GSEA'
permute_dir  = '/Users/kanaaax/Google Drive/TS-EUROTRAIN/RESULTS_QSMv3/dataframes/permutations'
save_fig_dir = '/Users/kanaaax/Google Drive/TS-EUROTRAIN/Papers/2016_QSM_paper/Figures_python_v4'

# wells outside the striatal masks 
wells = [2371,       # AHBA claustrum, right
         2379,       # AHBA claustrum, left
         159226045,  # AHBA striatum -- out of mask
         160091500   # AHBA septal nuclei, left
         ] 
#housekeeping
drop_strings = ['coords_native', 'donor_names', 'struct_id', 'struct_name', 'top_struct', 'Mean', 'Median', 'PC1', 'PC2','PC3', ]

# %%
###########################################
# Read QSM stat maps#
##########################################

df_MNI = pd.read_csv(os.path.join(ahba_dir,'QSM_TSTATS/MNI_NIFTI_VALUES_permute_10K_OCT2.csv'), index_col = 0 )

# %%
###########################################
# Read expression values of AHBA database  
###########################################

AHBA = pd.read_csv(os.path.join(ahba_dir, 'ahba_data', 'AHBA_20737.csv'), index_col = 0)

# %%
############################################
# Concatenate geneset expression dataframes 
############################################

def return_expression_df(geneset):
    df = pd.read_csv(os.path.join(ahba_dir, 'AHBA_%s.csv'%geneset),index_col=0)
    gs = [i for i in df.columns if i not in drop_strings]
    return df, gs 

IRON_H,  GS_IRON_H   = return_expression_df('IRON_HOMEOSTASIS_PCA')
IRON_D,  GS_IRON_D   = return_expression_df('IRON_D_PCA')
IRON_T2, GS_IRON_T2  = return_expression_df('IRON_TRANSPORT2_PCA')
FERRITIN,GS_FERRITIN = return_expression_df('FERRITIN_PCA')

genesets = {'IRON_H'  : GS_IRON_H,'IRON_D'  : GS_IRON_D,'IRON_T2' : GS_IRON_T2,'FERRITIN': GS_FERRITIN}

def concat_dfs(measure):
    df  = pd.DataFrame(index = IRON_H.index, columns = ['IRON', 'IRON_D', 'IRON_T2', 'FERRITIN', 'top_struct', 'struct'])
    xval = 1
    df['top_struct']        = IRON_H.top_struct
    df['struct']            = IRON_H.struct_name
    df['IRON_H']            = IRON_H[measure] * xval
    df['IRON_D']            = IRON_D[measure]
    df['IRON_T2']           = IRON_T2[measure] * xval
    df['FERRITIN']          = FERRITIN[measure] * xval    
    df['FERRITIN']          = FERRITIN[measure] * xval    
    dfc = pd.concat([df_MNI, df], axis = 1)
    return dfc

df_PC1   = concat_dfs('RC1')
df_MU    = concat_dfs('Mean')
df_MD    = concat_dfs('Median')

dfs = {'df_PC1': df_PC1, 'df_MU':df_MU, 'df_MD':df_MD}

# %%
nucleus = ['STR3_MOTOR_tstat_CP_1mm']

df_chi  = df_MNI.drop([i for i in df_MNI.columns if i not in ['STR_tstat_CP_1mm']],axis=1)
df_chi  = pd.DataFrame(df_MNI[nucleus].drop(wells,axis=0).dropna())
len(df_chi)
# Out:
# 58

# %%
df_MNI.head()
# Out:
#            corrected_mni_x  corrected_mni_y  corrected_mni_z  \
# 126439333       -13.467693         2.255686         3.432523
# 126432538       -53.603259        -8.120055         0.868643
# 126435762       -16.288739       -34.198856       -19.944686
# 126439285       -17.820212         3.595613       -32.872868
# 126435744       -23.726456       -25.139000       -16.692841
#
#                                                   mni_coords  \
# 126439333  (-13.467692624176099, 2.2556863621849201, 3.43...
# 126432538  (-53.603259238745785, -8.12005526025591, 0.868...
# 126435762  (-16.2887392340876, -34.198856409531899, -19.9...
# 126439285  (-17.820211862154199, 3.5956125920259701, -32....
# 126435744  (-23.7264555931642, -25.138999524959399, -16.6...
#
#            Caud_tstat_CP_1mm  Caud_tfce_corrp_tstat_CP_1mm  \
# 126439333                NaN                           NaN
# 126432538                NaN                           NaN
# 126435762                NaN                           NaN
# 126439285                NaN                           NaN
# 126435744                NaN                           NaN
#
#            Caud_vox_p_tstat_CP_1mm  Caud_vox_corrp_tstat_CP_1mm  \
# 126439333                      NaN                          NaN
# 126432538                      NaN                          NaN
# 126435762                      NaN                          NaN
# 126439285                      NaN                          NaN
# 126435744                      NaN                          NaN
#
#            Caud_tfce_tstat_CP_1mm  Caud_tfce_p_tstat_CP_1mm  \
# 126439333                     NaN                       NaN
# 126432538                     NaN                       NaN
# 126435762                     NaN                       NaN
# 126439285                     NaN                       NaN
# 126435744                     NaN                       NaN
#
#            Pall_tstat_CP_1mm  Pall_tfce_corrp_tstat_CP_1mm  \
# 126439333                NaN                           NaN
# 126432538                NaN                           NaN
# 126435762                NaN                           NaN
# 126439285                NaN                           NaN
# 126435744                NaN                           NaN
#
#            Pall_vox_p_tstat_CP_1mm  Pall_vox_corrp_tstat_CP_1mm  \
# 126439333                      NaN                          NaN
# 126432538                      NaN                          NaN
# 126435762                      NaN                          NaN
# 126439285                      NaN                          NaN
# 126435744                      NaN                          NaN
#
#            Pall_tfce_tstat_CP_1mm  Pall_tfce_p_tstat_CP_1mm  \
# 126439333                     NaN                       NaN
# 126432538                     NaN                       NaN
# 126435762                     NaN                       NaN
# 126439285                     NaN                       NaN
# 126435744                     NaN                       NaN
#
#            Puta_tstat_CP_1mm  Puta_tfce_corrp_tstat_CP_1mm  \
# 126439333                NaN                           NaN
# 126432538                NaN                           NaN
# 126435762                NaN                           NaN
# 126439285                NaN                           NaN
# 126435744                NaN                           NaN
#
#            Puta_vox_p_tstat_CP_1mm  Puta_vox_corrp_tstat_CP_1mm  \
# 126439333                      NaN                          NaN
# 126432538                      NaN                          NaN
# 126435762                      NaN                          NaN
# 126439285                      NaN                          NaN
# 126435744                      NaN                          NaN
#
#            Puta_tfce_tstat_CP_1mm  Puta_tfce_p_tstat_CP_1mm  STR_tstat_CP_1mm  \
# 126439333                     NaN                       NaN               NaN
# 126432538                     NaN                       NaN               NaN
# 126435762                     NaN                       NaN               NaN
# 126439285                     NaN                       NaN               NaN
# 126435744                     NaN                       NaN               NaN
#
#            STR_tfce_corrp_tstat_CP_1mm  STR_vox_p_tstat_CP_1mm  \
# 126439333                          NaN                     NaN
# 126432538                          NaN                     NaN
# 126435762                          NaN                     NaN
# 126439285                          NaN                     NaN
# 126435744                          NaN                     NaN
#
#            STR_vox_corrp_tstat_CP_1mm  STR_tfce_tstat_CP_1mm  \
# 126439333                         NaN                    NaN
# 126432538                         NaN                    NaN
# 126435762                         NaN                    NaN
# 126439285                         NaN                    NaN
# 126435744                         NaN                    NaN
#
#            STR_tfce_p_tstat_CP_1mm  STR3_MOTOR_tstat_CP_1mm  \
# 126439333                      NaN                      NaN
# 126432538                      NaN                      NaN
# 126435762                      NaN                      NaN
# 126439285                      NaN                      NaN
# 126435744                      NaN                      NaN
#
#            STR3_MOTOR_tfce_corrp_tstat_CP_1mm  STR3_MOTOR_vox_p_tstat_CP_1mm  \
# 126439333                                 NaN                            NaN
# 126432538                                 NaN                            NaN
# 126435762                                 NaN                            NaN
# 126439285                                 NaN                            NaN
# 126435744                                 NaN                            NaN
#
#            STR3_MOTOR_vox_corrp_tstat_CP_1mm  STR3_MOTOR_tfce_tstat_CP_1mm  \
# 126439333                                NaN                           NaN
# 126432538                                NaN                           NaN
# 126435762                                NaN                           NaN
# 126439285                                NaN                           NaN
# 126435744                                NaN                           NaN
#
#            STR3_MOTOR_tfce_p_tstat_CP_1mm  STR3_MOTOR_tstat_LL_1mm  \
# 126439333                             NaN                      NaN
# 126432538                             NaN                      NaN
# 126435762                             NaN                      NaN
# 126439285                             NaN                      NaN
# 126435744                             NaN                      NaN
#
#            STR3_MOTOR_tfce_corrp_tstat_LL_1mm  STR3_MOTOR_vox_p_tstat_LL_1mm  \
# 126439333                                 NaN                            NaN
# 126432538                                 NaN                            NaN
# 126435762                                 NaN                            NaN
# 126439285                                 NaN                            NaN
# 126435744                                 NaN                            NaN
#
#            STR3_MOTOR_vox_corrp_tstat_LL_1mm  STR3_MOTOR_tfce_tstat_LL_1mm  \
# 126439333                                NaN                           NaN
# 126432538                                NaN                           NaN
# 126435762                                NaN                           NaN
# 126439285                                NaN                           NaN
# 126435744                                NaN                           NaN
#
#            STR3_MOTOR_tfce_p_tstat_LL_1mm  STR3_MOTOR_Pall_tstat_CP_1mm  \
# 126439333                             NaN                           NaN
# 126432538                             NaN                           NaN
# 126435762                             NaN                           NaN
# 126439285                             NaN                           NaN
# 126435744                             NaN                           NaN
#
#            STR3_MOTOR_Pall_tfce_corrp_tstat_CP_1mm  \
# 126439333                                      NaN
# 126432538                                      NaN
# 126435762                                      NaN
# 126439285                                      NaN
# 126435744                                      NaN
#
#            STR3_MOTOR_Pall_vox_p_tstat_CP_1mm  \
# 126439333                                 NaN
# 126432538                                 NaN
# 126435762                                 NaN
# 126439285                                 NaN
# 126435744                                 NaN
#
#            STR3_MOTOR_Pall_vox_corrp_tstat_CP_1mm  \
# 126439333                                     NaN
# 126432538                                     NaN
# 126435762                                     NaN
# 126439285                                     NaN
# 126435744                                     NaN
#
#            STR3_MOTOR_Pall_tfce_tstat_CP_1mm  \
# 126439333                                NaN
# 126432538                                NaN
# 126435762                                NaN
# 126439285                                NaN
# 126435744                                NaN
#
#            STR3_MOTOR_Pall_tfce_p_tstat_CP_1mm  STR3_MOTOR_Pall_tstat_LL_1mm  \
# 126439333                                  NaN                           NaN
# 126432538                                  NaN                           NaN
# 126435762                                  NaN                           NaN
# 126439285                                  NaN                           NaN
# 126435744                                  NaN                           NaN
#
#            STR3_MOTOR_Pall_tfce_corrp_tstat_LL_1mm  \
# 126439333                                      NaN
# 126432538                                      NaN
# 126435762                                      NaN
# 126439285                                      NaN
# 126435744                                      NaN
#
#            STR3_MOTOR_Pall_vox_p_tstat_LL_1mm  \
# 126439333                                 NaN
# 126432538                                 NaN
# 126435762                                 NaN
# 126439285                                 NaN
# 126435744                                 NaN
#
#            STR3_MOTOR_Pall_vox_corrp_tstat_LL_1mm  \
# 126439333                                     NaN
# 126432538                                     NaN
# 126435762                                     NaN
# 126439285                                     NaN
# 126435744                                     NaN
#
#            STR3_MOTOR_Pall_tfce_tstat_LL_1mm  \
# 126439333                                NaN
# 126432538                                NaN
# 126435762                                NaN
# 126439285                                NaN
# 126435744                                NaN
#
#            STR3_MOTOR_Pall_tfce_p_tstat_LL_1mm  STR3_LIMBIC_tstat_CP_1mm  \
# 126439333                                  NaN                       NaN
# 126432538                                  NaN                       NaN
# 126435762                                  NaN                       NaN
# 126439285                                  NaN                       NaN
# 126435744                                  NaN                       NaN
#
#            STR3_LIMBIC_tfce_corrp_tstat_CP_1mm  \
# 126439333                                  NaN
# 126432538                                  NaN
# 126435762                                  NaN
# 126439285                                  NaN
# 126435744                                  NaN
#
#            STR3_LIMBIC_vox_p_tstat_CP_1mm  STR3_LIMBIC_vox_corrp_tstat_CP_1mm  \
# 126439333                             NaN                                 NaN
# 126432538                             NaN                                 NaN
# 126435762                             NaN                                 NaN
# 126439285                             NaN                                 NaN
# 126435744                             NaN                                 NaN
#
#            STR3_LIMBIC_tfce_tstat_CP_1mm  STR3_LIMBIC_tfce_p_tstat_CP_1mm  \
# 126439333                            NaN                              NaN
# 126432538                            NaN                              NaN
# 126435762                            NaN                              NaN
# 126439285                            NaN                              NaN
# 126435744                            NaN                              NaN
#
#            STR3_EXEC_tstat_CP_1mm  STR3_EXEC_tfce_corrp_tstat_CP_1mm  \
# 126439333                     NaN                                NaN
# 126432538                     NaN                                NaN
# 126435762                     NaN                                NaN
# 126439285                     NaN                                NaN
# 126435744                     NaN                                NaN
#
#            STR3_EXEC_vox_p_tstat_CP_1mm  STR3_EXEC_vox_corrp_tstat_CP_1mm  \
# 126439333                           NaN                               NaN
# 126432538                           NaN                               NaN
# 126435762                           NaN                               NaN
# 126439285                           NaN                               NaN
# 126435744                           NaN                               NaN
#
#            STR3_EXEC_tfce_tstat_CP_1mm  STR3_EXEC_tfce_p_tstat_CP_1mm  \
# 126439333                          NaN                            NaN
# 126432538                          NaN                            NaN
# 126435762                          NaN                            NaN
# 126439285                          NaN                            NaN
# 126435744                          NaN                            NaN
#
#            GM_0.0_tstat_CP_1mm  GM_0.0_tfce_corrp_tstat_CP_1mm  \
# 126439333                  NaN                             NaN
# 126432538                  NaN                             NaN
# 126435762                  NaN                             NaN
# 126439285                  NaN                             NaN
# 126435744                  NaN                             NaN
#
#            GM_0.0_vox_p_tstat_CP_1mm  GM_0.0_vox_corrp_tstat_CP_1mm  \
# 126439333                        NaN                            NaN
# 126432538                        NaN                            NaN
# 126435762                        NaN                            NaN
# 126439285                        NaN                            NaN
# 126435744                        NaN                            NaN
#
#            GM_0.0_tfce_tstat_CP_1mm  GM_0.0_tfce_p_tstat_CP_1mm  \
# 126439333                       NaN                         NaN
# 126432538                       NaN                         NaN
# 126435762                       NaN                         NaN
# 126439285                       NaN                         NaN
# 126435744                       NaN                         NaN
#
#            Caud_tstat_CP_2mm  Caud_tfce_corrp_tstat_CP_2mm  \
# 126439333                NaN                           NaN
# 126432538                NaN                           NaN
# 126435762                NaN                           NaN
# 126439285                NaN                           NaN
# 126435744                NaN                           NaN
#
#            Caud_vox_p_tstat_CP_2mm  Caud_vox_corrp_tstat_CP_2mm  \
# 126439333                      NaN                          NaN
# 126432538                      NaN                          NaN
# 126435762                      NaN                          NaN
# 126439285                      NaN                          NaN
# 126435744                      NaN                          NaN
#
#            Caud_tfce_tstat_CP_2mm  Caud_tfce_p_tstat_CP_2mm  \
# 126439333                     NaN                       NaN
# 126432538                     NaN                       NaN
# 126435762                     NaN                       NaN
# 126439285                     NaN                       NaN
# 126435744                     NaN                       NaN
#
#            Pall_tstat_CP_2mm  Pall_tfce_corrp_tstat_CP_2mm  \
# 126439333                NaN                           NaN
# 126432538                NaN                           NaN
# 126435762                NaN                           NaN
# 126439285                NaN                           NaN
# 126435744                NaN                           NaN
#
#            Pall_vox_p_tstat_CP_2mm  Pall_vox_corrp_tstat_CP_2mm  \
# 126439333                      NaN                          NaN
# 126432538                      NaN                          NaN
# 126435762                      NaN                          NaN
# 126439285                      NaN                          NaN
# 126435744                      NaN                          NaN
#
#            Pall_tfce_tstat_CP_2mm  Pall_tfce_p_tstat_CP_2mm  \
# 126439333                     NaN                       NaN
# 126432538                     NaN                       NaN
# 126435762                     NaN                       NaN
# 126439285                     NaN                       NaN
# 126435744                     NaN                       NaN
#
#            Puta_tstat_CP_2mm  Puta_tfce_corrp_tstat_CP_2mm  \
# 126439333                NaN                           NaN
# 126432538                NaN                           NaN
# 126435762                NaN                           NaN
# 126439285                NaN                           NaN
# 126435744                NaN                           NaN
#
#            Puta_vox_p_tstat_CP_2mm  Puta_vox_corrp_tstat_CP_2mm  \
# 126439333                      NaN                          NaN
# 126432538                      NaN                          NaN
# 126435762                      NaN                          NaN
# 126439285                      NaN                          NaN
# 126435744                      NaN                          NaN
#
#            Puta_tfce_tstat_CP_2mm  Puta_tfce_p_tstat_CP_2mm  STR_tstat_CP_2mm  \
# 126439333                     NaN                       NaN               NaN
# 126432538                     NaN                       NaN               NaN
# 126435762                     NaN                       NaN               NaN
# 126439285                     NaN                       NaN               NaN
# 126435744                     NaN                       NaN               NaN
#
#            STR_tfce_corrp_tstat_CP_2mm  STR_vox_p_tstat_CP_2mm  \
# 126439333                          NaN                     NaN
# 126432538                          NaN                     NaN
# 126435762                          NaN                     NaN
# 126439285                          NaN                     NaN
# 126435744                          NaN                     NaN
#
#            STR_vox_corrp_tstat_CP_2mm  STR_tfce_tstat_CP_2mm  \
# 126439333                         NaN                    NaN
# 126432538                         NaN                    NaN
# 126435762                         NaN                    NaN
# 126439285                         NaN                    NaN
# 126435744                         NaN                    NaN
#
#            STR_tfce_p_tstat_CP_2mm  STR3_MOTOR_tstat_CP_2mm  \
# 126439333                      NaN                      NaN
# 126432538                      NaN                      NaN
# 126435762                      NaN                      NaN
# 126439285                      NaN                      NaN
# 126435744                      NaN                      NaN
#
#            STR3_MOTOR_tfce_corrp_tstat_CP_2mm  STR3_MOTOR_vox_p_tstat_CP_2mm  \
# 126439333                                 NaN                            NaN
# 126432538                                 NaN                            NaN
# 126435762                                 NaN                            NaN
# 126439285                                 NaN                            NaN
# 126435744                                 NaN                            NaN
#
#            STR3_MOTOR_vox_corrp_tstat_CP_2mm  STR3_MOTOR_tfce_tstat_CP_2mm  \
# 126439333                                NaN                           NaN
# 126432538                                NaN                           NaN
# 126435762                                NaN                           NaN
# 126439285                                NaN                           NaN
# 126435744                                NaN                           NaN
#
#            STR3_MOTOR_tfce_p_tstat_CP_2mm  STR3_MOTOR_tstat_LL_2mm  \
# 126439333                             NaN                      NaN
# 126432538                             NaN                      NaN
# 126435762                             NaN                      NaN
# 126439285                             NaN                      NaN
# 126435744                             NaN                      NaN
#
#            STR3_MOTOR_tfce_corrp_tstat_LL_2mm  STR3_MOTOR_vox_p_tstat_LL_2mm  \
# 126439333                                 NaN                            NaN
# 126432538                                 NaN                            NaN
# 126435762                                 NaN                            NaN
# 126439285                                 NaN                            NaN
# 126435744                                 NaN                            NaN
#
#            STR3_MOTOR_vox_corrp_tstat_LL_2mm  STR3_MOTOR_tfce_tstat_LL_2mm  \
# 126439333                                NaN                           NaN
# 126432538                                NaN                           NaN
# 126435762                                NaN                           NaN
# 126439285                                NaN                           NaN
# 126435744                                NaN                           NaN
#
#            STR3_MOTOR_tfce_p_tstat_LL_2mm  STR3_MOTOR_Pall_tstat_CP_2mm  \
# 126439333                             NaN                           NaN
# 126432538                             NaN                           NaN
# 126435762                             NaN                           NaN
# 126439285                             NaN                           NaN
# 126435744                             NaN                           NaN
#
#            STR3_MOTOR_Pall_tfce_corrp_tstat_CP_2mm  \
# 126439333                                      NaN
# 126432538                                      NaN
# 126435762                                      NaN
# 126439285                                      NaN
# 126435744                                      NaN
#
#            STR3_MOTOR_Pall_vox_p_tstat_CP_2mm  \
# 126439333                                 NaN
# 126432538                                 NaN
# 126435762                                 NaN
# 126439285                                 NaN
# 126435744                                 NaN
#
#            STR3_MOTOR_Pall_vox_corrp_tstat_CP_2mm  \
# 126439333                                     NaN
# 126432538                                     NaN
# 126435762                                     NaN
# 126439285                                     NaN
# 126435744                                     NaN
#
#            STR3_MOTOR_Pall_tfce_tstat_CP_2mm  \
# 126439333                                NaN
# 126432538                                NaN
# 126435762                                NaN
# 126439285                                NaN
# 126435744                                NaN
#
#            STR3_MOTOR_Pall_tfce_p_tstat_CP_2mm  STR3_MOTOR_Pall_tstat_LL_2mm  \
# 126439333                                  NaN                           NaN
# 126432538                                  NaN                           NaN
# 126435762                                  NaN                           NaN
# 126439285                                  NaN                           NaN
# 126435744                                  NaN                           NaN
#
#            STR3_MOTOR_Pall_tfce_corrp_tstat_LL_2mm  \
# 126439333                                      NaN
# 126432538                                      NaN
# 126435762                                      NaN
# 126439285                                      NaN
# 126435744                                      NaN
#
#            STR3_MOTOR_Pall_vox_p_tstat_LL_2mm  \
# 126439333                                 NaN
# 126432538                                 NaN
# 126435762                                 NaN
# 126439285                                 NaN
# 126435744                                 NaN
#
#            STR3_MOTOR_Pall_vox_corrp_tstat_LL_2mm  \
# 126439333                                     NaN
# 126432538                                     NaN
# 126435762                                     NaN
# 126439285                                     NaN
# 126435744                                     NaN
#
#            STR3_MOTOR_Pall_tfce_tstat_LL_2mm  \
# 126439333                                NaN
# 126432538                                NaN
# 126435762                                NaN
# 126439285                                NaN
# 126435744                                NaN
#
#            STR3_MOTOR_Pall_tfce_p_tstat_LL_2mm  STR3_LIMBIC_tstat_CP_2mm  \
# 126439333                                  NaN                       NaN
# 126432538                                  NaN                       NaN
# 126435762                                  NaN                       NaN
# 126439285                                  NaN                       NaN
# 126435744                                  NaN                       NaN
#
#            STR3_LIMBIC_tfce_corrp_tstat_CP_2mm  \
# 126439333                                  NaN
# 126432538                                  NaN
# 126435762                                  NaN
# 126439285                                  NaN
# 126435744                                  NaN
#
#            STR3_LIMBIC_vox_p_tstat_CP_2mm  STR3_LIMBIC_vox_corrp_tstat_CP_2mm  \
# 126439333                             NaN                                 NaN
# 126432538                             NaN                                 NaN
# 126435762                             NaN                                 NaN
# 126439285                             NaN                                 NaN
# 126435744                             NaN                                 NaN
#
#            STR3_LIMBIC_tfce_tstat_CP_2mm  STR3_LIMBIC_tfce_p_tstat_CP_2mm  \
# 126439333                            NaN                              NaN
# 126432538                            NaN                              NaN
# 126435762                            NaN                              NaN
# 126439285                            NaN                              NaN
# 126435744                            NaN                              NaN
#
#            STR3_EXEC_tstat_CP_2mm  STR3_EXEC_tfce_corrp_tstat_CP_2mm  \
# 126439333                     NaN                                NaN
# 126432538                     NaN                                NaN
# 126435762                     NaN                                NaN
# 126439285                     NaN                                NaN
# 126435744                     NaN                                NaN
#
#            STR3_EXEC_vox_p_tstat_CP_2mm  STR3_EXEC_vox_corrp_tstat_CP_2mm  \
# 126439333                           NaN                               NaN
# 126432538                           NaN                               NaN
# 126435762                           NaN                               NaN
# 126439285                           NaN                               NaN
# 126435744                           NaN                               NaN
#
#            STR3_EXEC_tfce_tstat_CP_2mm  STR3_EXEC_tfce_p_tstat_CP_2mm  \
# 126439333                          NaN                            NaN
# 126432538                          NaN                            NaN
# 126435762                          NaN                            NaN
# 126439285                          NaN                            NaN
# 126435744                          NaN                            NaN
#
#            GM_0.0_tstat_CP_2mm  GM_0.0_tfce_corrp_tstat_CP_2mm  \
# 126439333                  NaN                             NaN
# 126432538                  NaN                             NaN
# 126435762                  NaN                             NaN
# 126439285                  NaN                             NaN
# 126435744                  NaN                             NaN
#
#            GM_0.0_vox_p_tstat_CP_2mm  GM_0.0_vox_corrp_tstat_CP_2mm  \
# 126439333                        NaN                            NaN
# 126432538                        NaN                            NaN
# 126435762                        NaN                            NaN
# 126439285                        NaN                            NaN
# 126435744                        NaN                            NaN
#
#            GM_0.0_tfce_tstat_CP_2mm  GM_0.0_tfce_p_tstat_CP_2mm  \
# 126439333                       NaN                         NaN
# 126432538                       NaN                         NaN
# 126435762                       NaN                         NaN
# 126439285                       NaN                         NaN
# 126435744                       NaN                         NaN
#
#            Caud_tstat_CP_3mm  Caud_tfce_corrp_tstat_CP_3mm  \
# 126439333                NaN                           NaN
# 126432538                NaN                           NaN
# 126435762                NaN                           NaN
# 126439285                NaN                           NaN
# 126435744                NaN                           NaN
#
#            Caud_vox_p_tstat_CP_3mm  Caud_vox_corrp_tstat_CP_3mm  \
# 126439333                      NaN                          NaN
# 126432538                      NaN                          NaN
# 126435762                      NaN                          NaN
# 126439285                      NaN                          NaN
# 126435744                      NaN                          NaN
#
#            Caud_tfce_tstat_CP_3mm  Caud_tfce_p_tstat_CP_3mm  \
# 126439333                     NaN                       NaN
# 126432538                     NaN                       NaN
# 126435762                     NaN                       NaN
# 126439285                     NaN                       NaN
# 126435744                     NaN                       NaN
#
#            Pall_tstat_CP_3mm  Pall_tfce_corrp_tstat_CP_3mm  \
# 126439333            1.94524                       0.78975
# 126432538                NaN                           NaN
# 126435762                NaN                           NaN
# 126439285                NaN                           NaN
# 126435744                NaN                           NaN
#
#            Pall_vox_p_tstat_CP_3mm  Pall_vox_corrp_tstat_CP_3mm  \
# 126439333                 0.966225                     0.011833
# 126432538                      NaN                          NaN
# 126435762                      NaN                          NaN
# 126439285                      NaN                          NaN
# 126435744                      NaN                          NaN
#
#            Pall_tfce_tstat_CP_3mm  Pall_tfce_p_tstat_CP_3mm  \
# 126439333             1394.345581                  0.989525
# 126432538                     NaN                       NaN
# 126435762                     NaN                       NaN
# 126439285                     NaN                       NaN
# 126435744                     NaN                       NaN
#
#            Puta_tstat_CP_3mm  Puta_tfce_corrp_tstat_CP_3mm  \
# 126439333                NaN                           NaN
# 126432538                NaN                           NaN
# 126435762                NaN                           NaN
# 126439285                NaN                           NaN
# 126435744                NaN                           NaN
#
#            Puta_vox_p_tstat_CP_3mm  Puta_vox_corrp_tstat_CP_3mm  \
# 126439333                      NaN                          NaN
# 126432538                      NaN                          NaN
# 126435762                      NaN                          NaN
# 126439285                      NaN                          NaN
# 126435744                      NaN                          NaN
#
#            Puta_tfce_tstat_CP_3mm  Puta_tfce_p_tstat_CP_3mm  STR_tstat_CP_3mm  \
# 126439333                     NaN                       NaN               NaN
# 126432538                     NaN                       NaN               NaN
# 126435762                     NaN                       NaN               NaN
# 126439285                     NaN                       NaN               NaN
# 126435744                     NaN                       NaN               NaN
#
#            STR_tfce_corrp_tstat_CP_3mm  STR_vox_p_tstat_CP_3mm  \
# 126439333                          NaN                     NaN
# 126432538                          NaN                     NaN
# 126435762                          NaN                     NaN
# 126439285                          NaN                     NaN
# 126435744                          NaN                     NaN
#
#            STR_vox_corrp_tstat_CP_3mm  STR_tfce_tstat_CP_3mm  \
# 126439333                         NaN                    NaN
# 126432538                         NaN                    NaN
# 126435762                         NaN                    NaN
# 126439285                         NaN                    NaN
# 126435744                         NaN                    NaN
#
#            STR_tfce_p_tstat_CP_3mm  STR3_MOTOR_tstat_CP_3mm  \
# 126439333                      NaN                      NaN
# 126432538                      NaN                      NaN
# 126435762                      NaN                      NaN
# 126439285                      NaN                      NaN
# 126435744                      NaN                      NaN
#
#            STR3_MOTOR_tfce_corrp_tstat_CP_3mm  STR3_MOTOR_vox_p_tstat_CP_3mm  \
# 126439333                                 NaN                            NaN
# 126432538                                 NaN                            NaN
# 126435762                                 NaN                            NaN
# 126439285                                 NaN                            NaN
# 126435744                                 NaN                            NaN
#
#            STR3_MOTOR_vox_corrp_tstat_CP_3mm  STR3_MOTOR_tfce_tstat_CP_3mm  \
# 126439333                                NaN                           NaN
# 126432538                                NaN                           NaN
# 126435762                                NaN                           NaN
# 126439285                                NaN                           NaN
# 126435744                                NaN                           NaN
#
#            STR3_MOTOR_tfce_p_tstat_CP_3mm  STR3_MOTOR_tstat_LL_3mm  \
# 126439333                             NaN                      NaN
# 126432538                             NaN                      NaN
# 126435762                             NaN                      NaN
# 126439285                             NaN                      NaN
# 126435744                             NaN                      NaN
#
#            STR3_MOTOR_tfce_corrp_tstat_LL_3mm  STR3_MOTOR_vox_p_tstat_LL_3mm  \
# 126439333                                 NaN                            NaN
# 126432538                                 NaN                            NaN
# 126435762                                 NaN                            NaN
# 126439285                                 NaN                            NaN
# 126435744                                 NaN                            NaN
#
#            STR3_MOTOR_vox_corrp_tstat_LL_3mm  STR3_MOTOR_tfce_tstat_LL_3mm  \
# 126439333                                NaN                           NaN
# 126432538                                NaN                           NaN
# 126435762                                NaN                           NaN
# 126439285                                NaN                           NaN
# 126435744                                NaN                           NaN
#
#            STR3_MOTOR_tfce_p_tstat_LL_3mm  STR3_MOTOR_Pall_tstat_CP_3mm  \
# 126439333                             NaN                      1.802169
# 126432538                             NaN                           NaN
# 126435762                             NaN                           NaN
# 126439285                             NaN                           NaN
# 126435744                             NaN                           NaN
#
#            STR3_MOTOR_Pall_tfce_corrp_tstat_CP_3mm  \
# 126439333                                 0.779833
# 126432538                                      NaN
# 126435762                                      NaN
# 126439285                                      NaN
# 126435744                                      NaN
#
#            STR3_MOTOR_Pall_vox_p_tstat_CP_3mm  \
# 126439333                            0.958325
# 126432538                                 NaN
# 126435762                                 NaN
# 126439285                                 NaN
# 126435744                                 NaN
#
#            STR3_MOTOR_Pall_vox_corrp_tstat_CP_3mm  \
# 126439333                                  0.0001
# 126432538                                     NaN
# 126435762                                     NaN
# 126439285                                     NaN
# 126435744                                     NaN
#
#            STR3_MOTOR_Pall_tfce_tstat_CP_3mm  \
# 126439333                        2150.244385
# 126432538                                NaN
# 126435762                                NaN
# 126439285                                NaN
# 126435744                                NaN
#
#            STR3_MOTOR_Pall_tfce_p_tstat_CP_3mm  STR3_MOTOR_Pall_tstat_LL_3mm  \
# 126439333                             0.989925                     -2.137132
# 126432538                                  NaN                           NaN
# 126435762                                  NaN                           NaN
# 126439285                                  NaN                           NaN
# 126435744                                  NaN                           NaN
#
#            STR3_MOTOR_Pall_tfce_corrp_tstat_LL_3mm  \
# 126439333                                      NaN
# 126432538                                      NaN
# 126435762                                      NaN
# 126439285                                      NaN
# 126435744                                      NaN
#
#            STR3_MOTOR_Pall_vox_p_tstat_LL_3mm  \
# 126439333                            0.033117
# 126432538                                 NaN
# 126435762                                 NaN
# 126439285                                 NaN
# 126435744                                 NaN
#
#            STR3_MOTOR_Pall_vox_corrp_tstat_LL_3mm  \
# 126439333                                     NaN
# 126432538                                     NaN
# 126435762                                     NaN
# 126439285                                     NaN
# 126435744                                     NaN
#
#            STR3_MOTOR_Pall_tfce_tstat_LL_3mm  \
# 126439333                                NaN
# 126432538                                NaN
# 126435762                                NaN
# 126439285                                NaN
# 126435744                                NaN
#
#            STR3_MOTOR_Pall_tfce_p_tstat_LL_3mm  STR3_LIMBIC_tstat_CP_3mm  \
# 126439333                                  NaN                       NaN
# 126432538                                  NaN                       NaN
# 126435762                                  NaN                       NaN
# 126439285                                  NaN                       NaN
# 126435744                                  NaN                       NaN
#
#            STR3_LIMBIC_tfce_corrp_tstat_CP_3mm  \
# 126439333                                  NaN
# 126432538                                  NaN
# 126435762                                  NaN
# 126439285                                  NaN
# 126435744                                  NaN
#
#            STR3_LIMBIC_vox_p_tstat_CP_3mm  STR3_LIMBIC_vox_corrp_tstat_CP_3mm  \
# 126439333                             NaN                                 NaN
# 126432538                             NaN                                 NaN
# 126435762                             NaN                                 NaN
# 126439285                             NaN                                 NaN
# 126435744                             NaN                                 NaN
#
#            STR3_LIMBIC_tfce_tstat_CP_3mm  STR3_LIMBIC_tfce_p_tstat_CP_3mm  \
# 126439333                            NaN                              NaN
# 126432538                            NaN                              NaN
# 126435762                            NaN                              NaN
# 126439285                            NaN                              NaN
# 126435744                            NaN                              NaN
#
#            STR3_EXEC_tstat_CP_3mm  STR3_EXEC_tfce_corrp_tstat_CP_3mm  \
# 126439333                     NaN                                NaN
# 126432538                     NaN                                NaN
# 126435762                     NaN                                NaN
# 126439285                     NaN                                NaN
# 126435744                     NaN                                NaN
#
#            STR3_EXEC_vox_p_tstat_CP_3mm  STR3_EXEC_vox_corrp_tstat_CP_3mm  \
# 126439333                           NaN                               NaN
# 126432538                           NaN                               NaN
# 126435762                           NaN                               NaN
# 126439285                           NaN                               NaN
# 126435744                           NaN                               NaN
#
#            STR3_EXEC_tfce_tstat_CP_3mm  STR3_EXEC_tfce_p_tstat_CP_3mm  \
# 126439333                          NaN                            NaN
# 126432538                          NaN                            NaN
# 126435762                          NaN                            NaN
# 126439285                          NaN                            NaN
# 126435744                          NaN                            NaN
#
#            GM_0.0_tstat_CP_3mm  GM_0.0_tfce_corrp_tstat_CP_3mm  \
# 126439333                  NaN                             NaN
# 126432538                  NaN                             NaN
# 126435762                  NaN                             NaN
# 126439285                  NaN                             NaN
# 126435744                  NaN                             NaN
#
#            GM_0.0_vox_p_tstat_CP_3mm  GM_0.0_vox_corrp_tstat_CP_3mm  \
# 126439333                        NaN                            NaN
# 126432538                        NaN                            NaN
# 126435762                        NaN                            NaN
# 126439285                        NaN                            NaN
# 126435744                        NaN                            NaN
#
#            GM_0.0_tfce_tstat_CP_3mm  GM_0.0_tfce_p_tstat_CP_3mm  \
# 126439333                       NaN                         NaN
# 126432538                       NaN                         NaN
# 126435762                       NaN                         NaN
# 126439285                       NaN                         NaN
# 126435744                       NaN                         NaN
#
#            Caud_tstat_CP_4mm  Caud_tfce_corrp_tstat_CP_4mm  \
# 126439333                NaN                           NaN
# 126432538                NaN                           NaN
# 126435762                NaN                           NaN
# 126439285                NaN                           NaN
# 126435744                NaN                           NaN
#
#            Caud_vox_p_tstat_CP_4mm  Caud_vox_corrp_tstat_CP_4mm  \
# 126439333                      NaN                          NaN
# 126432538                      NaN                          NaN
# 126435762                      NaN                          NaN
# 126439285                      NaN                          NaN
# 126435744                      NaN                          NaN
#
#            Caud_tfce_tstat_CP_4mm  Caud_tfce_p_tstat_CP_4mm  \
# 126439333                     NaN                       NaN
# 126432538                     NaN                       NaN
# 126435762                     NaN                       NaN
# 126439285                     NaN                       NaN
# 126435744                     NaN                       NaN
#
#            Pall_tstat_CP_4mm  Pall_tfce_corrp_tstat_CP_4mm  \
# 126439333           1.880892                      0.733661
# 126432538                NaN                           NaN
# 126435762                NaN                           NaN
# 126439285                NaN                           NaN
# 126435744                NaN                           NaN
#
#            Pall_vox_p_tstat_CP_4mm  Pall_vox_corrp_tstat_CP_4mm  \
# 126439333                 0.955336                     0.017064
# 126432538                      NaN                          NaN
# 126435762                      NaN                          NaN
# 126439285                      NaN                          NaN
# 126435744                      NaN                          NaN
#
#            Pall_tfce_tstat_CP_4mm  Pall_tfce_p_tstat_CP_4mm  \
# 126439333             1343.924072                  0.980879
# 126432538                     NaN                       NaN
# 126435762                     NaN                       NaN
# 126439285                     NaN                       NaN
# 126435744                     NaN                       NaN
#
#            Puta_tstat_CP_4mm  Puta_tfce_corrp_tstat_CP_4mm  \
# 126439333                NaN                           NaN
# 126432538                NaN                           NaN
# 126435762                NaN                           NaN
# 126439285                NaN                           NaN
# 126435744                NaN                           NaN
#
#            Puta_vox_p_tstat_CP_4mm  Puta_vox_corrp_tstat_CP_4mm  \
# 126439333                      NaN                          NaN
# 126432538                      NaN                          NaN
# 126435762                      NaN                          NaN
# 126439285                      NaN                          NaN
# 126435744                      NaN                          NaN
#
# ...
# 126439285                    0.001133                    0.001391
# 126435744                    0.003544                    0.004293
#
#            MEAN_PATIENTS_GM_thr0.00_10  MEAN_PATIENTS_GM_1  \
# 126439333                     0.052125                 NaN
# 126432538                     0.000721           -0.014283
# 126435762                     0.001557           -0.015680
# 126439285                     0.001469           -0.006107
# 126435744                     0.005882           -0.017128
#
#            MEAN_PATIENTS_GM_2  MEAN_PATIENTS_GM_4  MEAN_PATIENTS_GM_6  \
# 126439333            0.006475            0.033433            0.023364
# 126432538           -0.015250           -0.015482           -0.015565
# 126435762           -0.016575           -0.021241           -0.023073
# 126439285           -0.007081           -0.011379           -0.015942
# 126435744           -0.016154           -0.012374           -0.012302
#
#            MEAN_PATIENTS_GM_8  MEAN_PATIENTS_GM_10  MEAN_STR_LEMON_1mm  \
# 126439333            0.010929             0.002097                 NaN
# 126432538           -0.017517            -0.018457                 NaN
# 126435762           -0.022410            -0.021094                 NaN
# 126439285           -0.019306            -0.020558                 NaN
# 126435744           -0.014635            -0.015245                 NaN
#
#            MEAN_STR_LEMON_2mm  MEAN_STR_LEMON_3mm  MEAN_STR_LEMON_4mm  \
# 126439333                 NaN                 NaN                 NaN
# 126432538                 NaN                 NaN                 NaN
# 126435762                 NaN                 NaN                 NaN
# 126439285                 NaN                 NaN                 NaN
# 126435744                 NaN                 NaN                 NaN
#
#            MEAN_CAUD_LEMON_1mm  MEAN_CAUD_LEMON_2mm  MEAN_CAUD_LEMON_3mm  \
# 126439333                  NaN                  NaN                  NaN
# 126432538                  NaN                  NaN                  NaN
# 126435762                  NaN                  NaN                  NaN
# 126439285                  NaN                  NaN                  NaN
# 126435744                  NaN                  NaN                  NaN
#
#            MEAN_CAUD_LEMON_4mm  MEAN_PUTA_LEMON_1mm  MEAN_PUTA_LEMON_2mm  \
# 126439333                  NaN                  NaN                  NaN
# 126432538                  NaN                  NaN                  NaN
# 126435762                  NaN                  NaN                  NaN
# 126439285                  NaN                  NaN                  NaN
# 126435744                  NaN                  NaN                  NaN
#
#            MEAN_PUTA_LEMON_3mm  MEAN_PUTA_LEMON_4mm  MEAN_PALL_LEMON_1mm  \
# 126439333                  NaN                  NaN                  NaN
# 126432538                  NaN                  NaN                  NaN
# 126435762                  NaN                  NaN                  NaN
# 126439285                  NaN                  NaN                  NaN
# 126435744                  NaN                  NaN                  NaN
#
#            MEAN_PALL_LEMON_2mm  MEAN_PALL_LEMON_3mm  MEAN_PALL_LEMON_4mm  \
# 126439333                  NaN             0.074357             0.079958
# 126432538                  NaN                  NaN                  NaN
# 126435762                  NaN                  NaN                  NaN
# 126439285                  NaN                  NaN                  NaN
# 126435744                  NaN                  NaN                  NaN
#
#            MEAN_STR3_MOTOR_LEMON_1mm  MEAN_STR3_MOTOR_LEMON_2mm  \
# 126439333                        NaN                        NaN
# 126432538                        NaN                        NaN
# 126435762                        NaN                        NaN
# 126439285                        NaN                        NaN
# 126435744                        NaN                        NaN
#
#            MEAN_STR3_MOTOR_LEMON_3mm  MEAN_STR3_MOTOR_LEMON_4mm  \
# 126439333                        NaN                        NaN
# 126432538                        NaN                        NaN
# 126435762                        NaN                        NaN
# 126439285                        NaN                        NaN
# 126435744                        NaN                        NaN
#
#            MEAN_STR3_LIMBIC_LEMON_1mm  MEAN_STR3_LIMBIC_LEMON_2mm  \
# 126439333                         NaN                         NaN
# 126432538                         NaN                         NaN
# 126435762                         NaN                         NaN
# 126439285                         NaN                         NaN
# 126435744                         NaN                         NaN
#
#            MEAN_STR3_LIMBIC_LEMON_3mm  MEAN_STR3_LIMBIC_LEMON_4mm  \
# 126439333                         NaN                         NaN
# 126432538                         NaN                         NaN
# 126435762                         NaN                         NaN
# 126439285                         NaN                         NaN
# 126435744                         NaN                         NaN
#
#            MEAN_STR3_EXEC_LEMON_1mm  MEAN_STR3_EXEC_LEMON_2mm  \
# 126439333                       NaN                       NaN
# 126432538                       NaN                       NaN
# 126435762                       NaN                       NaN
# 126439285                       NaN                       NaN
# 126435744                       NaN                       NaN
#
#            MEAN_STR3_EXEC_LEMON_3mm  MEAN_STR3_EXEC_LEMON_4mm  \
# 126439333                       NaN                       NaN
# 126432538                       NaN                       NaN
# 126435762                       NaN                       NaN
# 126439285                       NaN                       NaN
# 126435744                       NaN                       NaN
#
#            MEAN_STR3_MOTOR_Pall_LEMON_1mm  MEAN_STR3_MOTOR_Pall_LEMON_2mm  \
# 126439333                             NaN                             NaN
# 126432538                             NaN                             NaN
# 126435762                             NaN                             NaN
# 126439285                             NaN                             NaN
# 126435744                             NaN                             NaN
#
#            MEAN_STR3_MOTOR_Pall_LEMON_3mm  MEAN_STR3_MOTOR_Pall_LEMON_4mm  \
# 126439333                        0.074357                        0.079958
# 126432538                             NaN                             NaN
# 126435762                             NaN                             NaN
# 126439285                             NaN                             NaN
# 126435744                             NaN                             NaN
#
#            MEAN_LEMON_GM_thr0.00_1  MEAN_LEMON_GM_thr0.00_2  \
# 126439333                 0.000675                 0.004594
# 126432538                      NaN                      NaN
# 126435762                      NaN                      NaN
# 126439285                      NaN                 0.000130
# 126435744                      NaN                 0.000059
#
#            MEAN_LEMON_GM_thr0.00_4  MEAN_LEMON_GM_thr0.00_6  \
# 126439333                 0.027371                 0.040553
# 126432538                      NaN                 0.001274
# 126435762                 0.000277                 0.003076
# 126439285                 0.000175                 0.000154
# 126435744                 0.000670                 0.003744
#
#            MEAN_LEMON_GM_thr0.00_8  MEAN_LEMON_GM_thr0.00_10  MEAN_LEMON_GM_1  \
# 126439333                 0.047259                  0.048396         0.000449
# 126432538                 0.001159                  0.001077        -0.008329
# 126435762                 0.002507                  0.002637        -0.009961
# 126439285                 0.000162                  0.000663        -0.001071
# 126435744                 0.005130                  0.006953        -0.020761
#
#            MEAN_LEMON_GM_2  MEAN_LEMON_GM_4  MEAN_LEMON_GM_6  MEAN_LEMON_GM_8  \
# 126439333         0.002704         0.014075         0.017452         0.013996
# 126432538        -0.009362        -0.009243        -0.009185        -0.011193
# 126435762        -0.010811        -0.011691        -0.011646        -0.011798
# 126439285        -0.002832        -0.007346        -0.011512        -0.013568
# 126435744        -0.019335        -0.015081        -0.011171        -0.010688
#
#            MEAN_LEMON_GM_10  MEAN_STR_ALL_1mm  MEAN_STR_ALL_2mm  \
# 126439333          0.008554               NaN               NaN
# 126432538         -0.012776               NaN               NaN
# 126435762         -0.011739               NaN               NaN
# 126439285         -0.014067               NaN               NaN
# 126435744         -0.009855               NaN               NaN
#
#            MEAN_STR_ALL_3mm  MEAN_STR_ALL_4mm  MEAN_CAUD_ALL_1mm  \
# 126439333               NaN               NaN                NaN
# 126432538               NaN               NaN                NaN
# 126435762               NaN               NaN                NaN
# 126439285               NaN               NaN                NaN
# 126435744               NaN               NaN                NaN
#
#            MEAN_CAUD_ALL_2mm  MEAN_CAUD_ALL_3mm  MEAN_CAUD_ALL_4mm  \
# 126439333                NaN                NaN                NaN
# 126432538                NaN                NaN                NaN
# 126435762                NaN                NaN                NaN
# 126439285                NaN                NaN                NaN
# 126435744                NaN                NaN                NaN
#
#            MEAN_PUTA_ALL_1mm  MEAN_PUTA_ALL_2mm  MEAN_PUTA_ALL_3mm  \
# 126439333                NaN                NaN                NaN
# 126432538                NaN                NaN                NaN
# 126435762                NaN                NaN                NaN
# 126439285                NaN                NaN                NaN
# 126435744                NaN                NaN                NaN
#
#            MEAN_PUTA_ALL_4mm  MEAN_PALL_ALL_1mm  MEAN_PALL_ALL_2mm  \
# 126439333                NaN                NaN                NaN
# 126432538                NaN                NaN                NaN
# 126435762                NaN                NaN                NaN
# 126439285                NaN                NaN                NaN
# 126435744                NaN                NaN                NaN
#
#            MEAN_PALL_ALL_3mm  MEAN_PALL_ALL_4mm  MEAN_STR3_MOTOR_ALL_1mm  \
# 126439333           0.068416           0.074434                      NaN
# 126432538                NaN                NaN                      NaN
# 126435762                NaN                NaN                      NaN
# 126439285                NaN                NaN                      NaN
# 126435744                NaN                NaN                      NaN
#
#            MEAN_STR3_MOTOR_ALL_2mm  MEAN_STR3_MOTOR_ALL_3mm  \
# 126439333                      NaN                      NaN
# 126432538                      NaN                      NaN
# 126435762                      NaN                      NaN
# 126439285                      NaN                      NaN
# 126435744                      NaN                      NaN
#
#            MEAN_STR3_MOTOR_ALL_4mm  MEAN_STR3_LIMBIC_ALL_1mm  \
# 126439333                      NaN                       NaN
# 126432538                      NaN                       NaN
# 126435762                      NaN                       NaN
# 126439285                      NaN                       NaN
# 126435744                      NaN                       NaN
#
#            MEAN_STR3_LIMBIC_ALL_2mm  MEAN_STR3_LIMBIC_ALL_3mm  \
# 126439333                       NaN                       NaN
# 126432538                       NaN                       NaN
# 126435762                       NaN                       NaN
# 126439285                       NaN                       NaN
# 126435744                       NaN                       NaN
#
#            MEAN_STR3_LIMBIC_ALL_4mm  MEAN_STR3_EXEC_ALL_1mm  \
# 126439333                       NaN                     NaN
# 126432538                       NaN                     NaN
# 126435762                       NaN                     NaN
# 126439285                       NaN                     NaN
# 126435744                       NaN                     NaN
#
#            MEAN_STR3_EXEC_ALL_2mm  MEAN_STR3_EXEC_ALL_3mm  \
# 126439333                     NaN                     NaN
# 126432538                     NaN                     NaN
# 126435762                     NaN                     NaN
# 126439285                     NaN                     NaN
# 126435744                     NaN                     NaN
#
#            MEAN_STR3_EXEC_ALL_4mm  MEAN_STR3_MOTOR_Pall_ALL_1mm  \
# 126439333                     NaN                           NaN
# 126432538                     NaN                           NaN
# 126435762                     NaN                           NaN
# 126439285                     NaN                           NaN
# 126435744                     NaN                           NaN
#
#            MEAN_STR3_MOTOR_Pall_ALL_2mm  MEAN_STR3_MOTOR_Pall_ALL_3mm  \
# 126439333                           NaN                      0.068416
# 126432538                           NaN                           NaN
# 126435762                           NaN                           NaN
# 126439285                           NaN                           NaN
# 126435744                           NaN                           NaN
#
#            MEAN_STR3_MOTOR_Pall_ALL_4mm  MEAN_ALL_GM_thr0.00_1  \
# 126439333                      0.074434               0.000458
# 126432538                           NaN                    NaN
# 126435762                           NaN                    NaN
# 126439285                           NaN                    NaN
# 126435744                           NaN                    NaN
#
#            MEAN_ALL_GM_thr0.00_2  MEAN_ALL_GM_thr0.00_4  \
# 126439333               0.003964               0.025395
# 126432538                    NaN                    NaN
# 126435762                    NaN               0.000071
# 126439285               0.000044               0.000095
# 126435744               0.000131               0.000792
#
#            MEAN_ALL_GM_thr0.00_6  MEAN_ALL_GM_thr0.00_8  \
# 126439333               0.038772               0.045811
# 126432538               0.001283               0.001044
# 126435762               0.003061               0.002131
# 126439285               0.000180               0.000189
# 126435744               0.003078               0.004411
#
#            MEAN_ALL_GM_thr0.00_10  MEAN_ALL_GM_1  MEAN_ALL_GM_2  \
# 126439333                0.047311       0.000304       0.002348
# 126432538                0.000914      -0.009090      -0.010071
# 126435762                0.002107      -0.011785      -0.012178
# 126439285                0.000199      -0.001639      -0.002875
# 126435744                0.006203      -0.020665      -0.019190
#
#            MEAN_ALL_GM_4  MEAN_ALL_GM_6  MEAN_ALL_GM_8  MEAN_ALL_GM_10
# 126439333       0.013047       0.016171       0.012646        0.007206
# 126432538      -0.010276      -0.010227      -0.012266       -0.013677
# 126435762      -0.012919      -0.013119      -0.013036       -0.012787
# 126439285      -0.006208      -0.009483      -0.011921       -0.012940
# 126435744      -0.014494      -0.011391      -0.011369       -0.010711

# %%
GOALL = 'gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/c5.all.v6.2.symbols.gmt'
GOBP  = 'gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/c5.bp.v6.2.symbols.gmt'
GOMF  = 'gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/c5.cc.v6.2.symbols.gmt'
GOCC  = 'gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/c5.mf.v6.2.symbols.gmt'
            
GOALLREACTOME = 'gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/c2.cp.reactome.v6.2.symbols.gmt,gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/c5.all.v6.2.symbols.gmt'
GOBPREACTOME  = 'gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/c2.cp.reactome.v6.2.symbols.gmt,gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/c5.bp.v6.2.symbols.gmt'
GOALLKEGG     ='gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/c2.cp.kegg.v6.2.symbols.gmt,gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/c5.all.v6.2.symbols.gmt'
GOALLREACTKEGG= 'gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/c2.cp.kegg.v6.2.symbols.gmt,gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/c2.cp.reactome.v6.2.symbols.gmt,gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/c5.all.v6.2.symbols.gmt'

CURATEDALL = 'gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/c2.all.v6.2.symbols.gmt'
CANONICAL  = 'gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/c2.cp.v6.2.symbols.gmt' 
CHEMGEN    = 'gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/c2.cgp.v6.2.symbols.gmt'
BIOCARTA   = 'gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/c2.cp.biocarta.v6.2.symbols.gmt'
KEGG       = 'gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/c2.cp.kegg.v6.2.symbols.gmt'
REACTOME   = 'gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/c2.cp.reactome.v6.2.symbols.gmt'
HALLMARK   = 'gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/h.all.v6.2.symbols.gmt'

# %%
def make_geneset_enrichment_stats(nucleus, gset, gset_name, gset_size, fname, corr_type='pearson'):

    ################################
    # This code runs a Geneset enrichment analysis 
    # Gene Set Enrichment Analysis (GSEA) is a computational method 
    # that determines whether an a priori defined set of genes shows statistically 
    # significant, concordant differences between two biological states (e.g. phenotypes). 
    # https://software.broadinstitute.org/gsea/index.jsp
    
    ################################
    # Create preranked table 
    # This is a 2x20737 matrix with gene names for col1 and R-values for col2
    # R-Values represent the association between gene-expression leves and t-statistical susceptibility difference 
    
    print 'Running gene set enrichment analysis for %s nucleus with %s and size %s and %s correlation' %(fname, gset_name, gset_size, corr_type)
    
    rank_file   = os.path.join(gsea_dir, 'GSEA_%s_%s.rnk'%(fname,corr_type))
    
    if not os.path.isfile(rank_file):
        print '.....creating rank file'
        GENES = AHBA.columns[:-28]
        df_GSEA = pd.DataFrame(index = ['r_val'], columns =GENES)#.T

        df_chi  = df_MNI.drop([i for i in df_MNI.columns if i not in ['STR_tstat_CP_1mm']],axis=1)
        df_chi  = pd.DataFrame(dfs["df_MU"][nucleus].drop(wells,axis=0).dropna())

        for gene in GENES:
            #print gene
            df_chigen = pd.DataFrame(index = df_chi.index)
            df_chigen['GEN'] = AHBA[gene]
            df_chigen['chi'] = df_chi[nucleus]

            # make correlations 
            if corr_type == 'pearson':
                pearson  = pearsonr(df_chigen['chi'], df_chigen['GEN'])
                df_GSEA.loc["r_val"][gene] =  pearson[0]
            elif corr_type == 'spearman':
                spearman  = spearmanr(df_chigen['chi'], df_chigen['GEN'])
                df_GSEA.loc["r_val"][gene] =  spearman[0]

        df_GSEA = df_GSEA.T.sort_values("r_val", ascending=False)
        df_GSEA.index.name = "Gene"
        df_GSEA.to_csv(rank_file, sep='\t')
    
    ###############################
    # Run gsea-3.0.jar
    
    outfname = '%s_%s_%s' %(fname, gset_name, gset_size )
    logfile  = os.path.join(gsea_dir, 'log_%s.txt'%outfname)
    
    outfolder = [i for i in os.listdir(gsea_dir) if outfname in i ]
    
    if outfolder:
        print '.....file made:', outfolder[0]
    
    else:
        print '..... runing gsea-3.0.jar'
        gsea_cmd = ' '.join(['java -Xmx512m',
                    '-cp ~/Desktop/gsea-3.0.jar xtools.gsea.GseaPreranked', 
                    '-gmx ' + gset,
                    '-norm meandiv -nperm 1000', 
                    '-rnk '+ rank_file,
                    '-scoring_scheme weighted',
                    '-rpt_label ' + outfname,
                    '-create_svgs false',
                    '-make_sets true',
                    '-plot_top_x 1000', 
                    '-rnd_seed timestamp',
                    '-set_max %s'%gset_size, 
                    '-set_min 15',
                    '-zip_report false',
                    '-out ' + gsea_dir, 
                    '-gui false',
                    '> ' + logfile 
                  ])

        print '..... %s' %gsea_cmd
        os.system(gsea_cmd)

# %%
nuc = ['STR3_MOTOR_tstat_LL_1mm']


for size in [500]:
    #make_geneset_enrichment_stats(nuc, GOALL, 'GO_all' , gset_size=size, fname = 'STR', corr_type='pearson')
    #make_geneset_enrichment_stats(nuc, KEGG, 'KEGG' , gset_size=size, fname = 'STR', corr_type='pearson')
    #make_geneset_enrichment_stats(nuc, REACTOME, 'REACTOME' , gset_size=size, fname = 'STR', corr_type='pearson')
    make_geneset_enrichment_stats(nuc, GOALLREACTOME, 'GOALLREACTOME' , gset_size=size, fname = 'STR', corr_type='pearson')
    #make_geneset_enrichment_stats(nuc, GOALLKEGG, 'GOALLKEGG' , gset_size=size, fname = 'STR', corr_type='pearson')
    make_geneset_enrichment_stats(nuc, GOALLREACTKEGG, 'GOALLREACTKEGG' , gset_size=size, fname = 'STR_LL', corr_type='pearson')
    #make_geneset_enrichment_stats(nuc, HALLMARK, 'HALLMARK' , gset_size=size, fname = 'STR_LL', corr_type='pearson')
# Out:
# Running gene set enrichment analysis for STR nucleus with GOALLREACTOME and size 500 and pearson correlation
# .....creating rank file
# .....file made: STR_GOALLREACTOME_500.GseaPreranked.1559596403531
# Running gene set enrichment analysis for STR_LL nucleus with GOALLREACTKEGG and size 500 and pearson correlation
# .....file made: log_STR_LL_GOALLREACTKEGG_500.txt

# %%
nuc = ['STR3_MOTOR_tstat_CP_1mm']
nuc = ['MEAN_STR3_MOTOR_LEMON_1mm']

for size in [500]:
    #make_geneset_enrichment_stats(nuc, GOALL, 'GO_all' , gset_size=size, fname = 'STR', corr_type='pearson')
    #make_geneset_enrichment_stats(nuc, KEGG, 'KEGG' , gset_size=size, fname = 'STR', corr_type='pearson')
    #make_geneset_enrichment_stats(nuc, REACTOME, 'REACTOME' , gset_size=size, fname = 'STR', corr_type='pearson')
    #make_geneset_enrichment_stats(nuc, GOALLREACTOME, 'GOALLREACTOME' , gset_size=size, fname = 'STR', corr_type='pearson')
    #make_geneset_enrichment_stats(nuc, GOALLKEGG, 'GOALLKEGG' , gset_size=size, fname = 'STR', corr_type='pearson')
    #make_geneset_enrichment_stats(nuc, GOALLREACTKEGG, 'GOALLREACTKEGG' , gset_size=size, fname = 'STR3_MOTOR_MEAN_LEMON', corr_type='pearson')
    make_geneset_enrichment_stats(nuc, HALLMARK, 'HALLMARK' , gset_size=size, fname = 'STR3_MOTOR_MEAN_LEMON', corr_type='pearson')
# Out:
# Running gene set enrichment analysis for STR3_MOTOR_MEAN_LEMON nucleus with HALLMARK and size 500 and pearson correlation
# ..... runing gsea-3.0.jar
# ..... java -Xmx512m -cp ~/Desktop/gsea-3.0.jar xtools.gsea.GseaPreranked -gmx gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/h.all.v6.2.symbols.gmt -norm meandiv -nperm 1000 -rnk /Users/kanaaax/Desktop/GSEA/GSEA_STR3_MOTOR_MEAN_LEMON_pearson.rnk -scoring_scheme weighted -rpt_label STR3_MOTOR_MEAN_LEMON_HALLMARK_500 -create_svgs false -make_sets true -plot_top_x 1000 -rnd_seed timestamp -set_max 500 -set_min 15 -zip_report false -out /Users/kanaaax/Desktop/GSEA -gui false > /Users/kanaaax/Desktop/GSEA/log_STR3_MOTOR_MEAN_LEMON_HALLMARK_500.txt

# %%
nuc = ['MEAN_STR_LEMON_1mm']

for size in [500]:
    #make_geneset_enrichment_stats(nuc, GOALL, 'GO_all' , gset_size=size, fname = 'STR', corr_type='pearson')
    #make_geneset_enrichment_stats(nuc, KEGG, 'KEGG' , gset_size=size, fname = 'STR', corr_type='pearson')
    #make_geneset_enrichment_stats(nuc, REACTOME, 'REACTOME' , gset_size=size, fname = 'STR', corr_type='pearson')
    #make_geneset_enrichment_stats(nuc, GOALLREACTOME, 'GOALLREACTOME' , gset_size=size, fname = 'STR', corr_type='pearson')
    #make_geneset_enrichment_stats(nuc, GOALLKEGG, 'GOALLKEGG' , gset_size=size, fname = 'STR', corr_type='pearson')
    make_geneset_enrichment_stats(nuc, GOALLREACTKEGG, 'GOALLREACTKEGG' , gset_size=size, fname = 'STR_MEAN_LEMON', corr_type='pearson')
    #make_geneset_enrichment_stats(nuc, HALLMARK, 'HALLMARK' , gset_size=size, fname = 'STR_sp', corr_type='spearman')

# %%
nuc = ['STR3_MOTOR_tstat_CP_1mm']

for size in [500]:
    #make_geneset_enrichment_stats(nuc, GOALL, 'GO_all' , gset_size=size, fname = 'STR3_MOTOR', corr_type='pearson')
    #make_geneset_enrichment_stats(nuc, KEGG, 'KEGG' , gset_size=size, fname = 'STR3_MOTOR', corr_type='pearson')
    #make_geneset_enrichment_stats(nuc, REACTOME, 'REACTOME' , gset_size=size, fname = 'STR3_MOTOR', corr_type='pearson')
    #make_geneset_enrichment_stats(nuc, GOALLREACTOME, 'GOALLREACTOME' , gset_size=size, fname = 'STR3_MOTOR_plt', corr_type='pearson')
    #make_geneset_enrichment_stats(nuc, GOALLKEGG, 'GOALLKEGG' , gset_size=size, fname = 'STR3_MOTOR', corr_type='pearson')
    make_geneset_enrichment_stats(nuc, GOALLREACTKEGG, 'GOALLREACTKEGG' , gset_size=size, fname = 'STR3_MOTOR', corr_type='pearson')
    make_geneset_enrichment_stats(nuc, HALLMARK, 'HALLMARK' , gset_size=size, fname = 'STR3_MOTOR', corr_type='pearson')
    make_geneset_enrichment_stats(nuc, GOALLREACTKEGG, 'GOALLREACTKEGG' , gset_size=size, fname = 'STR3_MOTOR_spr', corr_type='spearman')
    make_geneset_enrichment_stats(nuc, HALLMARK, 'HALLMARK' , gset_size=size, fname = 'STR3_MOTOR_spr', corr_type='spearman')
# Out:
# Running gene set enrichment analysis for STR3_MOTOR nucleus with GOALLREACTKEGG and size 500 and pearson correlation
# .....creating rank file
# .....file made: log_STR3_MOTOR_GOALLREACTKEGG_500.txt
# Running gene set enrichment analysis for STR3_MOTOR nucleus with HALLMARK and size 500 and pearson correlation
# .....file made: STR3_MOTOR_HALLMARK_500.GseaPreranked.1559603519788
# Running gene set enrichment analysis for STR3_MOTOR_spr nucleus with GOALLREACTKEGG and size 500 and spearman correlation
# .....creating rank file
# .....file made: log_STR3_MOTOR_spr_GOALLREACTKEGG_500.txt
# Running gene set enrichment analysis for STR3_MOTOR_spr nucleus with HALLMARK and size 500 and spearman correlation
# .....file made: STR3_MOTOR_spr_HALLMARK_500.GseaPreranked.1559860839809

# %%
nuc = ['STR3_EXEC_tstat_CP_1mm']

for size in [500]:
    make_geneset_enrichment_stats(nuc, GOALL, 'GO_all' , gset_size=size, fname = 'STR3_EXEC', corr_type='pearson')
    make_geneset_enrichment_stats(nuc, KEGG, 'KEGG' , gset_size=size, fname = 'STR3_EXEC', corr_type='pearson')
    make_geneset_enrichment_stats(nuc, REACTOME, 'REACTOME' , gset_size=size, fname = 'STR3_EXEC', corr_type='pearson')
    make_geneset_enrichment_stats(nuc, G®†OALLREACTOME, 'GOALLREACTOME' , gset_size=size, fname = 'STR3_EXEC', corr_type='pearson')
    make_geneset_enrichment_stats(nuc, GOALLKEGG, 'GOALLKEGG' , gset_size=size, fname = 'STR3_EXEC', corr_type='pearson')
    make_geneset_enrichment_stats(nuc, GOALLREACTKEGG, 'GOALLREACTKEGG' , gset_size=size, fname = 'STR3_EXEC', corr_type='pearson')
    make_geneset_enrichment_stats(nuc, HALLMARK, 'HALLMARK' , gset_size=size, fname = 'STR3_EXEC', corr_type='pearson')
# Out:
#   File "<ipython-input-9-14840d89c641>", line 7
#     make_geneset_enrichment_stats(nuc, G®†OALLREACTOME, 'GOALLREACTOME' , gset_size=size, fname = 'STR3_EXEC', corr_type='pearson')
#                                         ^
# SyntaxError: invalid syntax

# %%
nuc = ['STR3_LIMBIC_tstat_CP_1mm']

for size in [500]:
    make_geneset_enrichment_stats(nuc, GOALL, 'GO_all' , gset_size=size, fname = 'STR3_LIMBIC', corr_type='pearson')
    make_geneset_enrichment_stats(nuc, KEGG, 'KEGG' , gset_size=size, fname = 'STR3_LIMBIC', corr_type='pearson')
    make_geneset_enrichment_stats(nuc, REACTOME, 'REACTOME' , gset_size=size, fname = 'STR3_LIMBIC', corr_type='pearson')
    make_geneset_enrichment_stats(nuc, GOALLREACTOME, 'GOALLREACTOME' , gset_size=size, fname = 'STR3_LIMBIC', corr_type='pearson')
    make_geneset_enrichment_stats(nuc, GOALLKEGG, 'GOALLKEGG' , gset_size=size, fname = 'STR3_LIMBIC', corr_type='pearson')
    make_geneset_enrichment_stats(nuc, GOALLREACTKEGG, 'GOALLREACTKEGG' , gset_size=size, fname = 'STR3_MOTOR', corr_type='pearson')
    make_geneset_enrichment_stats(nuc, HALLMARK, 'HALLMARK' , gset_size=size, fname = 'STR3_LIMBIC', corr_type='pearson')

# %%
nuc = ['GM_0.0_tstat_CP_1mm']

for size in [500]:
    make_geneset_enrichment_stats(nuc, GOALL, 'GO_all' , gset_size=size, fname = 'GM_0.0', corr_type='pearson')
    make_geneset_enrichment_stats(nuc, KEGG, 'KEGG' , gset_size=size, fname = 'GM_0.0', corr_type='pearson')
    make_geneset_enrichment_stats(nuc, REACTOME, 'REACTOME' , gset_size=size, fname = 'GM_0.0', corr_type='pearson')
    make_geneset_enrichment_stats(nuc, GOALLREACTOME, 'GOALLREACTOME' , gset_size=size, fname = 'GM', corr_type='pearson')
    make_geneset_enrichment_stats(nuc, GOALLKEGG, 'GOALLKEGG' , gset_size=size, fname = 'GM_0.0', corr_type='pearson')
    make_geneset_enrichment_stats(nuc, GOALLREACTKEGG, 'GOALLREACTKEGG' , gset_size=size, fname = 'GM_0.0', corr_type='pearson')
    make_geneset_enrichment_stats(nuc, HALLMARK, 'HALLMARK' , gset_size=size, fname = 'GM_0.0', corr_type='pearson')
# Out:
# Running gene set enrichment analysis for GM_0.0 nucleus with GO_all and size 500 and pearson correlation
# .....creating rank file
# ..... runing gsea-3.0.jar
# ..... java -Xmx512m -cp ~/Desktop/gsea-3.0.jar xtools.gsea.GseaPreranked -gmx gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/c5.all.v6.2.symbols.gmt -norm meandiv -nperm 1000 -rnk /Users/kanaaax/Desktop/GSEA/GSEA_GM_0.0_pearson.rnk -scoring_scheme weighted -rpt_label GM_0.0_GO_all_500 -create_svgs false -make_sets true -plot_top_x 1000 -rnd_seed timestamp -set_max 500 -set_min 15 -zip_report false -out /Users/kanaaax/Desktop/GSEA -gui false > /Users/kanaaax/Desktop/GSEA/log_GM_0.0_GO_all_500.txt
# Running gene set enrichment analysis for GM_0.0 nucleus with KEGG and size 500 and pearson correlation
# ..... runing gsea-3.0.jar
# ..... java -Xmx512m -cp ~/Desktop/gsea-3.0.jar xtools.gsea.GseaPreranked -gmx gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/c2.cp.kegg.v6.2.symbols.gmt -norm meandiv -nperm 1000 -rnk /Users/kanaaax/Desktop/GSEA/GSEA_GM_0.0_pearson.rnk -scoring_scheme weighted -rpt_label GM_0.0_KEGG_500 -create_svgs false -make_sets true -plot_top_x 1000 -rnd_seed timestamp -set_max 500 -set_min 15 -zip_report false -out /Users/kanaaax/Desktop/GSEA -gui false > /Users/kanaaax/Desktop/GSEA/log_GM_0.0_KEGG_500.txt
# Running gene set enrichment analysis for GM_0.0 nucleus with REACTOME and size 500 and pearson correlation
# ..... runing gsea-3.0.jar
# ..... java -Xmx512m -cp ~/Desktop/gsea-3.0.jar xtools.gsea.GseaPreranked -gmx gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/c2.cp.reactome.v6.2.symbols.gmt -norm meandiv -nperm 1000 -rnk /Users/kanaaax/Desktop/GSEA/GSEA_GM_0.0_pearson.rnk -scoring_scheme weighted -rpt_label GM_0.0_REACTOME_500 -create_svgs false -make_sets true -plot_top_x 1000 -rnd_seed timestamp -set_max 500 -set_min 15 -zip_report false -out /Users/kanaaax/Desktop/GSEA -gui false > /Users/kanaaax/Desktop/GSEA/log_GM_0.0_REACTOME_500.txt
# Running gene set enrichment analysis for GM nucleus with GOALLREACTOME and size 500 and pearson correlation
# .....creating rank file
# ..... runing gsea-3.0.jar
# ..... java -Xmx512m -cp ~/Desktop/gsea-3.0.jar xtools.gsea.GseaPreranked -gmx gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/c2.cp.reactome.v6.2.symbols.gmt,gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/c5.all.v6.2.symbols.gmt -norm meandiv -nperm 1000 -rnk /Users/kanaaax/Desktop/GSEA/GSEA_GM_pearson.rnk -scoring_scheme weighted -rpt_label GM_GOALLREACTOME_500 -create_svgs false -make_sets true -plot_top_x 1000 -rnd_seed timestamp -set_max 500 -set_min 15 -zip_report false -out /Users/kanaaax/Desktop/GSEA -gui false > /Users/kanaaax/Desktop/GSEA/log_GM_GOALLREACTOME_500.txt
# Running gene set enrichment analysis for GM_0.0 nucleus with GOALLKEGG and size 500 and pearson correlation
# ..... runing gsea-3.0.jar
# ..... java -Xmx512m -cp ~/Desktop/gsea-3.0.jar xtools.gsea.GseaPreranked -gmx gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/c2.cp.kegg.v6.2.symbols.gmt,gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/c5.all.v6.2.symbols.gmt -norm meandiv -nperm 1000 -rnk /Users/kanaaax/Desktop/GSEA/GSEA_GM_0.0_pearson.rnk -scoring_scheme weighted -rpt_label GM_0.0_GOALLKEGG_500 -create_svgs false -make_sets true -plot_top_x 1000 -rnd_seed timestamp -set_max 500 -set_min 15 -zip_report false -out /Users/kanaaax/Desktop/GSEA -gui false > /Users/kanaaax/Desktop/GSEA/log_GM_0.0_GOALLKEGG_500.txt
# Running gene set enrichment analysis for GM_0.0 nucleus with GOALLREACTKEGG and size 500 and pearson correlation
# ..... runing gsea-3.0.jar
# ..... java -Xmx512m -cp ~/Desktop/gsea-3.0.jar xtools.gsea.GseaPreranked -gmx gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/c2.cp.kegg.v6.2.symbols.gmt,gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/c2.cp.reactome.v6.2.symbols.gmt,gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/c5.all.v6.2.symbols.gmt -norm meandiv -nperm 1000 -rnk /Users/kanaaax/Desktop/GSEA/GSEA_GM_0.0_pearson.rnk -scoring_scheme weighted -rpt_label GM_0.0_GOALLREACTKEGG_500 -create_svgs false -make_sets true -plot_top_x 1000 -rnd_seed timestamp -set_max 500 -set_min 15 -zip_report false -out /Users/kanaaax/Desktop/GSEA -gui false > /Users/kanaaax/Desktop/GSEA/log_GM_0.0_GOALLREACTKEGG_500.txt
# Running gene set enrichment analysis for GM_0.0 nucleus with HALLMARK and size 500 and pearson correlation
# ..... runing gsea-3.0.jar
# ..... java -Xmx512m -cp ~/Desktop/gsea-3.0.jar xtools.gsea.GseaPreranked -gmx gseaftp.broadinstitute.org://pub/gsea/gene_sets_final/h.all.v6.2.symbols.gmt -norm meandiv -nperm 1000 -rnk /Users/kanaaax/Desktop/GSEA/GSEA_GM_0.0_pearson.rnk -scoring_scheme weighted -rpt_label GM_0.0_HALLMARK_500 -create_svgs false -make_sets true -plot_top_x 1000 -rnd_seed timestamp -set_max 500 -set_min 15 -zip_report false -out /Users/kanaaax/Desktop/GSEA -gui false > /Users/kanaaax/Desktop/GSEA/log_GM_0.0_HALLMARK_500.txt

# %%
import pandas as pd

# %%
x = pd.read_csv('/Users/kanaaax/Desktop/GSEA/STR3_MOTOR_GOALLREACTKEGG_500.GseaPreranked.1559602912792/edb/GSEA_STR3_MOTOR_pearson.rnk',
            sep='\t', header=None)[0][0:1000]
list(x)
# Out:
# ['RPL22',
#  'COL16A1',
#  'ELL2',
#  'AC005393.1',
#  'C17orf56',
#  'MAGI2',
#  'RPL10A',
#  'C20orf39',
#  'PLEKHA1',
#  'ZDHHC11',
#  'LSM3',
#  'SUPT4H1',
#  'LOC648771',
#  'RPL23',
#  'PSRC1',
#  'LOC440311',
#  'FTH1P20',
#  'POLR3GL',
#  'CNOT2',
#  'POLR2I',
#  'SFTPC',
#  'ARHGEF2',
#  'SERTAD2',
#  'MYH9',
#  'EXOSC10',
#  'HNRNPC',
#  'SNHG1',
#  'MAP3K3',
#  'PUF60',
#  'MAN2A2',
#  'RPS8',
#  'NACA',
#  'BLOC1S1',
#  'GUK1',
#  'CTSB',
#  'DDRGK1',
#  'ANAPC5',
#  'NACA2',
#  'LOC653881',
#  'GPR124',
#  'NME2P1',
#  'LOC100289173',
#  'RPL32',
#  'RAPGEF5',
#  'DNAJC25-GNG10',
#  'SHB',
#  'TMEM50A',
#  'SEPW1',
#  'BSG',
#  'HNRNPUL1',
#  'MGRN1',
#  'RPL37',
#  'OSTF1',
#  'RPL31',
#  'PABPN1',
#  'VASH1',
#  'NME2',
#  'FAHD2B',
#  'SH3PXD2A',
#  'SH3GL1',
#  'SNED1',
#  'RPL23A',
#  'RPL36A',
#  'OSBPL1A',
#  'MTMR2',
#  'KIAA0892',
#  'TMEM151A',
#  'RPL13AP3',
#  'CA1',
#  'STAC2',
#  'RPS3P3',
#  'RPL15',
#  'UXT',
#  'DLG1',
#  'UNC5B',
#  'MYO9B',
#  'MYBPHL',
#  'RPL11',
#  'HNRPDL',
#  'EIF3G',
#  'RPL35A',
#  'EXOSC1',
#  'AMZ2',
#  'RPL39',
#  'MRPL33',
#  'EIF1',
#  'IFRD2',
#  'H3F3AP4',
#  'RNF220',
#  'RBMX',
#  'C8orf46',
#  'AFG3L1P',
#  'SNF8',
#  'ROGDI',
#  'C16orf88',
#  'AC013402.2',
#  'LIME1',
#  'RPS20',
#  'PXMP4',
#  'RPL26',
#  'ATP10A',
#  'KCNA1',
#  'CCT4',
#  'SF3A3',
#  'TOMM7',
#  'OSGEP',
#  'SFRS8',
#  'CCNI',
#  'AGRN',
#  'RPS7',
#  'HR',
#  'RPS6',
#  'ADO',
#  'ISOC2',
#  'LOC100133161',
#  'RPS27A',
#  'USP48',
#  'EEF2',
#  'RPL13',
#  'RPS13P2',
#  'POGK',
#  'MTCP1NB',
#  'GDE1',
#  'NFIC',
#  'RPLP2',
#  'RPS17',
#  'SEMA4C',
#  'POLR2F',
#  'MBD3',
#  'MX2',
#  'RPS21',
#  'DRAP1',
#  'RPL12',
#  'ACTN4',
#  'FAM98C',
#  'C9orf123',
#  'FAM120C',
#  'PURB',
#  'HACL1',
#  'LOC730144',
#  'C16orf94',
#  'PACS2',
#  'ASPHD1',
#  'KIAA0467',
#  'RBM10',
#  'RPL7',
#  'CFL1P1',
#  'SLC5A11',
#  'NLRX1',
#  'RPS12',
#  'RPL4',
#  'NCAPD2',
#  'LGI3',
#  'FCHO1',
#  'UBL7',
#  'CUTA',
#  'C1orf43',
#  'OVCA2',
#  'H1F0',
#  'IPO13',
#  'CAPN13',
#  'LOC100287260',
#  'TACC1',
#  'KLF13',
#  'ZNF524',
#  'ZMIZ2',
#  'EIF4B',
#  'RPL9',
#  'ZNF827',
#  'CIDEA',
#  'FBRS',
#  'FSCN1',
#  'FRMD5',
#  'APC2',
#  'RPL8',
#  'RNF5P1',
#  'C2orf84',
#  'RPL36AL',
#  'APPBP2',
#  'MBNL2',
#  'BAX',
#  'PLCXD1',
#  'UQCRFS1',
#  'TULP4',
#  'ITFG2',
#  'PARP1',
#  'SEMA7A',
#  'NDUFA4',
#  'FAM131B',
#  'YPEL2',
#  'EPB41L4A-AS1',
#  'ZBTB47',
#  'KCNMB4',
#  'SH3GL3',
#  'CNPY2',
#  'UQCR11',
#  'SERF1A',
#  'ZNF189',
#  'GPBP1',
#  'TMEM53',
#  'CHCHD8',
#  'RPS27AP11',
#  'KIAA0196',
#  'STK39',
#  'LAYN',
#  'BECN1',
#  'RPS15P5',
#  'ZDHHC4',
#  'RPL29',
#  'MAPKAPK5',
#  'C11orf10',
#  'FEZ1',
#  'ZNF609',
#  'NUDCD2',
#  'UCRC',
#  'DDB2',
#  'LOC728532',
#  'RPL30',
#  'EIF3L',
#  'WNK1',
#  'CDC42EP2',
#  'TIMM9',
#  'MGC16384',
#  'KRT8P9',
#  'C7orf26',
#  'SEC14L5',
#  'TMEM14B',
#  'GLTSCR2',
#  'CSNK2B',
#  'CHMP2A',
#  'POLDIP2',
#  'C1orf77',
#  'TRABD',
#  'GATAD2B',
#  'SAT2',
#  'TCEB1',
#  'ABHD6',
#  'PPP2R3C',
#  'NUP133',
#  'MDP1',
#  'CHCHD2',
#  'RPS18',
#  'C9orf23',
#  'CCDC97',
#  'CTRL',
#  'NHP2',
#  'FAU',
#  'C11orf9',
#  'SIRT2',
#  'ATP5I',
#  'PCTK3',
#  'NKTR',
#  'PSME2',
#  'MAP3K11',
#  'UBXN1',
#  'VPS52',
#  'SPOCK3',
#  'LOC645937',
#  'PPDPF',
#  'PPIEL',
#  'RHOBTB1',
#  'HNRNPU',
#  'SP2',
#  'BRD7',
#  'XPA',
#  'NAA38',
#  'RPL21P44',
#  'PRKAB2',
#  'C12orf57',
#  'TRIP4',
#  'RHOG',
#  'TRPV1',
#  'SOHLH1',
#  'SIRT5',
#  'EIF3K',
#  'CMC2',
#  'ZNFX1-AS1',
#  'KIAA1009',
#  'LARP6',
#  'RPL21',
#  'LHPP',
#  'RPL5',
#  'IDI1',
#  'ITPA',
#  'ECHDC1',
#  'MYLK',
#  'ZBTB17',
#  'HNRNPA2B1',
#  'C1orf162',
#  'SNRPEP4',
#  'RPS29',
#  'TOMM40L',
#  'ELAVL3',
#  'ANAPC11',
#  'LOC100287869',
#  'KRTCAP2',
#  'SDCCAG1',
#  'RPL7A',
#  'MXI1',
#  'PCBP2',
#  'TMEM126A',
#  'DHX37',
#  'PTPMT1',
#  'AATF',
#  'PLA2G4C',
#  'LOC100131706',
#  'RPL37A',
#  'LOC100288252',
#  'GOLGA7',
#  'RPL36',
#  'CROCCP2',
#  'NDUFC1',
#  'PHACTR3',
#  'PRKCQ',
#  'ZFR',
#  'C13orf23',
#  'ANKH',
#  'TYW3',
#  'BRK1',
#  'TMX2',
#  'POLR2G',
#  'FBXO32',
#  'NSUN5C',
#  'HNRNPH3',
#  'SH3TC2',
#  'ULK2',
#  'GPR20',
#  'EIF4E2',
#  'EIF3E',
#  'NCOA6',
#  'GOLGA1',
#  'PGAP2',
#  'SLC47A1',
#  'PAXIP1',
#  'FIS1',
#  'PRDM2',
#  'STX5',
#  'SCN1B',
#  'MAP6D1',
#  'PAF1',
#  'DAD1',
#  'PEBP1',
#  'DYNC1I2',
#  'GGCX',
#  'BOLA3',
#  'ZNF506',
#  'ACO2',
#  'COX7A2',
#  'PIGK',
#  'NSUN5',
#  'RWDD1',
#  'LOC644172',
#  'SLC12A9',
#  'NPFF',
#  'AHSA2',
#  'HNRNPR',
#  'DMRT2',
#  'BBS10',
#  'B2M',
#  'GCLC',
#  'HMOX2',
#  'MCTS1',
#  'P2RX7',
#  'ADAP2',
#  'LDOC1L',
#  'CIZ1',
#  'AP000347.4',
#  'RPS25',
#  'COBL',
#  'LCP2',
#  'KIAA1147',
#  'SLC48A1',
#  'MTA1',
#  'SLCO2B1',
#  'NXPH3',
#  'SFRS16',
#  'SUPT6H',
#  'PTP4A2',
#  'FKBP3',
#  'PTMA',
#  'FLJ30901',
#  'KCNK1',
#  'PKD2',
#  'PDIA2',
#  'ZNF7',
#  'SNRPE',
#  'ARL6IP5',
#  'EIF3D',
#  'ZNF839',
#  'EEF1A1',
#  'RNF214',
#  'ANKHD1',
#  'KLHL24',
#  'AKAP8',
#  'DCTN1',
#  'JOSD2',
#  'DDT',
#  'TMEM59',
#  'HIGD2A',
#  'COX7C',
#  'RPL13AP6',
#  'EIF2B1',
#  'SEPT7',
#  'ST3GAL6',
#  'POP5',
#  'PFDN5',
#  'USE1',
#  'RASIP1',
#  'AC093838.4',
#  'C9orf3',
#  'RPL24',
#  'CBX7',
#  'HERC2P4',
#  'FAM63A',
#  'ANKRD65',
#  'MRPS18C',
#  'DBF4B',
#  'MRPL45',
#  'PCDH9',
#  'ROMO1',
#  'SRP68',
#  'RPL27',
#  'ARHGAP1',
#  'CLN8',
#  'HLA-J',
#  'LAGE3',
#  'ROBO4',
#  'PIK3C3',
#  'SORT1',
#  'BRP44L',
#  'BACE1',
#  'LOC100130107',
#  'ALDH1A1',
#  'NDUFS7',
#  'ZNF575',
#  'CCT6A',
#  'NPIPL3',
#  'RPS10',
#  'ZNF557',
#  'RPS4X',
#  'ZNF526',
#  'MKKS',
#  'SMA4',
#  'RSAD1',
#  'CHKA',
#  'DIMT1',
#  'U2AF1',
#  'ZFYVE21',
#  'NUP85',
#  'YY1',
#  'OLFML2A',
#  'PSMD7',
#  'PSMA6',
#  'CIRH1A',
#  'MLLT6',
#  'LRRC14',
#  'RAB5B',
#  'DDX47',
#  'LYNX1',
#  'BRD9',
#  'SPDYE3',
#  'LUC7L2',
#  'SYNJ2',
#  'PIR',
#  'JDP2',
#  'GPATCH8',
#  'LOC391334',
#  'PNN',
#  'GGT7',
#  'CASP9',
#  'COX8A',
#  'SORBS3',
#  'TJAP1',
#  'FAHD2A',
#  'CDK5RAP1',
#  'MOBP',
#  'FAM76B',
#  'NASP',
#  'EFHD1',
#  'ZNF187',
#  'UBC',
#  'UBE2D2',
#  'AC005921.3',
#  'POLR3C',
#  'SNX26',
#  'MBD2',
#  'C14orf133',
#  'FANCE',
#  'DUSP23',
#  'DCP1A',
#  'NVL',
#  'ZFP91',
#  'KIF5C',
#  'LOC100289525',
#  'LOC728533',
#  'SNX21',
#  'KIAA0141',
#  'SF3A1',
#  'DNLZ',
#  'HOXD1',
#  'AC008073.2',
#  'SEPN1',
#  'CCDC76',
#  'GPATCH4',
#  'LMBRD1',
#  'RAB5C',
#  'RNASEN',
#  'FUNDC2',
#  'USP1',
#  'C21orf45',
#  'TFEB',
#  'RNF141',
#  'GHDC',
#  'ERH',
#  'ANKRD24',
#  'SEPT13',
#  'DENND5A',
#  'NR2C2AP',
#  'KCNS3',
#  'FRG1',
#  'RPSAP15',
#  'DNAJB12',
#  'SULT1A2',
#  'TSEN15',
#  'MDC1',
#  'GAS7',
#  'AGXT2L2',
#  'COX7A1',
#  'SGK493',
#  'COMMD2',
#  'SHKBP1',
#  'BAT1',
#  'WIPF2',
#  'MCM7',
#  'NDUFA12',
#  'ATG13',
#  'ZNF574',
#  'DLSTP',
#  'SLC27A5',
#  'ARHGAP4',
#  'ATP2B3',
#  'TBC1D9B',
#  'LOC100289349',
#  'C17orf90',
#  'ESRRA',
#  'ITGB1BP1',
#  'NCL',
#  'ATP9B',
#  'TCEAL6',
#  'RPL10',
#  'APLP1',
#  '61E3.4',
#  'TTLL13',
#  'ITGA7',
#  'C20orf24',
#  'CENPB',
#  'AC106037.2',
#  'ARAP2',
#  'KREMEN2',
#  'EEF1D',
#  'COX19',
#  'SLC25A6',
#  'CALU',
#  'PAQR6',
#  'RYBP',
#  'WWC3',
#  'MYO18A',
#  'SHFM1',
#  'LOC729973',
#  'NRBP2',
#  'PCM1',
#  'SURF2',
#  'FBXW11',
#  'GSTO1',
#  'USP16',
#  'AC087742.2',
#  'SCRT1',
#  'ILK',
#  'AATK',
#  'ACBD6',
#  'CCNB1IP1',
#  'EEF1A1P9',
#  'CKS1BP6',
#  'HDDC3',
#  'LOC730234',
#  'RER1',
#  'AIFM1',
#  'CTNNA1',
#  'TTLL11',
#  'RPL31P11',
#  'SNTB2',
#  'CYP2R1',
#  'ACTB',
#  'CCDC53',
#  'RPL35',
#  'MAP3K7IP1',
#  'CD68',
#  'LDB3',
#  'HGS',
#  'STX4',
#  'ACTR1B',
#  'KIAA0562',
#  'C19orf42',
#  'EZH1',
#  'RPS2',
#  'HNRNPA3',
#  'UQCRB',
#  'ZNF337',
#  'HNRNPD',
#  'IFI6',
#  'MMP19',
#  'MRPS9',
#  'SCLY',
#  'MIEN1',
#  'PECAM1',
#  'NDUFB11',
#  'ATP5L',
#  'KIF13B',
#  'KIAA1310',
#  'RPS27',
#  'PRPF3',
#  'KIF1C',
#  'HLA-E',
#  'ZNF691',
#  'C14orf156',
#  'RPL28',
#  'JAKMIP3',
#  'LOC100128775',
#  'IBTK',
#  'RRAS',
#  'NDUFB9',
#  'NFATC3',
#  'AGBL5',
#  'POLG',
#  'MYO1D',
#  'INTS4',
#  'EEF1A1P24',
#  'FGFR2',
#  'RPUSD4',
#  'UPF1',
#  'EBLN2',
#  'MED27',
#  'ALDH16A1',
#  'LOC391322',
#  'C1QTNF4',
#  'IQCJ-SCHIP1',
#  'FRYL',
#  'FTHL16',
#  'NDUFB2',
#  'FKBP8',
#  'ST3GAL3',
#  'TRIM41',
#  'ADCY4',
#  'DNAJB2',
#  'SLC44A1',
#  'LRRC37BP1',
#  'PHF3',
#  'POMGNT1',
#  'SAP30L',
#  'RPL6P10',
#  'THOC7',
#  'GTF3C6',
#  'RPS15A',
#  'ZNF684',
#  'COMMD1',
#  'PTPRK',
#  'QDPR',
#  'LTV1',
#  'PREX1',
#  'CTNNA3',
#  'FXYD4',
#  'FBXO25',
#  'RP4-695O20__B.1',
#  'DYSF',
#  'SSU72',
#  'HMGN2P15',
#  'CCDC47',
#  'RAC1',
#  'PTGDS',
#  'PHC2',
#  'LOC100289420',
#  'ADD1',
#  'DPYSL2',
#  'TOMM6',
#  'NDUFA7',
#  'PSMB6',
#  'ZNF652',
#  'BIN1',
#  'FLJ44635',
#  'LOC100286946',
#  'RPS11P5',
#  'CA11',
#  'FUS',
#  'CAMK2N1',
#  'C8orf4',
#  'FAM49B',
#  'RNASEH2C',
#  'CSTB',
#  'CCDC84',
#  'ELF2',
#  'ANKRD13A',
#  'PELI3',
#  'PARP6',
#  'RNF208',
#  'LY6E',
#  'HINT1',
#  'RP11-428G5.1',
#  'HNRNPH1',
#  'NFKBIB',
#  'RPL10L',
#  'SERINC1',
#  'GIPC1',
#  'NDUFB8',
#  'SF3B3',
#  'TMEM14C',
#  'PXN',
#  'SH3BP5L',
#  'TINF2',
#  'HNRNPA1P2',
#  'TBC1D10B',
#  'SSNA1',
#  'C14orf2',
#  'ASTN2',
#  'IPPK',
#  'LGALS9',
#  'CUL4A',
#  'PIAS4',
#  'FANCA',
#  'AIF1L',
#  'DDX1',
#  'C22orf9',
#  'DERA',
#  'ZNF266',
#  'MRPS36',
#  'SLC25A25',
#  'C6orf48',
#  'FAM168B',
#  'C21orf57',
#  'LOC344593',
#  'LOC100293763',
#  'RBM39',
#  'CNIH4',
#  'ZFYVE20',
#  'NDUFA13',
#  'IGFBP6',
#  'NDUFB10',
#  'GMPS',
#  'KCNK6',
#  'SCNM1',
#  'NDUFB4',
#  'FAM123A',
#  'GPM6B',
#  'TSC1',
#  'COL9A2',
#  'WDR83OS',
#  'SNHG8',
#  'AARS',
#  'PET100',
#  'BNIP3L',
#  'SNN',
#  'RPL18AP3',
#  'CYCS',
#  'DSE',
#  'SS18L2',
#  'POU6F1',
#  'ITGAM',
#  'KIAA2013',
#  'TCEB2',
#  'METT11D1',
#  'RAB11FIP4',
#  'ZBTB24',
#  'NAT8L',
#  'RBM5',
#  'FKBP15',
#  'WDR45',
#  'TOMM5',
#  'MPRIP',
#  'BCAR1',
#  'KLHL2',
#  'BAT4',
#  'RABEPK',
#  'COX5A',
#  'ITCH',
#  'ZNF787',
#  'ATP5H',
#  'RAB33A',
#  'TCFL5',
#  'MGC27345',
#  'AC017099.3',
#  'HSPA12B',
#  'CALD1',
#  'NPIPL2',
#  'CRTC3',
#  'GPR62',
#  'NDUFA2',
#  'DARS',
#  'C19orf50',
#  'ST13P4',
#  'MYLIP',
#  'RPL17P20',
#  'SNRPB',
#  'MRPL43',
#  'ARL3',
#  'HP1BP3',
#  'AC023055.2',
#  'LOC100132528',
#  'PRKCZ',
#  'KBTBD11',
#  'NEDD8',
#  'FAM119A',
#  'C9orf80',
#  'PIGT',
#  'MAP1A',
#  'FLCN',
#  'CPLX1',
#  'FTHL17',
#  'SH3GLB2',
#  'PTRF',
#  'C5orf53',
#  'TYRO3',
#  'GIGYF1',
#  'UQCRH',
#  'CCDC59',
#  'LOC100294376',
#  'CDC2L6',
#  'EIF2C2',
#  'ERMN',
#  'NDFIP2',
#  'PTPN23',
#  'ITPK1',
#  'PEX19',
#  'C2orf82',
#  'RP11-27I1.2',
#  'TAF12',
#  'PHB2',
#  'ACAT1',
#  'RBBP6',
#  'NCAM1',
#  'SMC1A',
#  'ZNF271',
#  'TIMMDC1',
#  'MYADML2',
#  'LOC151162',
#  'PSMB1',
#  'RASSF2',
#  'CNIH',
#  'POLG2',
#  'POLD4',
#  'ARL6IP4',
#  'STMN4',
#  'CYFIP1',
#  'APPL1',
#  'RP11-314P12.3',
#  'MCF2L',
#  'PPP2R2D',
#  'MCM8',
#  'SEPT4',
#  'ZFYVE1',
#  'PFN1',
#  'MSRA',
#  'H3F3A',
#  'EDF1',
#  'RPL22L1',
#  'IK',
#  'FBXO7',
#  'NUP35',
#  'C14orf166',
#  'ATP5E',
#  'BID',
#  'KLHL21',
#  'COL20A1',
#  'GOLGB1',
#  'LYN',
#  'COPA',
#  'EIF3A',
#  'RP9',
#  'CHCHD7',
#  'MCEE',
#  'WBP1',
#  'EME1',
#  'TMCC2',
#  'AZGP1',
#  'ALDOB',
#  'FNTB',
#  'NHLRC1',
#  'HOOK2',
#  'LOC646890',
#  'OIP5-AS1',
#  'DBP',
#  'ETFB',
#  'CCDC56',
#  'PADI2',
#  'WDR23',
#  'SUCNR1',
#  'MRPS28',
#  'ARPP19',
#  'TCF4',
#  'ZNF689',
#  'TMEM199',
#  'CISD3',
#  'MTDH',
#  'AGFG1',
#  'GGTA1',
#  'MTRR',
#  'ANP32BP1',
#  'PXK',
#  'FAM71E1',
#  'RP11-392P7.1',
#  'SLC7A5P2',
#  'CLPP',
#  'XAF1',
#  'SRGAP2C',
#  'UQCRHL',
#  'NSUN5B',
#  'IDNK',
#  'TRMT5',
#  'BUD31',
#  'RPL29P2',
#  'FAM108A4P',
#  'TAZ',
#  'URM1',
#  'COX4NB',
#  'AGPAT4',
#  'PPP2R3A',
#  'GPR116',
#  'ADAMTSL2',
#  'BCDIN3D',
#  'ADC',
#  'VWA1',
#  'PLAC8L1',
#  'PFDN1',
#  'CMTM5',
#  'C13orf15',
#  'CEP95',
#  'ZNF48',
#  'ARRDC2',
#  'MTERFD2',
#  'CYTSB',
#  'KCTD11',
#  'TMEM140',
#  'KIAA1598',
#  'LOC643630',
#  'SLC30A4',
#  'ZNF536',
#  'C1QTNF1',
#  'SLC35E3',
#  'TICAM1',
#  'MED25',
#  'IKBKAP',
#  'WIBG',
#  'RARS2',
#  'SAP30',
#  'PWP2H',
#  'RPSAP9',
#  'AC025647.1',
#  'RP11-195F19.5',
#  'EHMT2',
#  'RP11-169K16.9',
#  'TRAF1',
#  'SDCCAG10',
#  'MPP1',
#  'EBNA1BP2',
#  'ARHGAP21',
#  'TAF9',
#  'GNAO1',
#  'EIF2S2',
#  'GPIHBP1',
#  'FIZ1',
#  'VPS72',
#  'SFRS17A',
#  'TOMM22',
#  'FBXO17',
#  'C8orf59',
#  'POP7',
#  'RPS14',
#  'DIP2A',
#  'CNDP2',
#  'CA14',
#  'CRTC2',
#  'OCEL1',
#  'NDUFAF3',
#  'DEK',
#  'GPKOW',
#  'CSRP1',
#  'APEX1',
#  'BRSK1',
#  'ANKRD11',
#  'ZBTB7A',
#  'DDX39',
#  'IQCE',
#  'LOC729400',
#  'ALG8',
#  'AKAP1',
#  'CEBPZ',
#  'FNBP1',
#  'PCTK1',
#  'LENG1',
#  'BBIP1',
#  'MRPL48',
#  'USMG5']
